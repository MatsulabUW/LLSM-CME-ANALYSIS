# %% [markdown]
# # In this notebook a Tracks Class from filters.py is used to calculate different features of tracks and assist in applying filters accordingly

# %%
import pandas as pd 
import numpy as np 
import sys
sys.path.append('../src/')
from filters import Track, create_tracks_from_dataframe, drop_short_tracks
from filters import drop_early_peak_tracks, drop_last_frame_peak_tracks, drop_tracks_below_intensity
from filters import plot_z_sum, allocate_membrane_regions, plot_z_sum_bd
import napari
import zarr
import dask.array as da
import os

# %% [markdown]
# ### Do not change the code in the cell below

# %%
# This assumes that your notebook is inside 'Jupyter Notebooks', which is at the same level as 'test_data'
base_dir = os.path.join(os.path.dirname(os.path.abspath("__file__")), '..', 'test_data')

zarr_directory = 'zarr_file/all_channels_data'
zarr_full_path = os.path.join(base_dir, zarr_directory)

input_directory = 'datasets'
input_file_name = 'track_df_cleaned_final_full.pkl'
input_directory_full = os.path.join(base_dir,input_directory, input_file_name)

output_directory = 'datasets'
output_file_name = 'filtered_tracks_final.pkl'
output_directory_full = os.path.join(base_dir,output_directory, output_file_name)

# %%
track_df = pd.read_pickle(input_directory_full)

z2 = zarr.open(zarr_full_path, mode='r')
z2.shape
# Out:
# (130, 3, 75, 258, 275)

# %%
track_df.head()
# Out:
#    frame  c3_gaussian_amp  c3_mu_x  c3_mu_y  c3_mu_z  c3_sigma_x  c3_sigma_y  \
# 0      0       206.593249     11.0     12.0      0.0         2.0         2.0
# 1      0       191.000000     36.0     88.0      1.0         2.0         1.0
# 2      0       231.007679     40.0    141.0      1.0         2.0         2.0
# 3      0       185.152538     40.0     58.0      1.0         2.0         1.0
# 4      0       202.000000     46.0     73.0      1.0         2.0         2.0
#
#    c3_sigma_z  tree_id  track_id  ...  c1_peak_z  c1_voxel_sum  \
# 0         4.0        0         0  ...          2          8395
# 1         2.0        1         1  ...          3         12758
# 2         2.0        2         2  ...          3         12604
# 3         3.0        3         3  ...          3         12234
# 4         3.0        4         4  ...          4         12659
#
#    c1_voxel_sum_adjusted  c1_gaussian_amp  c1_mu_x  c1_mu_y  c1_mu_z  \
# 0             135.363636       229.333333     10.0     14.0      1.0
# 1             -47.294118       185.082663     37.0     86.0      7.0
# 2              25.176471       196.333333     39.0    139.0      3.0
# 3            -298.941176       191.000000     43.0     58.0      3.0
# 4              -1.588235       214.000000     48.0     71.0      4.0
#
#    c1_sigma_x  c1_sigma_y  c1_sigma_z
# 0         0.0         2.0         1.0
# 1         3.0         3.0        10.0
# 2         2.0         2.0         4.0
# 3         4.0         2.0         3.0
# 4         3.0         2.0         4.0
#
# [5 rows x 46 columns]

# %%
track_df.shape
# Out:
# (43346, 46)

# %%
tracks = create_tracks_from_dataframe(df = track_df, intensities_col_name = ['c3_gaussian_amp', 'c2_peak_amp', 'c1_peak_amp'], 
track_id_col_name = 'track_id', frame_col_name = 'frame', coords = ['c3_mu_x', 'c3_mu_y', 'c3_mu_z'])

# %%
# Create DataFrame from Track instances
tracks_data = {
    'track_id': [track.track_id.values[0] for track in tracks],
    'track_length': [track.track_length for track in tracks],
    'track_start': [track.track_start for track in tracks],
    'track_end': [track.track_end for track in tracks],
    'c3_peak': [track.peak_intensities[0] for track in tracks],
    'c2_peak': [track.peak_intensities[1] for track in tracks],
    'c1_peak': [track.peak_intensities[2] for track in tracks],
    'c3_peak_frame': [track.peak_intensity_frames[0] for track in tracks],
    'c2_peak_frame': [track.peak_intensity_frames[1] for track in tracks],
    'c1_peak_frame': [track.peak_intensity_frames[2] for track in tracks],
    'mean_displacement': [track.mean_displacement_track for track in tracks],
    'mean_z': [track.mean_z_value for track in tracks],
    'mean_z_displacement': [track.mean_z_displacement for track in tracks]
}

tracks_df = pd.DataFrame(tracks_data)

# %%
tracks_df.head()
# Out:
#    track_id  track_length  track_start  track_end     c3_peak  c2_peak  \
# 0         0             1            0          0  206.593249    152.0
# 1         1             1            0          0  191.000000    143.0
# 2         2             1            0          0  231.007679    142.0
# 3         3             1            0          0  185.152538    142.0
# 4         4             2            0          1  202.000000    141.0
#
#    c1_peak  c3_peak_frame  c2_peak_frame  c1_peak_frame  mean_displacement  \
# 0    231.0              0              0              0                NaN
# 1    189.0              0              0              0                NaN
# 2    198.0              0              0              0                NaN
# 3    196.0              0              0              0                NaN
# 4    219.0              0              0              0                1.0
#
#    mean_z  mean_z_displacement
# 0     0.0                  NaN
# 1     1.0                  NaN
# 2     1.0                  NaN
# 3     1.0                  NaN
# 4     1.0                  0.0

# %%
tracks_df[tracks_df['track_id']==541]
# Out:
#      track_id  track_length  track_start  track_end  c3_peak  c2_peak  \
# 541       541             1            2          2    246.0    167.0
#
#      c1_peak  c3_peak_frame  c2_peak_frame  c1_peak_frame  mean_displacement  \
# 541    199.0              2              2              2                NaN
#
#      mean_z  mean_z_displacement
# 541     3.0                  NaN

# %%
tracks_df.shape
# Out:
# (17515, 13)

# %% [markdown]
# # DROPPING SHORT TRACKS

# %%
#dropping tracks of length 3 and below
length_filtered_tracks_df = drop_short_tracks(df = tracks_df, threshold = 3)

# %%
length_filtered_tracks_df.shape
# Out:
# (4413, 13)

# %% [markdown]
# ## Determining Valid Channel 3 tracks

# %% [markdown]
# ### Dropping tracks with Clathrin (Channel 3 peak in the last frame)

# %%
valid_c3_tracks = drop_last_frame_peak_tracks(df = length_filtered_tracks_df, intensity_col = 'c3_peak_frame')

# %%
valid_c3_tracks.shape
# Out:
# (3569, 13)

# %% [markdown]
# ### Dropping tracks with Clathrin (Channel 3) which have their peaks in the first three frames

# %%
valid_c3_tracks = drop_early_peak_tracks(df = valid_c3_tracks, intensity_peak_frame = 'c3_peak_frame', 
                                      cutoff = 3)

# %%
valid_c3_tracks.shape
# Out:
# (659, 13)

# %% [markdown]
# **valid_c3_tracks will serve as baseline clathrin positive and valid tracks**

# %% [markdown]
# # Filtering for Channel 2 (Dynamin)

# %% [markdown]
# ## Filter 1
# ### Identifying Dynamin Positive Tracks

# %%
dnm2_positive_tracks = drop_tracks_below_intensity(df = valid_c3_tracks, threshold = 150, 
                                          intensity_peak_frame = 'c2_peak')

# %%
dnm2_positive_tracks.shape
# Out:
# (641, 13)

# %% [markdown]
# ## Filter 2
# ### Filter tracks based on channel 2 peak if occurs within 3 frames of starting of a track

# %%
dnm2_positive_tracks = drop_early_peak_tracks(df = dnm2_positive_tracks, intensity_peak_frame = 'c2_peak_frame', 
                                      cutoff = 3)

# %%
dnm2_positive_tracks.shape
# Out:
# (400, 13)

# %% [markdown]
# ## Filter 3
# ### Filter tracks based on channel 2 peaks occuring in the last frame

# %%
dnm2_positive_tracks = drop_last_frame_peak_tracks(df = dnm2_positive_tracks, intensity_col = 'c2_peak_frame')

# %%
dnm2_positive_tracks.shape
# Out:
# (316, 13)

# %% [markdown]
# **dnm2_positive_tracks will serve as the baseline for dynamin positive tracks**

# %% [markdown]
# # Identifying Channel 1 (Actin) positive tracks

# %% [markdown]
# ## Filter 1
# ### Identifying Actin Positive Tracks

# %%
actin_positive_tracks = drop_tracks_below_intensity(df = valid_c3_tracks, threshold = 240, 
                                          intensity_peak_frame = 'c1_peak' )

# %%
actin_positive_tracks.shape
# Out:
# (562, 13)

# %% [markdown]
# ## Filter 2
# ### Filter tracks based on channel 1 peaks if occurs within the first 3 frames

# %%
actin_positive_tracks = drop_early_peak_tracks(df = actin_positive_tracks, intensity_peak_frame = 'c1_peak_frame', 
                                      cutoff = 3)

# %%
actin_positive_tracks.shape
# Out:
# (349, 13)

# %% [markdown]
# ## Filter 3
# ### Filter tracks based on channel 1 peaks occuring in the last frame

# %%
actin_positive_tracks = drop_last_frame_peak_tracks(df = actin_positive_tracks, intensity_col = 'c1_peak_frame')

# %%
actin_positive_tracks.shape
# Out:
# (273, 13)

# %% [markdown]
# # Combining actin and dynamin positive tracks with valid clathrin positive tracks

# %%
final_tracks = valid_c3_tracks.copy(deep = True)

# %%
final_tracks['dnm2_positive'] = False

# %%
final_tracks['actin_positive'] = False

# %%
final_tracks.head()
# Out:
#      track_id  track_length  track_start  track_end     c3_peak  c2_peak  \
# 22         22             8            0          7  268.426824    168.0
# 65         65             8            0          7  345.835302    224.0
# 93         93             8            0          7  308.000000    169.0
# 95         95             8            0          7  332.333333    201.0
# 100       100            22            0         21  257.000000    188.0
#
#      c1_peak  c3_peak_frame  c2_peak_frame  c1_peak_frame  mean_displacement  \
# 22     238.0              4              7              6           1.080068
# 65     420.0              6              6              6           2.043674
# 93     230.0              6              3              5           1.222925
# 95     251.0              6              7              7           3.090703
# 100    513.0             13             21             13           2.233344
#
#         mean_z  mean_z_displacement  dnm2_positive  actin_positive
# 22    1.625000             0.428571          False           False
# 65    6.625000             1.571429          False           False
# 93   11.500000             0.857143          False           False
# 95   13.000000             1.714286          False           False
# 100  12.090909             0.904762          False           False

# %% [markdown]
# ***Setting actin positive tracks to True***

# %%
# Get the track IDs from actin_positive_tracks
actin_positive_track_ids = actin_positive_tracks['track_id']

# Set 'actin_positive' to True for rows where 'track_id' is in positive_track_ids
final_tracks.loc[final_tracks['track_id'].isin(actin_positive_track_ids), 'actin_positive'] = True

# %%
final_tracks[final_tracks['actin_positive'] == True]
# Out:
#        track_id  track_length  track_start  track_end     c3_peak  c2_peak  \
# 65           65             8            0          7  345.835302    224.0
# 100         100            22            0         21  257.000000    188.0
# 137         137            12            0         11  335.000000    231.0
# 172         172            13            0         12  286.000000    196.0
# 204         204            12            0         11  324.000000    193.0
# ...         ...           ...          ...        ...         ...      ...
# 16538     16538             8          120        127  230.599300    194.0
# 16646     16646             6          122        127  213.000000    156.0
# 16787     16787             7          123        129  191.000000    177.0
# 16825     16825             7          123        129  226.485961    187.0
# 16847     16847             7          123        129  257.189037    212.0
#
#        c1_peak  c3_peak_frame  c2_peak_frame  c1_peak_frame  \
# 65       420.0              6              6              6
# 100      513.0             13             21             13
# 137      448.0              7              4              5
# 172      305.0              7              9              8
# 204      287.0              7              9              9
# ...        ...            ...            ...            ...
# 16538    269.0            124            123            125
# 16646    281.0            126            126            126
# 16787    306.0            127            129            127
# 16825    280.0            128            127            127
# 16847    312.0            127            124            128
#
#        mean_displacement     mean_z  mean_z_displacement  dnm2_positive  \
# 65              2.043674   6.625000             1.571429          False
# 100             2.233344  12.090909             0.904762          False
# 137             2.050306  17.416667             1.636364          False
# 172             1.903529  27.846154             1.250000          False
# 204             2.032328  33.083333             1.272727          False
# ...                  ...        ...                  ...            ...
# 16538           2.140131  68.875000             1.285714          False
# 16646           2.959874   3.666667             1.600000          False
# 16787           3.673223  11.857143             1.833333          False
# 16825           2.005698  34.857143             1.333333          False
# 16847           1.685731  53.000000             1.166667          False
#
#        actin_positive
# 65               True
# 100              True
# 137              True
# 172              True
# 204              True
# ...               ...
# 16538            True
# 16646            True
# 16787            True
# 16825            True
# 16847            True
#
# [273 rows x 15 columns]

# %%
actin_rows_count = final_tracks[final_tracks['actin_positive'] == True].shape[0]
print(f'number of actin positive tracks are: {actin_rows_count}')
# Out:
# number of actin positive tracks are: 273

# %% [markdown]
# ***Setting dynamin positive tracks to True***

# %%
# Get the track IDs from actin_positive_tracks
dnm2_positive_track_ids = dnm2_positive_tracks['track_id']

# Set 'actin_positive' to True for rows where 'track_id' is in positive_track_ids
final_tracks.loc[final_tracks['track_id'].isin(dnm2_positive_track_ids), 'dnm2_positive'] = True

# %%
final_tracks[final_tracks['dnm2_positive'] == True]
# Out:
#        track_id  track_length  track_start  track_end     c3_peak  c2_peak  \
# 65           65             8            0          7  345.835302    224.0
# 137         137            12            0         11  335.000000    231.0
# 161         161             9            0          8  242.014911    176.0
# 168         168            40            0         39  250.679774    185.0
# 172         172            13            0         12  286.000000    196.0
# ...         ...           ...          ...        ...         ...      ...
# 16453     16453            10          120        129  234.000000    188.0
# 16646     16646             6          122        127  213.000000    156.0
# 16699     16699             8          122        129  222.000000    151.0
# 16825     16825             7          123        129  226.485961    187.0
# 16974     16974             6          124        129  314.492478    187.0
#
#        c1_peak  c3_peak_frame  c2_peak_frame  c1_peak_frame  \
# 65       420.0              6              6              6
# 137      448.0              7              4              5
# 161      266.0              6              5              0
# 168      255.0             27             36              0
# 172      305.0              7              9              8
# ...        ...            ...            ...            ...
# 16453    257.0            124            126            128
# 16646    281.0            126            126            126
# 16699    235.0            126            127            123
# 16825    280.0            128            127            127
# 16974    763.0            128            128            129
#
#        mean_displacement     mean_z  mean_z_displacement  dnm2_positive  \
# 65              2.043674   6.625000             1.571429           True
# 137             2.050306  17.416667             1.636364           True
# 161             2.569747  25.222222             1.250000           True
# 168             2.065427  28.700000             1.051282           True
# 172             1.903529  27.846154             1.250000           True
# ...                  ...        ...                  ...            ...
# 16453           2.216026   7.000000             1.777778           True
# 16646           2.959874   3.666667             1.600000           True
# 16699           1.724438  40.500000             1.142857           True
# 16825           2.005698  34.857143             1.333333           True
# 16974           1.229253  68.166667             0.200000           True
#
#        actin_positive
# 65               True
# 137              True
# 161             False
# 168             False
# 172              True
# ...               ...
# 16453            True
# 16646            True
# 16699           False
# 16825            True
# 16974           False
#
# [316 rows x 15 columns]

# %%
dnm2_rows_count = final_tracks[final_tracks['dnm2_positive'] == True].shape[0]
print(f'number of dynamin positive tracks are: {dnm2_rows_count}')
# Out:
# number of dynamin positive tracks are: 316

# %%
final_tracks[(final_tracks['dnm2_positive'] == True) & (final_tracks['actin_positive'] == True)]
# Out:
#        track_id  track_length  track_start  track_end     c3_peak  c2_peak  \
# 65           65             8            0          7  345.835302    224.0
# 137         137            12            0         11  335.000000    231.0
# 172         172            13            0         12  286.000000    196.0
# 204         204            12            0         11  324.000000    193.0
# 210         210            11            0         10  309.655343    215.0
# ...         ...           ...          ...        ...         ...      ...
# 16110     16110            13          117        129  232.000000    166.0
# 16371     16371             7          119        125  213.000000    203.0
# 16453     16453            10          120        129  234.000000    188.0
# 16646     16646             6          122        127  213.000000    156.0
# 16825     16825             7          123        129  226.485961    187.0
#
#        c1_peak  c3_peak_frame  c2_peak_frame  c1_peak_frame  \
# 65       420.0              6              6              6
# 137      448.0              7              4              5
# 172      305.0              7              9              8
# 204      287.0              7              9              9
# 210      257.0              7              4              5
# ...        ...            ...            ...            ...
# 16110    414.0            121            125            124
# 16371    282.0            124            124            124
# 16453    257.0            124            126            128
# 16646    281.0            126            126            126
# 16825    280.0            128            127            127
#
#        mean_displacement     mean_z  mean_z_displacement  dnm2_positive  \
# 65              2.043674   6.625000             1.571429           True
# 137             2.050306  17.416667             1.636364           True
# 172             1.903529  27.846154             1.250000           True
# 204             2.032328  33.083333             1.272727           True
# 210             2.036238  36.636364             0.800000           True
# ...                  ...        ...                  ...            ...
# 16110           2.677562   7.923077             1.166667           True
# 16371           1.522828  45.857143             0.500000           True
# 16453           2.216026   7.000000             1.777778           True
# 16646           2.959874   3.666667             1.600000           True
# 16825           2.005698  34.857143             1.333333           True
#
#        actin_positive
# 65               True
# 137              True
# 172              True
# 204              True
# 210              True
# ...               ...
# 16110            True
# 16371            True
# 16453            True
# 16646            True
# 16825            True
#
# [159 rows x 15 columns]

# %%
actin_dnm2_rows_count = final_tracks[(final_tracks['dnm2_positive'] == True) & 
                                     (final_tracks['actin_positive'] == True)].shape[0]
print(f'number of dynamin and actin positive tracks are: {actin_dnm2_rows_count}')
# Out:
# number of dynamin and actin positive tracks are: 159

# %% [markdown]
# # Allocating Apical/Basal/Lateral boundaries to tracks
# Using channel 1 (actin) for this purpose

# %%
#channel is hard coded in the function right now. Need to allow it to be passed as a parameter by the user 
plot_z_sum_bd(z2)
# Out:
# (75, 258, 275)
# frame is 0
# (75, 258, 275)
# frame is 32
# (75, 258, 275)
# frame is 65
# (75, 258, 275)
# frame is 97
# (75, 258, 275)
# frame is 129

# %% [markdown]
# Based on the above results the following boundaries can be determined
# 1. Basal (0-18)
# 2. Lateral(19-84)
# 3. Apical(85-116)

# %%
allocate_membrane_regions(df = final_tracks, basal_range = [0,10] , lateral_range = [10,68], apical_range = [68,75])
# Out:
#        track_id  track_length  track_start  track_end     c3_peak  c2_peak  \
# 22           22             8            0          7  268.426824    168.0
# 65           65             8            0          7  345.835302    224.0
# 93           93             8            0          7  308.000000    169.0
# 95           95             8            0          7  332.333333    201.0
# 100         100            22            0         21  257.000000    188.0
# ...         ...           ...          ...        ...         ...      ...
# 16825     16825             7          123        129  226.485961    187.0
# 16847     16847             7          123        129  257.189037    212.0
# 16933     16933             6          124        129  235.560093    170.0
# 16956     16956             6          124        129  209.000000    167.0
# 16974     16974             6          124        129  314.492478    187.0
#
#        c1_peak  c3_peak_frame  c2_peak_frame  c1_peak_frame  \
# 22       238.0              4              7              6
# 65       420.0              6              6              6
# 93       230.0              6              3              5
# 95       251.0              6              7              7
# 100      513.0             13             21             13
# ...        ...            ...            ...            ...
# 16825    280.0            128            127            127
# 16847    312.0            127            124            128
# 16933    248.0            128            124            124
# 16956    256.0            128            129            129
# 16974    763.0            128            128            129
#
#        mean_displacement     mean_z  mean_z_displacement  dnm2_positive  \
# 22              1.080068   1.625000             0.428571          False
# 65              2.043674   6.625000             1.571429           True
# 93              1.222925  11.500000             0.857143          False
# 95              3.090703  13.000000             1.714286          False
# 100             2.233344  12.090909             0.904762          False
# ...                  ...        ...                  ...            ...
# 16825           2.005698  34.857143             1.333333           True
# 16847           1.685731  53.000000             1.166667          False
# 16933           1.777270  46.666667             1.200000          False
# 16956           1.744551  60.333333             1.000000          False
# 16974           1.229253  68.166667             0.200000           True
#
#        actin_positive membrane_region
# 22              False           Basal
# 65               True           Basal
# 93              False         Lateral
# 95              False         Lateral
# 100              True         Lateral
# ...               ...             ...
# 16825            True         Lateral
# 16847            True         Lateral
# 16933           False         Lateral
# 16956           False         Lateral
# 16974           False          Apical
#
# [659 rows x 16 columns]

# %% [markdown]
# # Visualising tracks in Napari

# %%
# Create a napari viewer
viewer = napari.Viewer()

#access channel 3 only from zarr array 
dask_array = da.from_zarr(z2)

#the axis arrangement is (t,c,z,y,x)
#for the sake of improved performance only 1 channel could be imported here (if images get super large and performance issues occur)
channel_3 = dask_array[:,:,:,4:2050,:]

# Add the 4D stack to the viewer
layer_raw = viewer.add_image(channel_3, channel_axis = 1, name = ['actin', 'dynamin', 'clathrin'])
#other useful parameters 
#color_map = list
#contrast_limits = list of list 

# Add Bounding Box
layer_raw[0].bounding_box.visible = True
layer_raw[1].bounding_box.visible = True
layer_raw[2].bounding_box.visible = True

# %%
viewer.add_tracks(track_df[["track_id", "frame", "c3_mu_z", "c3_mu_y", "c3_mu_x"]], name = 'all tracks')
# Out:
# <Tracks layer 'all tracks' at 0x7fb6482430a0>

# %%
#Displaying Dynamin Positive tracks only (Tracks where actin is not present)
dnm2_positive_tracks_df = final_tracks[(final_tracks['dnm2_positive'] == True) & (final_tracks['actin_positive'] == False)]
dnm2_tracks_list = dnm2_positive_tracks_df['track_id'].values
track_1 = track_df[track_df['track_id'].isin(dnm2_tracks_list)]
viewer.add_tracks(track_1[["track_id", "frame", "c3_mu_z", "c3_mu_y", "c3_mu_x"]], name = 'dynamin+ tracks')
# Out:
# <Tracks layer 'dynamin+ tracks' at 0x7fb648243100>

# %%
#Displaying Actin Positive tracks only (Tracks where Dynamin is not present)
actin_positive_tracks_df = final_tracks[(final_tracks['dnm2_positive'] == False) & (final_tracks['actin_positive'] == True)]
actin_tracks_list = actin_positive_tracks_df['track_id'].values
track_2 = track_df[track_df['track_id'].isin(actin_tracks_list)]
viewer.add_tracks(track_2[["track_id", "frame", "c3_mu_z", "c3_mu_y", "c3_mu_x"]], name = 'actin+ tracks')
# Out:
# <Tracks layer 'actin+ tracks' at 0x7fb633144c70>

# %%
#Displaying all 3 channels positive tracks 
all_positive_tracks_df = final_tracks[(final_tracks['dnm2_positive'] == True) & (final_tracks['actin_positive'] == True)]
all_positive_tracks_list = all_positive_tracks_df['track_id'].values
track_3 = track_df[track_df['track_id'].isin(all_positive_tracks_list)]
viewer.add_tracks(track_3[["track_id", "frame","c3_mu_z", "c3_mu_y", "c3_mu_x"]], name = 'all+ tracks')
# Out:
# <Tracks layer 'all+ tracks' at 0x7fb63303ef20>

# %%
#Displaying basal tracks 
basal_tracks_df = final_tracks[final_tracks['membrane_region'] == 'Basal']
basal_tracks_list = basal_tracks_df['track_id'].values
track_4 = track_df[track_df['track_id'].isin(basal_tracks_list)]
viewer.add_tracks(track_4[["track_id", "frame","c3_mu_z", "c3_mu_y", "c3_mu_x"]], name = 'basal tracks')
# Out:
# <Tracks layer 'basal tracks' at 0x7fb635402680>

# %%
#Displaying lateral tracks 
lateral_tracks_df = final_tracks[final_tracks['membrane_region'] == 'Lateral']
lateral_tracks_list = lateral_tracks_df['track_id'].values
track_5 = track_df[track_df['track_id'].isin(lateral_tracks_list)]
viewer.add_tracks(track_5[["track_id", "frame", "c3_mu_z", "c3_mu_y", "c3_mu_x"]], name = 'Lateral tracks')
# Out:
# <Tracks layer 'Lateral tracks' at 0x7fb6359bb490>

# %%
#Displaying apical tracks 
apical_tracks_df = final_tracks[final_tracks['membrane_region'] == 'Apical']
apical_tracks_list = apical_tracks_df['track_id'].values
track_6 = track_df[track_df['track_id'].isin(apical_tracks_list)]
viewer.add_tracks(track_6[["track_id", "frame","c3_mu_z", "c3_mu_y", "c3_mu_x"]], name = 'Apical tracks')
# Out:
# <Tracks layer 'Apical tracks' at 0x7fb635f2b370>

# %%
final_tracks.to_pickle(output_directory_full)

# %%
final_tracks.shape
# Out:
# (659, 16)

# %% [markdown]
# ### final_tracks dataframe stores tracks which are at least clathrin positive.
