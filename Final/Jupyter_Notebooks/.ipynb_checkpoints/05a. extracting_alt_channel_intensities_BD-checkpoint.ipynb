# %% [markdown]
# # The following notebook uses the dataframe on which tracking has been performed and uses the spots coordinates to extract activity from alternate channels.

# %%
from os import path
import pandas as pd
from IPython.display import display
import numpy as np 
import sys 
import time 
import zarr

sys.path.append('../src/')

from extract_pixel_data import Extractor

#plt.rcParams["font.family"] = ""

# %%
#provide the file path of the tracking dataframe returned from notebook 04 
file_path = "/Users/apple/Desktop/Akamatsu_Lab/Data/full_movie_output/track_df_c3_cleaned.pkl"
track_df = pd.read_pickle(file_path)

# %%
track_df
# Out:
#         frame  index   amplitude   mu_x    mu_y   mu_z  sigma_x  sigma_y  \
# 0           0      0  175.000000   19.0  1813.0    3.0      2.0      1.0
# 1           0      1  188.000000   24.0  1804.0    4.0      2.0      2.0
# 2           0      2  182.305173   49.0   569.0    4.0      2.0      1.0
# 3           0      3  176.000000  134.0   739.0    4.0      2.0      2.0
# 4           0      4  178.000000   39.0  1124.0    4.0      3.0      2.0
# ...       ...    ...         ...    ...     ...    ...      ...      ...
# 515930    129   3059  227.867919  231.0  1921.0  110.0      2.0      2.0
# 515931    129   3060  269.333333  258.0  1272.0  110.0      2.0      1.0
# 515932    129   3061  186.475768  259.0  1339.0  110.0      3.0      2.0
# 515933    129   3062  184.892993  275.0  1325.0  110.0      2.0      2.0
# 515934    129   3063  346.333333  295.0  1279.0  110.0      3.0      3.0
#
#         sigma_z  frame_y  tree_id  track_id
# 0           2.0        0        0         0
# 1           3.0        0        1         1
# 2           2.0        0        2         2
# 3           3.0        0        3         3
# 4           3.0        0        4         4
# ...         ...      ...      ...       ...
# 515930      2.0      129   198325    198325
# 515931      2.0      129   198326    198326
# 515932      2.0      129   198327    198327
# 515933      2.0      129   195783    195783
# 515934      2.0      129   198328    198328
#
# [515935 rows x 12 columns]

# %%
# read the zarr file which contains the data of all three channels 
z = zarr.open('/Users/apple/Desktop/Akamatsu_Lab/Data/Zarr_file_new/all_channels_data', mode='r')

# %%
z.info
# Out:
# Type               : zarr.core.Array
# Data type          : uint16
# Shape              : (130, 3, 116, 2052, 340)
# Chunk shape        : (1, 1, 116, 2052, 340)
# Order              : C
# Read-only          : True
# Compressor         : Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)
# Store type         : zarr.storage.DirectoryStore
# No. bytes          : 63126086400 (58.8G)
# No. bytes stored   : 13548767504 (12.6G)
# Storage ratio      : 4.7
# Chunks initialized : 390/390

# %%
track_df['frame'].nunique()
# Out:
# 130

# %% [markdown]
# ## In the below cell the Extractor object is created

# %%
#Create an extractor object with required parameters to properly run the methods in next steps 
# radii is the expected radius of the CME sites (will be used for calculations which need fixed radius) 
# radii_col_name is a list of the variable sigma estimated by gaussian fitting (note: the convention for the list is z,y,x)
# n_jobs is the cores to be used. (parallel processing for gaussian fitting on the other two channels could be done to speed up the process)
extractor = Extractor(z, dataframe = track_df, radii=[4,2,2], frame_col_name = 'frame', 
                      radi_col_name = ['sigma_z', 'sigma_y', 'sigma_x'], n_jobs =2)

# %% [markdown]
# # Extract Information for Channel 3 (Clathrin)

# %% [markdown]
# ## Extracting voxel sum

# %%
# pass the channel for which voxel sum is needed and the coordinates around which voxel sum is supposed to be calculated
# convention for coords [z,y,x] 
# convention for channel is 1 for channel 1, 2 for channel 2 and so on 
# channel number is to passed according to whichever channel we want to extract the data for
start_time = time.time()
voxel_sum_array, _ = extractor.voxel_sum_fixed_bd(center_col_names = ['mu_z', 'mu_y', 'mu_x'], channel = 3)
end_time = time.time()
print('time taken (seconds)', end_time - start_time)

# %%
voxel_sum_array, _, adj_voxel_sum_1 = extractor.voxel_sum_fixed_background_v2(center_col_names = ['mu_z', 'mu_y', 'mu_x'], channel = 3)
# Out:
# current frame is 0
# area_small 96
# area_large 252
# voxel sum small patch 12927
# voxel sum larger patch 33821
# background adjusted sum 69.15384615384664
# area_small 112
# area_large 288
# voxel sum small patch 15894
# voxel sum larger patch 41080
# background adjusted sum -133.4545454545446
# area_small 112
# area_large 288
# voxel sum small patch 14697
# voxel sum larger patch 36356
# background adjusted sum 914.0
# area_small 112
# area_large 288
# voxel sum small patch 15905
# voxel sum larger patch 40803
# background adjusted sum 60.81818181818153
# area_small 112
# area_large 288
# voxel sum small patch 14972
# voxel sum larger patch 38479
# background adjusted sum 13.0
# area_small 128
# area_large 324
# voxel sum small patch 17522
# voxel sum larger patch 43952
# background adjusted sum 261.59183673469306
# area_small 112
# area_large 288
# voxel sum small patch 15730
# voxel sum larger patch 40574
# background adjusted sum -79.81818181818153
# area_small 128
# area_large 324
# voxel sum small patch 17743
# voxel sum larger patch 44890
# background adjusted sum 14.346938775510353
# area_small 96
# area_large 246
# voxel sum small patch 14956
# voxel sum larger patch 37811
# background adjusted sum 328.7999999999993
# area_small 100
# area_large 228
# voxel sum small patch 12818
# voxel sum larger patch 29289
# background adjusted sum -49.96875
# area_small 112
# area_large 246
# voxel sum small patch 14946
# voxel sum larger patch 32859
# background adjusted sum -26.059701492536078
# area_small 128
# area_large 360
# voxel sum small patch 16559
# voxel sum larger patch 46322
# background adjusted sum 138.03448275861956
# area_small 92
# area_large 240
# voxel sum small patch 13795
# voxel sum larger patch 36214
# background adjusted sum -141.13513513513612
# area_small 120
# area_large 270
# voxel sum small patch 15067
# voxel sum larger patch 34188
# background adjusted sum -229.7999999999995
# area_small 120
# area_large 306
# voxel sum small patch 16339
# voxel sum larger patch 39643
# background adjusted sum 1304.1612903225798
# area_small 128
# area_large 360
# voxel sum small patch 16971
# voxel sum larger patch 47462
# background adjusted sum 148.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 16733
# voxel sum larger patch 46385
# background adjusted sum 373.2758620689656
# area_small 128
# area_large 360
# voxel sum small patch 17374
# voxel sum larger patch 47640
# background adjusted sum 675.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 15995
# voxel sum larger patch 45163
# background adjusted sum -97.68965517241304
# area_small 128
# area_large 360
# voxel sum small patch 15590
# voxel sum larger patch 43935
# background adjusted sum -48.6206896551721
# area_small 128
# area_large 360
# voxel sum small patch 16899
# voxel sum larger patch 46788
# background adjusted sum 408.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 17976
# voxel sum larger patch 49470
# background adjusted sum 600.0
# area_small 128
# area_large 360
# voxel sum small patch 16304
# voxel sum larger patch 46120
# background adjusted sum -146.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 16879
# voxel sum larger patch 46815
# background adjusted sum 362.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 20850
# voxel sum larger patch 56759
# background adjusted sum 1038.1379310344819
# area_small 124
# area_large 318
# voxel sum small patch 17764
# voxel sum larger patch 43809
# background adjusted sum 1116.680412371134
# area_small 128
# area_large 360
# voxel sum small patch 16690
# voxel sum larger patch 45031
# background adjusted sum 1053.5862068965525
# area_small 128
# area_large 360
# voxel sum small patch 19143
# voxel sum larger patch 53048
# background adjusted sum 436.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 16276
# voxel sum larger patch 45813
# background adjusted sum -20.27586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16923
# voxel sum larger patch 47455
# background adjusted sum 77.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16858
# voxel sum larger patch 46921
# background adjusted sum 271.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 16262
# voxel sum larger patch 46121
# background adjusted sum -211.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 18009
# voxel sum larger patch 50841
# background adjusted sum -105.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 16654
# voxel sum larger patch 45965
# background adjusted sum 482.4137931034475
# area_small 128
# area_large 360
# voxel sum small patch 17947
# voxel sum larger patch 49197
# background adjusted sum 705.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 17252
# voxel sum larger patch 47094
# background adjusted sum 787.4482758620688
# area_small 128
# area_large 348
# voxel sum small patch 17879
# voxel sum larger patch 47770
# background adjusted sum 487.8727272727265
# area_small 128
# area_large 360
# voxel sum small patch 17238
# voxel sum larger patch 47550
# background adjusted sum 514.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 17898
# voxel sum larger patch 50364
# background adjusted sum -14.275862068963761
# area_small 128
# area_large 360
# voxel sum small patch 16871
# voxel sum larger patch 47252
# background adjusted sum 109.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 19237
# voxel sum larger patch 52591
# background adjusted sum 834.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 15827
# voxel sum larger patch 44453
# background adjusted sum 33.34482758620652
# area_small 128
# area_large 360
# voxel sum small patch 18520
# voxel sum larger patch 51578
# background adjusted sum 281.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 15990
# voxel sum larger patch 44867
# background adjusted sum 57.86206896551812
# area_small 128
# area_large 360
# voxel sum small patch 18936
# voxel sum larger patch 51484
# background adjusted sum 978.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 16869
# voxel sum larger patch 46603
# background adjusted sum 464.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 18422
# voxel sum larger patch 51379
# background adjusted sum 238.82758620689492
# area_small 128
# area_large 360
# voxel sum small patch 18991
# voxel sum larger patch 51997
# background adjusted sum 780.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 17581
# voxel sum larger patch 48445
# background adjusted sum 552.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 21787
# voxel sum larger patch 59452
# background adjusted sum 1006.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 17434
# voxel sum larger patch 48961
# background adjusted sum 39.79310344827536
# area_small 112
# area_large 294
# voxel sum small patch 15717
# voxel sum larger patch 41621
# background adjusted sum -223.9230769230776
# area_small 120
# area_large 306
# voxel sum small patch 15478
# voxel sum larger patch 38714
# background adjusted sum 487.0322580645165
# area_small 128
# area_large 360
# voxel sum small patch 17715
# voxel sum larger patch 48284
# background adjusted sum 849.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 16543
# voxel sum larger patch 46000
# background adjusted sum 290.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 17039
# voxel sum larger patch 47133
# background adjusted sum 435.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18106
# voxel sum larger patch 50940
# background adjusted sum -9.31034482758696
# area_small 128
# area_large 360
# voxel sum small patch 18571
# voxel sum larger patch 52215
# background adjusted sum 8.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 17608
# voxel sum larger patch 48811
# background adjusted sum 392.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 16449
# voxel sum larger patch 45828
# background adjusted sum 239.89655172413768
# area_small 128
# area_large 360
# voxel sum small patch 17519
# voxel sum larger patch 48631
# background adjusted sum 353.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16901
# voxel sum larger patch 47102
# background adjusted sum 238.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 17184
# voxel sum larger patch 47977
# background adjusted sum 194.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 17834
# voxel sum larger patch 49407
# background adjusted sum 414.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18222
# voxel sum larger patch 49353
# background adjusted sum 1046.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 17889
# voxel sum larger patch 49193
# background adjusted sum 617.8275862068949
# area_small 128
# area_large 360
# voxel sum small patch 17245
# voxel sum larger patch 47878
# background adjusted sum 344.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 17281
# voxel sum larger patch 48408
# background adjusted sum 107.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 19818
# voxel sum larger patch 52348
# background adjusted sum 1870.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17212
# voxel sum larger patch 48815
# background adjusted sum -224.13793103448188
# area_small 128
# area_large 360
# voxel sum small patch 16814
# voxel sum larger patch 45707
# background adjusted sum 873.0344827586215
# area_small 128
# area_large 360
# voxel sum small patch 17032
# voxel sum larger patch 46723
# background adjusted sum 650.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 23754
# voxel sum larger patch 62696
# background adjusted sum 2268.758620689656
# area_small 120
# area_large 306
# voxel sum small patch 19287
# voxel sum larger patch 48182
# background adjusted sum 645.0645161290329
# area_small 112
# area_large 282
# voxel sum small patch 15224
# voxel sum larger patch 37414
# background adjusted sum 604.705882352941
# area_small 100
# area_large 264
# voxel sum small patch 12267
# voxel sum larger patch 31490
# background adjusted sum 545.6585365853653
# area_small 88
# area_large 234
# voxel sum small patch 15594
# voxel sum larger patch 41170
# background adjusted sum 178.32876712328812
# area_small 112
# area_large 282
# voxel sum small patch 14460
# voxel sum larger patch 35771
# background adjusted sum 419.8117647058823
# area_small 112
# area_large 294
# voxel sum small patch 16584
# voxel sum larger patch 42397
# background adjusted sum 699.0769230769224
# area_small 128
# area_large 360
# voxel sum small patch 17985
# voxel sum larger patch 48973
# background adjusted sum 888.1724137931051
# area_small 128
# area_large 360
# voxel sum small patch 14985
# voxel sum larger patch 41492
# background adjusted sum 360.44827586206884
# area_small 128
# area_large 360
# voxel sum small patch 17384
# voxel sum larger patch 47113
# background adjusted sum 981.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 17071
# voxel sum larger patch 46753
# background adjusted sum 694.7241379310344
# area_small 128
# area_large 360
# voxel sum small patch 17673
# voxel sum larger patch 48348
# background adjusted sum 748.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 16819
# voxel sum larger patch 46261
# background adjusted sum 575.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 17137
# voxel sum larger patch 47014
# background adjusted sum 653.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 18117
# voxel sum larger patch 50905
# background adjusted sum 27.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 17901
# voxel sum larger patch 48517
# background adjusted sum 1009.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17347
# voxel sum larger patch 47967
# background adjusted sum 453.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 17128
# voxel sum larger patch 46819
# background adjusted sum 746.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 20778
# voxel sum larger patch 56428
# background adjusted sum 1109.0344827586196
# area_small 128
# area_large 360
# voxel sum small patch 19676
# voxel sum larger patch 53911
# background adjusted sum 787.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 17278
# voxel sum larger patch 48382
# background adjusted sum 117.17241379310508
# area_small 128
# area_large 360
# voxel sum small patch 17400
# voxel sum larger patch 47505
# background adjusted sum 790.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 16560
# voxel sum larger patch 45880
# background adjusted sum 383.44827586206884
# area_small 128
# area_large 360
# voxel sum small patch 17905
# voxel sum larger patch 49129
# background adjusted sum 677.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 16248
# voxel sum larger patch 44898
# background adjusted sum 441.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17212
# voxel sum larger patch 47204
# background adjusted sum 664.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 16857
# voxel sum larger patch 45980
# background adjusted sum 789.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 16857
# voxel sum larger patch 47476
# background adjusted sum -36.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 18241
# voxel sum larger patch 50732
# background adjusted sum 314.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 17024
# voxel sum larger patch 46138
# background adjusted sum 961.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 18460
# voxel sum larger patch 49850
# background adjusted sum 1141.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 18588
# voxel sum larger patch 51879
# background adjusted sum 220.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18905
# voxel sum larger patch 51031
# background adjusted sum 1180.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 17919
# voxel sum larger patch 49050
# background adjusted sum 743.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 17401
# voxel sum larger patch 46838
# background adjusted sum 1159.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 21854
# voxel sum larger patch 57622
# background adjusted sum 2119.931034482757
# area_small 128
# area_large 360
# voxel sum small patch 17584
# voxel sum larger patch 48858
# background adjusted sum 329.3793103448261
# area_small 128
# area_large 360
# voxel sum small patch 18341
# voxel sum larger patch 50498
# background adjusted sum 599.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 20122
# voxel sum larger patch 56364
# background adjusted sum 126.41379310344928
# area_small 128
# area_large 360
# voxel sum small patch 19250
# voxel sum larger patch 53284
# background adjusted sum 472.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 17857
# voxel sum larger patch 47957
# background adjusted sum 1250.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17959
# voxel sum larger patch 48551
# background adjusted sum 1080.6551724137935
# area_small 128
# area_large 348
# voxel sum small patch 19015
# voxel sum larger patch 50198
# background adjusted sum 872.1636363636353
# area_small 128
# area_large 348
# voxel sum small patch 18014
# voxel sum larger patch 47997
# background adjusted sum 569.3454545454551
# area_small 124
# area_large 330
# voxel sum small patch 17773
# voxel sum larger patch 46870
# background adjusted sum 258.3009708737876
# area_small 128
# area_large 342
# voxel sum small patch 17586
# voxel sum larger patch 46018
# background adjusted sum 579.9439252336451
# area_small 96
# area_large 252
# voxel sum small patch 15718
# voxel sum larger patch 41962
# background adjusted sum -432.15384615384573
# area_small 96
# area_large 252
# voxel sum small patch 13910
# voxel sum larger patch 36561
# background adjusted sum -29.076923076923777
# area_small 112
# area_large 288
# voxel sum small patch 17563
# voxel sum larger patch 42024
# background adjusted sum 1996.9090909090928
# area_small 112
# area_large 288
# voxel sum small patch 16486
# voxel sum larger patch 40709
# background adjusted sum 1071.363636363637
# area_small 112
# area_large 288
# voxel sum small patch 16824
# voxel sum larger patch 42817
# background adjusted sum 283.0
# area_small 120
# area_large 306
# voxel sum small patch 14769
# voxel sum larger patch 37528
# background adjusted sum 85.77419354838719
# area_small 128
# area_large 360
# voxel sum small patch 17643
# voxel sum larger patch 48062
# background adjusted sum 860.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 20268
# voxel sum larger patch 52864
# background adjusted sum 2284.0
# area_small 128
# area_large 360
# voxel sum small patch 17593
# voxel sum larger patch 49570
# background adjusted sum -49.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 16788
# voxel sum larger patch 46106
# background adjusted sum 612.5517241379312
# area_small 128
# area_large 360
# voxel sum small patch 19938
# voxel sum larger patch 55611
# background adjusted sum 256.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 17005
# voxel sum larger patch 46153
# background adjusted sum 923.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 17633
# voxel sum larger patch 46760
# background adjusted sum 1562.9310344827593
# area_small 128
# area_large 360
# voxel sum small patch 17984
# voxel sum larger patch 48686
# background adjusted sum 1044.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 17248
# voxel sum larger patch 48029
# background adjusted sum 265.3793103448261
# area_small 128
# area_large 360
# voxel sum small patch 18039
# voxel sum larger patch 49648
# background adjusted sum 599.5517241379312
# area_small 128
# area_large 360
# voxel sum small patch 16735
# voxel sum larger patch 46513
# background adjusted sum 305.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18776
# voxel sum larger patch 52670
# background adjusted sum 75.86206896551812
# area_small 128
# area_large 360
# voxel sum small patch 17997
# voxel sum larger patch 48699
# background adjusted sum 1057.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 18188
# voxel sum larger patch 49869
# background adjusted sum 708.8275862068949
# area_small 128
# area_large 360
# voxel sum small patch 18877
# voxel sum larger patch 52638
# background adjusted sum 250.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 19352
# voxel sum larger patch 51506
# background adjusted sum 1611.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 16817
# voxel sum larger patch 46313
# background adjusted sum 543.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 16879
# voxel sum larger patch 46863
# background adjusted sum 336.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17927
# voxel sum larger patch 48561
# background adjusted sum 1025.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 17292
# voxel sum larger patch 48061
# background adjusted sum 316.0
# area_small 128
# area_large 360
# voxel sum small patch 17190
# voxel sum larger patch 47571
# background adjusted sum 428.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 16666
# voxel sum larger patch 45235
# background adjusted sum 903.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 17262
# voxel sum larger patch 48030
# background adjusted sum 286.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 15981
# voxel sum larger patch 44685
# background adjusted sum 144.31034482758696
# area_small 128
# area_large 360
# voxel sum small patch 16519
# voxel sum larger patch 45473
# background adjusted sum 544.3793103448279
# area_small 128
# area_large 360
# voxel sum small patch 17933
# voxel sum larger patch 48832
# background adjusted sum 885.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 16445
# voxel sum larger patch 45593
# background adjusted sum 363.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 18626
# voxel sum larger patch 51668
# background adjusted sum 395.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 16898
# voxel sum larger patch 46631
# background adjusted sum 493.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 22899
# voxel sum larger patch 61674
# background adjusted sum 1505.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 23106
# voxel sum larger patch 61244
# background adjusted sum 2064.344827586206
# area_small 128
# area_large 360
# voxel sum small patch 20301
# voxel sum larger patch 55684
# background adjusted sum 779.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 17623
# voxel sum larger patch 48512
# background adjusted sum 580.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18327
# voxel sum larger patch 51255
# background adjusted sum 159.82758620689492
# area_small 128
# area_large 360
# voxel sum small patch 17966
# voxel sum larger patch 47951
# background adjusted sum 1422.5517241379312
# area_small 128
# area_large 360
# voxel sum small patch 21053
# voxel sum larger patch 57584
# background adjusted sum 897.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 19091
# voxel sum larger patch 50534
# background adjusted sum 1743.1379310344817
# area_small 128
# area_large 360
# voxel sum small patch 17306
# voxel sum larger patch 47543
# background adjusted sum 623.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 20689
# voxel sum larger patch 54967
# background adjusted sum 1777.0
# area_small 128
# area_large 360
# voxel sum small patch 17948
# voxel sum larger patch 48464
# background adjusted sum 1111.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 17849
# voxel sum larger patch 49341
# background adjusted sum 474.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 19270
# voxel sum larger patch 53483
# background adjusted sum 393.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 17554
# voxel sum larger patch 47187
# background adjusted sum 1204.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 19277
# voxel sum larger patch 52854
# background adjusted sum 751.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18531
# voxel sum larger patch 49721
# background adjusted sum 1322.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 16748
# voxel sum larger patch 46284
# background adjusted sum 452.27586206896547
# area_small 128
# area_large 360
# voxel sum small patch 18278
# voxel sum larger patch 49587
# background adjusted sum 1004.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 17416
# voxel sum larger patch 47648
# background adjusted sum 736.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 16427
# voxel sum larger patch 46288
# background adjusted sum -48.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 19384
# voxel sum larger patch 52340
# background adjusted sum 1201.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 17265
# voxel sum larger patch 47707
# background adjusted sum 469.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 20672
# voxel sum larger patch 55593
# background adjusted sum 1405.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 18092
# voxel sum larger patch 49245
# background adjusted sum 904.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 17565
# voxel sum larger patch 48981
# background adjusted sum 232.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 19081
# voxel sum larger patch 52022
# background adjusted sum 906.6551724137935
# area_small 128
# area_large 360
# voxel sum small patch 19570
# voxel sum larger patch 53089
# background adjusted sum 1076.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18821
# voxel sum larger patch 52451
# background adjusted sum 266.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 16741
# voxel sum larger patch 46494
# background adjusted sum 325.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18879
# voxel sum larger patch 52022
# background adjusted sum 593.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 20093
# voxel sum larger patch 54676
# background adjusted sum 1012.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 19846
# voxel sum larger patch 52235
# background adjusted sum 1976.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 18036
# voxel sum larger patch 48184
# background adjusted sum 1402.620689655174
# area_small 128
# area_large 342
# voxel sum small patch 18872
# voxel sum larger patch 49438
# background adjusted sum 589.5327102803749
# area_small 128
# area_large 342
# voxel sum small patch 16640
# voxel sum larger patch 43487
# background adjusted sum 581.9813084112157
# area_small 104
# area_large 270
# voxel sum small patch 14738
# voxel sum larger patch 38029
# background adjusted sum 146.0481927710846
# area_small 104
# area_large 270
# voxel sum small patch 15784
# voxel sum larger patch 39054
# background adjusted sum 1205.204819277109
# area_small 96
# area_large 246
# voxel sum small patch 16055
# voxel sum larger patch 41622
# background adjusted sum -307.8799999999992
# area_small 112
# area_large 294
# voxel sum small patch 16053
# voxel sum larger patch 41364
# background adjusted sum 476.99999999999864
# area_small 112
# area_large 294
# voxel sum small patch 14911
# voxel sum larger patch 38080
# background adjusted sum 653.1538461538469
# area_small 112
# area_large 294
# voxel sum small patch 15743
# voxel sum larger patch 40624
# background adjusted sum 431.6153846153843
# area_small 124
# area_large 318
# voxel sum small patch 16817
# voxel sum larger patch 42159
# background adjusted sum 619.0206185567026
# area_small 124
# area_large 318
# voxel sum small patch 16481
# voxel sum larger patch 41582
# background adjusted sum 437.0618556701045
# area_small 128
# area_large 348
# voxel sum small patch 17145
# voxel sum larger patch 45455
# background adjusted sum 673.7272727272721
# area_small 128
# area_large 348
# voxel sum small patch 16572
# voxel sum larger patch 43532
# background adjusted sum 886.1818181818179
# area_small 128
# area_large 336
# voxel sum small patch 20060
# voxel sum larger patch 49377
# background adjusted sum 2018.7692307692305
# area_small 128
# area_large 342
# voxel sum small patch 20521
# voxel sum larger patch 52938
# background adjusted sum 1131.3925233644877
# area_small 128
# area_large 354
# voxel sum small patch 18210
# voxel sum larger patch 49519
# background adjusted sum 477.46902654867154
# area_small 128
# area_large 354
# voxel sum small patch 23081
# voxel sum larger patch 57920
# background adjusted sum 3349.1769911504407
# area_small 128
# area_large 360
# voxel sum small patch 18307
# voxel sum larger patch 48550
# background adjusted sum 1621.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 15197
# voxel sum larger patch 42365
# background adjusted sum 207.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18571
# voxel sum larger patch 51158
# background adjusted sum 591.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 16793
# voxel sum larger patch 46314
# background adjusted sum 505.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 17744
# voxel sum larger patch 48837
# background adjusted sum 589.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 19331
# voxel sum larger patch 54501
# background adjusted sum -73.13793103448188
# area_small 128
# area_large 360
# voxel sum small patch 18311
# voxel sum larger patch 51180
# background adjusted sum 176.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 16539
# voxel sum larger patch 45721
# background adjusted sum 438.58620689655254
# area_small 128
# area_large 360
# voxel sum small patch 18185
# voxel sum larger patch 49126
# background adjusted sum 1114.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 18425
# voxel sum larger patch 47854
# background adjusted sum 2188.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 17709
# voxel sum larger patch 49838
# background adjusted sum -17.34482758620652
# area_small 128
# area_large 360
# voxel sum small patch 23919
# voxel sum larger patch 60441
# background adjusted sum 3768.9310344827563
# area_small 128
# area_large 360
# voxel sum small patch 19523
# voxel sum larger patch 53117
# background adjusted sum 988.3793103448261
# area_small 128
# area_large 360
# voxel sum small patch 18606
# voxel sum larger patch 49989
# background adjusted sum 1291.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 17999
# voxel sum larger patch 48009
# background adjusted sum 1441.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16733
# voxel sum larger patch 46087
# background adjusted sum 537.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 16806
# voxel sum larger patch 45623
# background adjusted sum 906.9655172413785
# area_small 128
# area_large 360
# voxel sum small patch 20392
# voxel sum larger patch 55145
# background adjusted sum 1217.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 17443
# voxel sum larger patch 47004
# background adjusted sum 1133.48275862069
# area_small 128
# area_large 360
# voxel sum small patch 16443
# voxel sum larger patch 45853
# background adjusted sum 216.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 18231
# voxel sum larger patch 49659
# background adjusted sum 891.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17848
# voxel sum larger patch 49404
# background adjusted sum 437.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 16631
# voxel sum larger patch 46484
# background adjusted sum 160.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 17675
# voxel sum larger patch 48683
# background adjusted sum 567.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 19201
# voxel sum larger patch 54237
# background adjusted sum -129.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 19507
# voxel sum larger patch 52006
# background adjusted sum 1576.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18359
# voxel sum larger patch 51605
# background adjusted sum 16.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 26868
# voxel sum larger patch 70664
# background adjusted sum 2704.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 18010
# voxel sum larger patch 47734
# background adjusted sum 1610.5517241379307
# area_small 128
# area_large 360
# voxel sum small patch 19797
# voxel sum larger patch 51977
# background adjusted sum 2042.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18338
# voxel sum larger patch 49398
# background adjusted sum 1201.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 17843
# voxel sum larger patch 49458
# background adjusted sum 400.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 16261
# voxel sum larger patch 45345
# background adjusted sum 214.65517241379348
# area_small 128
# area_large 360
# voxel sum small patch 16533
# voxel sum larger patch 46055
# background adjusted sum 245.0
# area_small 128
# area_large 360
# voxel sum small patch 18275
# voxel sum larger patch 50409
# background adjusted sum 545.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 18409
# voxel sum larger patch 50799
# background adjusted sum 538.6551724137935
# area_small 128
# area_large 360
# voxel sum small patch 16595
# voxel sum larger patch 45726
# background adjusted sum 522.7241379310344
# area_small 128
# area_large 360
# voxel sum small patch 18021
# voxel sum larger patch 50229
# background adjusted sum 251.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 21271
# voxel sum larger patch 56548
# background adjusted sum 1807.827586206895
# area_small 128
# area_large 360
# voxel sum small patch 16997
# voxel sum larger patch 46761
# background adjusted sum 575.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 20063
# voxel sum larger patch 53022
# background adjusted sum 1878.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 17445
# voxel sum larger patch 48062
# background adjusted sum 552.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 17566
# voxel sum larger patch 47450
# background adjusted sum 1078.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 20845
# voxel sum larger patch 54374
# background adjusted sum 2346.2413793103447
# area_small 128
# area_large 360
# voxel sum small patch 19039
# voxel sum larger patch 50768
# background adjusted sum 1533.3448275862063
# area_small 128
# area_large 360
# voxel sum small patch 21918
# voxel sum larger patch 55639
# background adjusted sum 3313.3103448275874
# area_small 128
# area_large 360
# voxel sum small patch 18470
# voxel sum larger patch 49619
# background adjusted sum 1284.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 17484
# voxel sum larger patch 48031
# background adjusted sum 630.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 18015
# voxel sum larger patch 49252
# background adjusted sum 780.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18725
# voxel sum larger patch 50121
# background adjusted sum 1403.068965517243
# area_small 128
# area_large 360
# voxel sum small patch 18489
# voxel sum larger patch 49536
# background adjusted sum 1359.620689655174
# area_small 128
# area_large 360
# voxel sum small patch 18347
# voxel sum larger patch 49796
# background adjusted sum 995.827586206895
# area_small 128
# area_large 360
# voxel sum small patch 16692
# voxel sum larger patch 46583
# background adjusted sum 200.41379310344928
# area_small 128
# area_large 360
# voxel sum small patch 18708
# voxel sum larger patch 51208
# background adjusted sum 776.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 25472
# voxel sum larger patch 66492
# background adjusted sum 2840.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 21019
# voxel sum larger patch 55703
# background adjusted sum 1883.0
# area_small 128
# area_large 360
# voxel sum small patch 17860
# voxel sum larger patch 48536
# background adjusted sum 935.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 18649
# voxel sum larger patch 50994
# background adjusted sum 803.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 16555
# voxel sum larger patch 45627
# background adjusted sum 515.2758620689656
# area_small 128
# area_large 360
# voxel sum small patch 21416
# voxel sum larger patch 58630
# background adjusted sum 884.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 15886
# voxel sum larger patch 44817
# background adjusted sum -75.93103448275906
# area_small 128
# area_large 360
# voxel sum small patch 19332
# voxel sum larger patch 52551
# background adjusted sum 1004.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 21226
# voxel sum larger patch 56163
# background adjusted sum 1950.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 20668
# voxel sum larger patch 56542
# background adjusted sum 875.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 18778
# voxel sum larger patch 50059
# background adjusted sum 1519.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 16587
# voxel sum larger patch 45512
# background adjusted sum 628.3793103448279
# area_small 128
# area_large 360
# voxel sum small patch 17584
# voxel sum larger patch 48484
# background adjusted sum 535.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 22278
# voxel sum larger patch 60476
# background adjusted sum 1203.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 21182
# voxel sum larger patch 56519
# background adjusted sum 1685.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 17436
# voxel sum larger patch 47541
# background adjusted sum 826.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 20089
# voxel sum larger patch 51887
# background adjusted sum 2545.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 19145
# voxel sum larger patch 52454
# background adjusted sum 767.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 18541
# voxel sum larger patch 50250
# background adjusted sum 1046.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 23153
# voxel sum larger patch 63456
# background adjusted sum 916.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 16769
# voxel sum larger patch 47009
# background adjusted sum 84.86206896551812
# area_small 128
# area_large 360
# voxel sum small patch 19774
# voxel sum larger patch 52612
# background adjusted sum 1656.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 20359
# voxel sum larger patch 54381
# background adjusted sum 1588.2413793103444
# area_small 128
# area_large 360
# voxel sum small patch 23192
# voxel sum larger patch 60507
# background adjusted sum 2604.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18477
# voxel sum larger patch 49792
# background adjusted sum 1199.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 19919
# voxel sum larger patch 54157
# background adjusted sum 1029.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 18819
# voxel sum larger patch 51813
# background adjusted sum 615.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17630
# voxel sum larger patch 49630
# background adjusted sum -25.17241379310508
# area_small 124
# area_large 324
# voxel sum small patch 18398
# voxel sum larger patch 46579
# background adjusted sum 925.7800000000001
# area_small 120
# area_large 306
# voxel sum small patch 23025
# voxel sum larger patch 56804
# background adjusted sum 1232.0967741935501
# area_small 92
# area_large 240
# voxel sum small patch 16709
# voxel sum larger patch 41708
# background adjusted sum 1169.0810810810815
# area_small 100
# area_large 264
# voxel sum small patch 14597
# voxel sum larger patch 36764
# background adjusted sum 1080.5365853658545
# area_small 92
# area_large 240
# voxel sum small patch 13756
# voxel sum larger patch 34893
# background adjusted sum 616.7837837837826
# area_small 92
# area_large 240
# voxel sum small patch 15249
# voxel sum larger patch 39064
# background adjusted sum 445.08108108108104
# area_small 92
# area_large 240
# voxel sum small patch 12753
# voxel sum larger patch 32099
# background adjusted sum 727.1081081081072
# area_small 116
# area_large 300
# voxel sum small patch 17935
# voxel sum larger patch 43709
# background adjusted sum 1686.1739130434771
# area_small 116
# area_large 300
# voxel sum small patch 15121
# voxel sum larger patch 37789
# background adjusted sum 830.3043478260868
# area_small 116
# area_large 300
# voxel sum small patch 15685
# voxel sum larger patch 39718
# background adjusted sum 533.7608695652189
# area_small 128
# area_large 342
# voxel sum small patch 17951
# voxel sum larger patch 46446
# background adjusted sum 907.2616822429918
# area_small 128
# area_large 342
# voxel sum small patch 23458
# voxel sum larger patch 58007
# background adjusted sum 2793.177570093459
# area_small 128
# area_large 360
# voxel sum small patch 16393
# voxel sum larger patch 45693
# background adjusted sum 227.48275862069016
# area_small 128
# area_large 360
# voxel sum small patch 17778
# voxel sum larger patch 46942
# background adjusted sum 1687.51724137931
# area_small 128
# area_large 360
# voxel sum small patch 21244
# voxel sum larger patch 56939
# background adjusted sum 1550.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 17714
# voxel sum larger patch 48013
# background adjusted sum 997.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 17932
# voxel sum larger patch 48889
# background adjusted sum 852.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 16866
# voxel sum larger patch 45737
# background adjusted sum 937.172413793103
# area_small 128
# area_large 360
# voxel sum small patch 20332
# voxel sum larger patch 56410
# background adjusted sum 426.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 19773
# voxel sum larger patch 52869
# background adjusted sum 1513.1379310344817
# area_small 128
# area_large 360
# voxel sum small patch 18501
# voxel sum larger patch 49416
# background adjusted sum 1444.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 22005
# voxel sum larger patch 57338
# background adjusted sum 2510.9310344827563
# area_small 128
# area_large 360
# voxel sum small patch 22124
# voxel sum larger patch 58674
# background adjusted sum 1958.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 16627
# voxel sum larger patch 46426
# background adjusted sum 186.17241379310508
# area_small 128
# area_large 360
# voxel sum small patch 19814
# voxel sum larger patch 52858
# background adjusted sum 1582.827586206895
# area_small 128
# area_large 360
# voxel sum small patch 20526
# voxel sum larger patch 55371
# background adjusted sum 1301.172413793105
# area_small 128
# area_large 360
# voxel sum small patch 18049
# voxel sum larger patch 49332
# background adjusted sum 789.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18978
# voxel sum larger patch 50230
# background adjusted sum 1735.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 19068
# voxel sum larger patch 50321
# background adjusted sum 1824.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 16348
# voxel sum larger patch 45068
# background adjusted sum 502.48275862069016
# area_small 128
# area_large 360
# voxel sum small patch 19233
# voxel sum larger patch 52996
# background adjusted sum 605.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 19612
# voxel sum larger patch 53807
# background adjusted sum 745.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 15867
# voxel sum larger patch 44277
# background adjusted sum 192.51724137930984
# area_small 128
# area_large 360
# voxel sum small patch 18698
# voxel sum larger patch 51902
# background adjusted sum 378.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18375
# voxel sum larger patch 51104
# background adjusted sum 317.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 21991
# voxel sum larger patch 58001
# background adjusted sum 2123.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17788
# voxel sum larger patch 48772
# background adjusted sum 693.3793103448261
# area_small 128
# area_large 360
# voxel sum small patch 20309
# voxel sum larger patch 54002
# background adjusted sum 1719.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18408
# voxel sum larger patch 50340
# background adjusted sum 790.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 19168
# voxel sum larger patch 52097
# background adjusted sum 1000.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 21148
# voxel sum larger patch 57193
# background adjusted sum 1261.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 19635
# voxel sum larger patch 54251
# background adjusted sum 536.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 17076
# voxel sum larger patch 47334
# background adjusted sum 381.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 19190
# voxel sum larger patch 51634
# background adjusted sum 1289.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 23801
# voxel sum larger patch 61045
# background adjusted sum 3252.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 19417
# voxel sum larger patch 52160
# background adjusted sum 1351.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 18140
# voxel sum larger patch 48598
# background adjusted sum 1335.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 16277
# voxel sum larger patch 45287
# background adjusted sum 271.4827586206902
# area_small 128
# area_large 360
# voxel sum small patch 21915
# voxel sum larger patch 60505
# background adjusted sum 623.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 18873
# voxel sum larger patch 52695
# background adjusted sum 212.58620689655072
# area_small 128
# area_large 360
# voxel sum small patch 21723
# voxel sum larger patch 57948
# background adjusted sum 1736.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 16877
# voxel sum larger patch 46530
# background adjusted sum 516.7241379310344
# area_small 128
# area_large 360
# voxel sum small patch 19000
# voxel sum larger patch 51090
# background adjusted sum 1295.172413793105
# area_small 128
# area_large 360
# voxel sum small patch 17818
# voxel sum larger patch 48690
# background adjusted sum 785.1724137931051
# area_small 128
# area_large 360
# voxel sum small patch 24023
# voxel sum larger patch 65462
# background adjusted sum 1160.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17652
# voxel sum larger patch 48338
# background adjusted sum 721.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18371
# voxel sum larger patch 51049
# background adjusted sum 341.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18971
# voxel sum larger patch 51702
# background adjusted sum 912.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 19346
# voxel sum larger patch 52954
# background adjusted sum 803.6551724137935
# area_small 128
# area_large 360
# voxel sum small patch 18278
# voxel sum larger patch 50131
# background adjusted sum 703.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 17523
# voxel sum larger patch 47775
# background adjusted sum 832.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 17130
# voxel sum larger patch 48018
# background adjusted sum 88.34482758620652
# area_small 128
# area_large 360
# voxel sum small patch 19638
# voxel sum larger patch 52415
# background adjusted sum 1554.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 17355
# voxel sum larger patch 46116
# background adjusted sum 1486.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 18964
# voxel sum larger patch 51811
# background adjusted sum 841.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 17380
# voxel sum larger patch 47141
# background adjusted sum 960.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 19222
# voxel sum larger patch 51459
# background adjusted sum 1436.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 19260
# voxel sum larger patch 51976
# background adjusted sum 1209.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 19277
# voxel sum larger patch 51718
# background adjusted sum 1378.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 20752
# voxel sum larger patch 56059
# background adjusted sum 1272.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 17491
# voxel sum larger patch 46510
# background adjusted sum 1480.5172413793102
# area_small 128
# area_large 360
# voxel sum small patch 16613
# voxel sum larger patch 46982
# background adjusted sum -142.31034482758696
# area_small 128
# area_large 360
# voxel sum small patch 18251
# voxel sum larger patch 48974
# background adjusted sum 1300.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 19337
# voxel sum larger patch 52477
# background adjusted sum 1052.8620689655183
# area_small 128
# area_large 360
# voxel sum small patch 21511
# voxel sum larger patch 57639
# background adjusted sum 1578.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 18711
# voxel sum larger patch 49552
# background adjusted sum 1695.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 24160
# voxel sum larger patch 63714
# background adjusted sum 2337.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17843
# voxel sum larger patch 49921
# background adjusted sum 144.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 19906
# voxel sum larger patch 52994
# background adjusted sum 1650.551724137931
# area_small 128
# area_large 360
# voxel sum small patch 24289
# voxel sum larger patch 61728
# background adjusted sum 3633.0
# area_small 128
# area_large 360
# voxel sum small patch 22304
# voxel sum larger patch 58085
# background adjusted sum 2562.7586206896553
# area_small 128
# area_large 360
# voxel sum small patch 23672
# voxel sum larger patch 63705
# background adjusted sum 1584.827586206895
# area_small 128
# area_large 360
# voxel sum small patch 24801
# voxel sum larger patch 66147
# background adjusted sum 1989.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 19121
# voxel sum larger patch 52350
# background adjusted sum 787.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16731
# voxel sum larger patch 46419
# background adjusted sum 351.4137931034475
# area_small 128
# area_large 360
# voxel sum small patch 18423
# voxel sum larger patch 50053
# background adjusted sum 971.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 19905
# voxel sum larger patch 53568
# background adjusted sum 1332.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 18956
# voxel sum larger patch 51547
# ...
# area_small 128
# area_large 360
# voxel sum small patch 18747
# voxel sum larger patch 52679
# background adjusted sum 25.89655172413768
# area_small 128
# area_large 360
# voxel sum small patch 17702
# voxel sum larger patch 48009
# background adjusted sum 980.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 19722
# voxel sum larger patch 54882
# background adjusted sum 323.3793103448261
# area_small 96
# area_large 258
# voxel sum small patch 14308
# voxel sum larger patch 37501
# background adjusted sum 564.0000000000009
# area_small 88
# area_large 234
# voxel sum small patch 11768
# voxel sum larger patch 29666
# background adjusted sum 980.164383561644
# area_small 128
# area_large 360
# voxel sum small patch 15764
# voxel sum larger patch 43803
# background adjusted sum 294.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 22357
# voxel sum larger patch 60075
# background adjusted sum 1547.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 17253
# voxel sum larger patch 48193
# background adjusted sum 182.65517241379348
# area_small 128
# area_large 360
# voxel sum small patch 25994
# voxel sum larger patch 68448
# background adjusted sum 2571.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 24067
# voxel sum larger patch 66383
# background adjusted sum 720.2413793103444
# area_small 128
# area_large 360
# voxel sum small patch 21364
# voxel sum larger patch 57367
# background adjusted sum 1500.2758620689635
# area_small 128
# area_large 360
# voxel sum small patch 20006
# voxel sum larger patch 53976
# background adjusted sum 1263.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 17392
# voxel sum larger patch 48936
# background adjusted sum -11.58620689655072
# area_small 128
# area_large 360
# voxel sum small patch 19841
# voxel sum larger patch 53766
# background adjusted sum 1123.7586206896553
# area_small 128
# area_large 360
# voxel sum small patch 35472
# voxel sum larger patch 93281
# background adjusted sum 3577.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 24154
# voxel sum larger patch 65560
# background adjusted sum 1309.3103448275872
# area_small 128
# area_large 360
# voxel sum small patch 24656
# voxel sum larger patch 65489
# background adjusted sum 2127.4482758620697
# area_small 128
# area_large 360
# voxel sum small patch 19182
# voxel sum larger patch 52952
# background adjusted sum 550.2758620689638
# area_small 128
# area_large 360
# voxel sum small patch 19753
# voxel sum larger patch 53852
# background adjusted sum 939.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18430
# voxel sum larger patch 50741
# background adjusted sum 603.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 18208
# voxel sum larger patch 50507
# background adjusted sum 387.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 18470
# voxel sum larger patch 50625
# background adjusted sum 729.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 19333
# voxel sum larger patch 52631
# background adjusted sum 961.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 20134
# voxel sum larger patch 56065
# background adjusted sum 310.0
# area_small 128
# area_large 360
# voxel sum small patch 21521
# voxel sum larger patch 58787
# background adjusted sum 960.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 22520
# voxel sum larger patch 61500
# background adjusted sum 1013.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18717
# voxel sum larger patch 51748
# background adjusted sum 493.0
# area_small 124
# area_large 318
# voxel sum small patch 17888
# voxel sum larger patch 44734
# background adjusted sum 728.7010309278364
# area_small 116
# area_large 300
# voxel sum small patch 16747
# voxel sum larger patch 42166
# background adjusted sum 721.9782608695655
# area_small 96
# area_large 252
# voxel sum small patch 13172
# voxel sum larger patch 32301
# background adjusted sum 1400.3076923076924
# area_small 88
# area_large 234
# voxel sum small patch 12113
# voxel sum larger patch 30214
# background adjusted sum 1202.8082191780818
# area_small 128
# area_large 348
# voxel sum small patch 29054
# voxel sum larger patch 75910
# background adjusted sum 1792.3272727272733
# area_small 120
# area_large 306
# voxel sum small patch 16346
# voxel sum larger patch 40857
# background adjusted sum 532.4516129032256
# area_small 124
# area_large 324
# voxel sum small patch 19981
# voxel sum larger patch 52038
# background adjusted sum 105.66000000000042
# area_small 128
# area_large 360
# voxel sum small patch 21581
# voxel sum larger patch 58450
# background adjusted sum 1239.4827586206889
# area_small 128
# area_large 360
# voxel sum small patch 17985
# voxel sum larger patch 49746
# background adjusted sum 461.68965517241304
# area_small 128
# area_large 360
# voxel sum small patch 24523
# voxel sum larger patch 67705
# background adjusted sum 698.448275862069
# area_small 128
# area_large 360
# voxel sum small patch 21808
# voxel sum larger patch 60374
# background adjusted sum 530.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 18462
# voxel sum larger patch 50556
# background adjusted sum 754.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 31137
# voxel sum larger patch 86810
# background adjusted sum 420.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 18138
# voxel sum larger patch 50703
# background adjusted sum 171.10344827586232
# area_small 128
# area_large 360
# voxel sum small patch 19949
# voxel sum larger patch 55627
# background adjusted sum 264.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 20272
# voxel sum larger patch 54939
# background adjusted sum 1145.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 24255
# voxel sum larger patch 66164
# background adjusted sum 1132.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 15823
# voxel sum larger patch 44240
# background adjusted sum 144.65517241379348
# area_small 128
# area_large 360
# voxel sum small patch 23606
# voxel sum larger patch 60628
# background adjusted sum 3180.0689655172446
# area_small 128
# area_large 360
# voxel sum small patch 19211
# voxel sum larger patch 51253
# background adjusted sum 1532.655172413794
# area_small 128
# area_large 360
# voxel sum small patch 22005
# voxel sum larger patch 62105
# background adjusted sum -119.13793103448188
# area_small 128
# area_large 360
# voxel sum small patch 17063
# voxel sum larger patch 47866
# background adjusted sum 68.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 17555
# voxel sum larger patch 48682
# background adjusted sum 381.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 19226
# voxel sum larger patch 52453
# background adjusted sum 893.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 26321
# voxel sum larger patch 69067
# background adjusted sum 2737.0
# area_small 112
# area_large 282
# voxel sum small patch 17181
# voxel sum larger patch 41922
# background adjusted sum 881.0470588235298
# area_small 104
# area_large 270
# voxel sum small patch 18650
# voxel sum larger patch 46953
# background adjusted sum 918.0
# area_small 124
# area_large 330
# voxel sum small patch 19801
# voxel sum larger patch 52354
# background adjusted sum 205.99029126213452
# area_small 124
# area_large 330
# voxel sum small patch 25508
# voxel sum larger patch 65842
# background adjusted sum 1229.2815533980574
# area_small 128
# area_large 324
# voxel sum small patch 16128
# voxel sum larger patch 40733
# background adjusted sum 59.428571428570706
# area_small 128
# area_large 324
# voxel sum small patch 19859
# voxel sum larger patch 48818
# background adjusted sum 947.0
# area_small 128
# area_large 360
# voxel sum small patch 17809
# voxel sum larger patch 49053
# background adjusted sum 570.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 21255
# voxel sum larger patch 59611
# background adjusted sum 93.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 18295
# voxel sum larger patch 50269
# background adjusted sum 654.1724137931051
# area_small 128
# area_large 360
# voxel sum small patch 19555
# voxel sum larger patch 53533
# background adjusted sum 808.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 27674
# voxel sum larger patch 72958
# background adjusted sum 2689.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 24762
# voxel sum larger patch 66334
# background adjusted sum 1825.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 19956
# voxel sum larger patch 55220
# background adjusted sum 500.0
# area_small 128
# area_large 324
# voxel sum small patch 18555
# voxel sum larger patch 47168
# background adjusted sum -131.04081632653106
# area_small 128
# area_large 360
# voxel sum small patch 19636
# voxel sum larger patch 53467
# background adjusted sum 970.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 19772
# voxel sum larger patch 55279
# background adjusted sum 181.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 21265
# voxel sum larger patch 58551
# background adjusted sum 693.4137931034493
# area_small 116
# area_large 300
# voxel sum small patch 15984
# voxel sum larger patch 40082
# background adjusted sum 791.7826086956538
# area_small 76
# area_large 168
# voxel sum small patch 10173
# voxel sum larger patch 21462
# background adjusted sum 847.3043478260865
# area_small 84
# area_large 192
# voxel sum small patch 12153
# voxel sum larger patch 27649
# background adjusted sum 100.5555555555544
# area_small 128
# area_large 360
# voxel sum small patch 23064
# voxel sum larger patch 63737
# background adjusted sum 623.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 16571
# voxel sum larger patch 45796
# background adjusted sum 446.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 23583
# voxel sum larger patch 63471
# background adjusted sum 1575.8275862068954
# area_small 128
# area_large 360
# voxel sum small patch 25676
# voxel sum larger patch 66591
# background adjusted sum 3102.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 17693
# voxel sum larger patch 48051
# background adjusted sum 943.7586206896557
# area_small 128
# area_large 360
# voxel sum small patch 21197
# voxel sum larger patch 60354
# background adjusted sum -406.8620689655181
# area_small 128
# area_large 324
# voxel sum small patch 17278
# voxel sum larger patch 43927
# background adjusted sum -125.42857142857247
# area_small 128
# area_large 360
# voxel sum small patch 18143
# voxel sum larger patch 50255
# background adjusted sum 426.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 20712
# voxel sum larger patch 57011
# background adjusted sum 684.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 23343
# voxel sum larger patch 65377
# background adjusted sum 151.82758620689492
# area_small 128
# area_large 360
# voxel sum small patch 30335
# voxel sum larger patch 80976
# background adjusted sum 2395.137931034481
# area_small 128
# area_large 360
# voxel sum small patch 18668
# voxel sum larger patch 51811
# background adjusted sum 382.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 25153
# voxel sum larger patch 68337
# background adjusted sum 1327.344827586206
# area_small 128
# area_large 360
# voxel sum small patch 25370
# voxel sum larger patch 67476
# background adjusted sum 2139.1034482758614
# area_small 128
# area_large 360
# voxel sum small patch 24252
# voxel sum larger patch 63594
# background adjusted sum 2546.0689655172437
# area_small 128
# area_large 360
# voxel sum small patch 19610
# voxel sum larger patch 53720
# background adjusted sum 790.689655172413
# area_small 128
# area_large 324
# voxel sum small patch 20964
# voxel sum larger patch 51045
# background adjusted sum 1319.2653061224482
# area_small 128
# area_large 360
# voxel sum small patch 17667
# voxel sum larger patch 50000
# background adjusted sum -171.89655172413768
# area_small 128
# area_large 360
# voxel sum small patch 24195
# voxel sum larger patch 67063
# background adjusted sum 543.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 34132
# voxel sum larger patch 94903
# background adjusted sum 603.1724137931014
# area_small 128
# area_large 360
# voxel sum small patch 18849
# voxel sum larger patch 52491
# background adjusted sum 287.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 17375
# voxel sum larger patch 48911
# background adjusted sum -24.17241379310508
# area_small 128
# area_large 360
# voxel sum small patch 19435
# voxel sum larger patch 52452
# background adjusted sum 1218.7241379310362
# area_small 128
# area_large 324
# voxel sum small patch 20202
# voxel sum larger patch 50994
# background adjusted sum 92.93877551020341
# area_small 128
# area_large 360
# voxel sum small patch 23926
# voxel sum larger patch 65222
# background adjusted sum 1142.0
# area_small 128
# area_large 360
# voxel sum small patch 26153
# voxel sum larger patch 71356
# background adjusted sum 1213.4137931034493
# area_small 128
# area_large 324
# voxel sum small patch 18494
# voxel sum larger patch 44893
# background adjusted sum 1253.8367346938758
# area_small 128
# area_large 324
# voxel sum small patch 27256
# voxel sum larger patch 68496
# background adjusted sum 323.75510204081706
# area_small 128
# area_large 324
# voxel sum small patch 18199
# voxel sum larger patch 45635
# background adjusted sum 281.6122448979586
# area_small 128
# area_large 360
# voxel sum small patch 23129
# voxel sum larger patch 62147
# background adjusted sum 1601.8275862068954
# area_small 128
# area_large 360
# voxel sum small patch 23198
# voxel sum larger patch 62792
# background adjusted sum 1353.0344827586198
# area_small 128
# area_large 324
# voxel sum small patch 18207
# voxel sum larger patch 46153
# background adjusted sum -43.448979591838
# area_small 128
# area_large 360
# voxel sum small patch 20131
# voxel sum larger patch 55822
# background adjusted sum 439.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 27482
# voxel sum larger patch 73646
# background adjusted sum 2012.2068965517246
# area_small 128
# area_large 324
# voxel sum small patch 20490
# voxel sum larger patch 49929
# background adjusted sum 1264.5306122448965
# area_small 128
# area_large 324
# voxel sum small patch 25419
# voxel sum larger patch 64403
# background adjusted sum -39.93877551020341
# area_small 128
# area_large 324
# voxel sum small patch 18118
# voxel sum larger patch 45578
# background adjusted sum 184.9387755102034
# area_small 128
# area_large 360
# voxel sum small patch 30859
# voxel sum larger patch 81062
# background adjusted sum 3160.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18090
# voxel sum larger patch 50189
# background adjusted sum 380.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 23366
# voxel sum larger patch 63755
# background adjusted sum 1082.4137931034493
# area_small 128
# area_large 324
# voxel sum small patch 18919
# voxel sum larger patch 46627
# background adjusted sum 823.9795918367345
# area_small 128
# area_large 324
# voxel sum small patch 18900
# voxel sum larger patch 46853
# background adjusted sum 644.9795918367345
# area_small 128
# area_large 324
# voxel sum small patch 19711
# voxel sum larger patch 49855
# background adjusted sum 25.122448979593173
# area_small 128
# area_large 324
# voxel sum small patch 18976
# voxel sum larger patch 47568
# background adjusted sum 303.6734693877552
# area_small 128
# area_large 324
# voxel sum small patch 20984
# voxel sum larger patch 53565
# background adjusted sum -293.3877551020414
# area_small 128
# area_large 324
# voxel sum small patch 21225
# voxel sum larger patch 51793
# background adjusted sum 1262.2244897959172
# area_small 128
# area_large 324
# voxel sum small patch 20185
# voxel sum larger patch 50656
# background adjusted sum 285.57142857142753
# area_small 128
# area_large 324
# voxel sum small patch 19972
# voxel sum larger patch 50682
# background adjusted sum -83.51020408163095
# area_small 128
# area_large 324
# voxel sum small patch 23303
# voxel sum larger patch 58473
# background adjusted sum 334.83673469387577
# area_small 128
# area_large 324
# voxel sum small patch 25036
# voxel sum larger patch 63673
# background adjusted sum -196.32653061224505
# area_small 128
# area_large 324
# voxel sum small patch 21020
# voxel sum larger patch 49909
# background adjusted sum 2153.7142857142862
# area_small 128
# area_large 324
# voxel sum small patch 18586
# voxel sum larger patch 46966
# background adjusted sum 52.12244897959317

# %%
voxel_sum_array, _, adj_voxel_sum_2 = extractor.voxel_sum_fixed_background(center_col_names = ['mu_z', 'mu_y', 'mu_x'], channel = 3)
# Out:
# current frame is 0
# area_small 96
# area_large 252
# voxel sum small patch 12927
# voxel sum larger patch 33821
# background adjusted sum 69.15384615384573
# area_small 112
# area_large 288
# voxel sum small patch 15894
# voxel sum larger patch 41080
# background adjusted sum -133.45454545454595
# area_small 112
# area_large 288
# voxel sum small patch 14697
# voxel sum larger patch 36356
# background adjusted sum 914.0
# area_small 112
# area_large 288
# voxel sum small patch 15905
# voxel sum larger patch 40803
# background adjusted sum 60.81818181818198
# area_small 112
# area_large 288
# voxel sum small patch 14972
# voxel sum larger patch 38479
# background adjusted sum 13.0
# area_small 128
# area_large 324
# voxel sum small patch 17522
# voxel sum larger patch 43952
# background adjusted sum 261.5918367346967
# area_small 112
# area_large 288
# voxel sum small patch 15730
# voxel sum larger patch 40574
# background adjusted sum -79.81818181818198
# area_small 128
# area_large 324
# voxel sum small patch 17743
# voxel sum larger patch 44890
# background adjusted sum 14.346938775510353
# area_small 96
# area_large 246
# voxel sum small patch 14956
# voxel sum larger patch 37811
# background adjusted sum 328.7999999999993
# area_small 100
# area_large 228
# voxel sum small patch 12818
# voxel sum larger patch 29289
# background adjusted sum -49.96875
# area_small 112
# area_large 246
# voxel sum small patch 14946
# voxel sum larger patch 32859
# background adjusted sum -26.059701492536988
# area_small 128
# area_large 360
# voxel sum small patch 16559
# voxel sum larger patch 46322
# background adjusted sum 138.03448275861956
# area_small 92
# area_large 240
# voxel sum small patch 13795
# voxel sum larger patch 36214
# background adjusted sum -141.135135135135
# area_small 120
# area_large 270
# voxel sum small patch 15067
# voxel sum larger patch 34188
# background adjusted sum -229.8000000000011
# area_small 120
# area_large 306
# voxel sum small patch 16339
# voxel sum larger patch 39643
# background adjusted sum 1304.1612903225814
# area_small 128
# area_large 360
# voxel sum small patch 16971
# voxel sum larger patch 47462
# background adjusted sum 148.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 16733
# voxel sum larger patch 46385
# background adjusted sum 373.2758620689656
# area_small 128
# area_large 360
# voxel sum small patch 17374
# voxel sum larger patch 47640
# background adjusted sum 675.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 15995
# voxel sum larger patch 45163
# background adjusted sum -97.68965517241304
# area_small 128
# area_large 360
# voxel sum small patch 15590
# voxel sum larger patch 43935
# background adjusted sum -48.6206896551721
# area_small 128
# area_large 360
# voxel sum small patch 16899
# voxel sum larger patch 46788
# background adjusted sum 408.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 17976
# voxel sum larger patch 49470
# background adjusted sum 600.0
# area_small 128
# area_large 360
# voxel sum small patch 16304
# voxel sum larger patch 46120
# background adjusted sum -146.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 16879
# voxel sum larger patch 46815
# background adjusted sum 362.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 20850
# voxel sum larger patch 56759
# background adjusted sum 1038.1379310344819
# area_small 124
# area_large 318
# voxel sum small patch 17764
# voxel sum larger patch 43809
# background adjusted sum 1116.6804123711336
# area_small 128
# area_large 360
# voxel sum small patch 16690
# voxel sum larger patch 45031
# background adjusted sum 1053.5862068965525
# area_small 128
# area_large 360
# voxel sum small patch 19143
# voxel sum larger patch 53048
# background adjusted sum 436.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 16276
# voxel sum larger patch 45813
# background adjusted sum -20.27586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16923
# voxel sum larger patch 47455
# background adjusted sum 77.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16858
# voxel sum larger patch 46921
# background adjusted sum 271.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 16262
# voxel sum larger patch 46121
# background adjusted sum -211.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 18009
# voxel sum larger patch 50841
# background adjusted sum -105.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 16654
# voxel sum larger patch 45965
# background adjusted sum 482.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17947
# voxel sum larger patch 49197
# background adjusted sum 705.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 17252
# voxel sum larger patch 47094
# background adjusted sum 787.4482758620688
# area_small 128
# area_large 348
# voxel sum small patch 17879
# voxel sum larger patch 47770
# background adjusted sum 487.8727272727265
# area_small 128
# area_large 360
# voxel sum small patch 17238
# voxel sum larger patch 47550
# background adjusted sum 514.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 17898
# voxel sum larger patch 50364
# background adjusted sum -14.275862068963761
# area_small 128
# area_large 360
# voxel sum small patch 16871
# voxel sum larger patch 47252
# background adjusted sum 109.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 19237
# voxel sum larger patch 52591
# background adjusted sum 834.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 15827
# voxel sum larger patch 44453
# background adjusted sum 33.34482758620652
# area_small 128
# area_large 360
# voxel sum small patch 18520
# voxel sum larger patch 51578
# background adjusted sum 281.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 15990
# voxel sum larger patch 44867
# background adjusted sum 57.86206896551812
# area_small 128
# area_large 360
# voxel sum small patch 18936
# voxel sum larger patch 51484
# background adjusted sum 978.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 16869
# voxel sum larger patch 46603
# background adjusted sum 464.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 18422
# voxel sum larger patch 51379
# background adjusted sum 238.82758620689856
# area_small 128
# area_large 360
# voxel sum small patch 18991
# voxel sum larger patch 51997
# background adjusted sum 780.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 17581
# voxel sum larger patch 48445
# background adjusted sum 552.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 21787
# voxel sum larger patch 59452
# background adjusted sum 1006.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 17434
# voxel sum larger patch 48961
# background adjusted sum 39.79310344827536
# area_small 112
# area_large 294
# voxel sum small patch 15717
# voxel sum larger patch 41621
# background adjusted sum -223.92307692307804
# area_small 120
# area_large 306
# voxel sum small patch 15478
# voxel sum larger patch 38714
# background adjusted sum 487.032258064517
# area_small 128
# area_large 360
# voxel sum small patch 17715
# voxel sum larger patch 48284
# background adjusted sum 849.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 16543
# voxel sum larger patch 46000
# background adjusted sum 290.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 17039
# voxel sum larger patch 47133
# background adjusted sum 435.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18106
# voxel sum larger patch 50940
# background adjusted sum -9.31034482758696
# area_small 128
# area_large 360
# voxel sum small patch 18571
# voxel sum larger patch 52215
# background adjusted sum 8.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 17608
# voxel sum larger patch 48811
# background adjusted sum 392.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 16449
# voxel sum larger patch 45828
# background adjusted sum 239.89655172413768
# area_small 128
# area_large 360
# voxel sum small patch 17519
# voxel sum larger patch 48631
# background adjusted sum 353.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16901
# voxel sum larger patch 47102
# background adjusted sum 238.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 17184
# voxel sum larger patch 47977
# background adjusted sum 194.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 17834
# voxel sum larger patch 49407
# background adjusted sum 414.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18222
# voxel sum larger patch 49353
# background adjusted sum 1046.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 17889
# voxel sum larger patch 49193
# background adjusted sum 617.8275862068986
# area_small 128
# area_large 360
# voxel sum small patch 17245
# voxel sum larger patch 47878
# background adjusted sum 344.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 17281
# voxel sum larger patch 48408
# background adjusted sum 107.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 19818
# voxel sum larger patch 52348
# background adjusted sum 1870.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17212
# voxel sum larger patch 48815
# background adjusted sum -224.13793103448188
# area_small 128
# area_large 360
# voxel sum small patch 16814
# voxel sum larger patch 45707
# background adjusted sum 873.0344827586214
# area_small 128
# area_large 360
# voxel sum small patch 17032
# voxel sum larger patch 46723
# background adjusted sum 650.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 23754
# voxel sum larger patch 62696
# background adjusted sum 2268.758620689656
# area_small 120
# area_large 306
# voxel sum small patch 19287
# voxel sum larger patch 48182
# background adjusted sum 645.064516129034
# area_small 112
# area_large 282
# voxel sum small patch 15224
# voxel sum larger patch 37414
# background adjusted sum 604.7058823529405
# area_small 100
# area_large 264
# voxel sum small patch 12267
# voxel sum larger patch 31490
# background adjusted sum 545.6585365853662
# area_small 88
# area_large 234
# voxel sum small patch 15594
# voxel sum larger patch 41170
# background adjusted sum 178.32876712328834
# area_small 112
# area_large 282
# voxel sum small patch 14460
# voxel sum larger patch 35771
# background adjusted sum 419.8117647058825
# area_small 112
# area_large 294
# voxel sum small patch 16584
# voxel sum larger patch 42397
# background adjusted sum 699.076923076922
# area_small 128
# area_large 360
# voxel sum small patch 17985
# voxel sum larger patch 48973
# background adjusted sum 888.1724137931051
# area_small 128
# area_large 360
# voxel sum small patch 14985
# voxel sum larger patch 41492
# background adjusted sum 360.44827586206884
# area_small 128
# area_large 360
# voxel sum small patch 17384
# voxel sum larger patch 47113
# background adjusted sum 981.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 17071
# voxel sum larger patch 46753
# background adjusted sum 694.7241379310344
# area_small 128
# area_large 360
# voxel sum small patch 17673
# voxel sum larger patch 48348
# background adjusted sum 748.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 16819
# voxel sum larger patch 46261
# background adjusted sum 575.1379310344837
# area_small 128
# area_large 360
# voxel sum small patch 17137
# voxel sum larger patch 47014
# background adjusted sum 653.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 18117
# voxel sum larger patch 50905
# background adjusted sum 27.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 17901
# voxel sum larger patch 48517
# background adjusted sum 1009.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17347
# voxel sum larger patch 47967
# background adjusted sum 453.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 17128
# voxel sum larger patch 46819
# background adjusted sum 746.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 20778
# voxel sum larger patch 56428
# background adjusted sum 1109.0344827586196
# area_small 128
# area_large 360
# voxel sum small patch 19676
# voxel sum larger patch 53911
# background adjusted sum 787.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 17278
# voxel sum larger patch 48382
# background adjusted sum 117.17241379310508
# area_small 128
# area_large 360
# voxel sum small patch 17400
# voxel sum larger patch 47505
# background adjusted sum 790.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 16560
# voxel sum larger patch 45880
# background adjusted sum 383.44827586206884
# area_small 128
# area_large 360
# voxel sum small patch 17905
# voxel sum larger patch 49129
# background adjusted sum 677.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 16248
# voxel sum larger patch 44898
# background adjusted sum 441.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17212
# voxel sum larger patch 47204
# background adjusted sum 664.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 16857
# voxel sum larger patch 45980
# background adjusted sum 789.1379310344837
# area_small 128
# area_large 360
# voxel sum small patch 16857
# voxel sum larger patch 47476
# background adjusted sum -36.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 18241
# voxel sum larger patch 50732
# background adjusted sum 314.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 17024
# voxel sum larger patch 46138
# background adjusted sum 961.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 18460
# voxel sum larger patch 49850
# background adjusted sum 1141.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 18588
# voxel sum larger patch 51879
# background adjusted sum 220.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18905
# voxel sum larger patch 51031
# background adjusted sum 1180.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 17919
# voxel sum larger patch 49050
# background adjusted sum 743.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 17401
# voxel sum larger patch 46838
# background adjusted sum 1159.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 21854
# voxel sum larger patch 57622
# background adjusted sum 2119.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 17584
# voxel sum larger patch 48858
# background adjusted sum 329.3793103448261
# area_small 128
# area_large 360
# voxel sum small patch 18341
# voxel sum larger patch 50498
# background adjusted sum 599.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 20122
# voxel sum larger patch 56364
# background adjusted sum 126.41379310344928
# area_small 128
# area_large 360
# voxel sum small patch 19250
# voxel sum larger patch 53284
# background adjusted sum 472.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 17857
# voxel sum larger patch 47957
# background adjusted sum 1250.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17959
# voxel sum larger patch 48551
# background adjusted sum 1080.6551724137935
# area_small 128
# area_large 348
# voxel sum small patch 19015
# voxel sum larger patch 50198
# background adjusted sum 872.163636363639
# area_small 128
# area_large 348
# voxel sum small patch 18014
# voxel sum larger patch 47997
# background adjusted sum 569.3454545454551
# area_small 124
# area_large 330
# voxel sum small patch 17773
# voxel sum larger patch 46870
# background adjusted sum 258.3009708737882
# area_small 128
# area_large 342
# voxel sum small patch 17586
# voxel sum larger patch 46018
# background adjusted sum 579.9439252336451
# area_small 96
# area_large 252
# voxel sum small patch 15718
# voxel sum larger patch 41962
# background adjusted sum -432.15384615384755
# area_small 96
# area_large 252
# voxel sum small patch 13910
# voxel sum larger patch 36561
# background adjusted sum -29.076923076923777
# area_small 112
# area_large 288
# voxel sum small patch 17563
# voxel sum larger patch 42024
# background adjusted sum 1996.909090909092
# area_small 112
# area_large 288
# voxel sum small patch 16486
# voxel sum larger patch 40709
# background adjusted sum 1071.363636363636
# area_small 112
# area_large 288
# voxel sum small patch 16824
# voxel sum larger patch 42817
# background adjusted sum 283.0
# area_small 120
# area_large 306
# voxel sum small patch 14769
# voxel sum larger patch 37528
# background adjusted sum 85.77419354838821
# area_small 128
# area_large 360
# voxel sum small patch 17643
# voxel sum larger patch 48062
# background adjusted sum 860.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 20268
# voxel sum larger patch 52864
# background adjusted sum 2284.0
# area_small 128
# area_large 360
# voxel sum small patch 17593
# voxel sum larger patch 49570
# background adjusted sum -49.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 16788
# voxel sum larger patch 46106
# background adjusted sum 612.5517241379312
# area_small 128
# area_large 360
# voxel sum small patch 19938
# voxel sum larger patch 55611
# background adjusted sum 256.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 17005
# voxel sum larger patch 46153
# background adjusted sum 923.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 17633
# voxel sum larger patch 46760
# background adjusted sum 1562.931034482759
# area_small 128
# area_large 360
# voxel sum small patch 17984
# voxel sum larger patch 48686
# background adjusted sum 1044.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 17248
# voxel sum larger patch 48029
# background adjusted sum 265.3793103448261
# area_small 128
# area_large 360
# voxel sum small patch 18039
# voxel sum larger patch 49648
# background adjusted sum 599.5517241379312
# area_small 128
# area_large 360
# voxel sum small patch 16735
# voxel sum larger patch 46513
# background adjusted sum 305.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18776
# voxel sum larger patch 52670
# background adjusted sum 75.86206896551812
# area_small 128
# area_large 360
# voxel sum small patch 17997
# voxel sum larger patch 48699
# background adjusted sum 1057.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 18188
# voxel sum larger patch 49869
# background adjusted sum 708.8275862068986
# area_small 128
# area_large 360
# voxel sum small patch 18877
# voxel sum larger patch 52638
# background adjusted sum 250.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 19352
# voxel sum larger patch 51506
# background adjusted sum 1611.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 16817
# voxel sum larger patch 46313
# background adjusted sum 543.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 16879
# voxel sum larger patch 46863
# background adjusted sum 336.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17927
# voxel sum larger patch 48561
# background adjusted sum 1025.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 17292
# voxel sum larger patch 48061
# background adjusted sum 316.0
# area_small 128
# area_large 360
# voxel sum small patch 17190
# voxel sum larger patch 47571
# background adjusted sum 428.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 16666
# voxel sum larger patch 45235
# background adjusted sum 903.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 17262
# voxel sum larger patch 48030
# background adjusted sum 286.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 15981
# voxel sum larger patch 44685
# background adjusted sum 144.31034482758696
# area_small 128
# area_large 360
# voxel sum small patch 16519
# voxel sum larger patch 45473
# background adjusted sum 544.3793103448279
# area_small 128
# area_large 360
# voxel sum small patch 17933
# voxel sum larger patch 48832
# background adjusted sum 885.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 16445
# voxel sum larger patch 45593
# background adjusted sum 363.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 18626
# voxel sum larger patch 51668
# background adjusted sum 395.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 16898
# voxel sum larger patch 46631
# background adjusted sum 493.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 22899
# voxel sum larger patch 61674
# background adjusted sum 1505.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 23106
# voxel sum larger patch 61244
# background adjusted sum 2064.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 20301
# voxel sum larger patch 55684
# background adjusted sum 779.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 17623
# voxel sum larger patch 48512
# background adjusted sum 580.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18327
# voxel sum larger patch 51255
# background adjusted sum 159.82758620689856
# area_small 128
# area_large 360
# voxel sum small patch 17966
# voxel sum larger patch 47951
# background adjusted sum 1422.5517241379312
# area_small 128
# area_large 360
# voxel sum small patch 21053
# voxel sum larger patch 57584
# background adjusted sum 897.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 19091
# voxel sum larger patch 50534
# background adjusted sum 1743.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 17306
# voxel sum larger patch 47543
# background adjusted sum 623.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 20689
# voxel sum larger patch 54967
# background adjusted sum 1777.0
# area_small 128
# area_large 360
# voxel sum small patch 17948
# voxel sum larger patch 48464
# background adjusted sum 1111.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 17849
# voxel sum larger patch 49341
# background adjusted sum 474.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 19270
# voxel sum larger patch 53483
# background adjusted sum 393.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 17554
# voxel sum larger patch 47187
# background adjusted sum 1204.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 19277
# voxel sum larger patch 52854
# background adjusted sum 751.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18531
# voxel sum larger patch 49721
# background adjusted sum 1322.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 16748
# voxel sum larger patch 46284
# background adjusted sum 452.2758620689656
# area_small 128
# area_large 360
# voxel sum small patch 18278
# voxel sum larger patch 49587
# background adjusted sum 1004.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 17416
# voxel sum larger patch 47648
# background adjusted sum 736.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 16427
# voxel sum larger patch 46288
# background adjusted sum -48.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 19384
# voxel sum larger patch 52340
# background adjusted sum 1201.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 17265
# voxel sum larger patch 47707
# background adjusted sum 469.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 20672
# voxel sum larger patch 55593
# background adjusted sum 1405.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 18092
# voxel sum larger patch 49245
# background adjusted sum 904.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 17565
# voxel sum larger patch 48981
# background adjusted sum 232.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 19081
# voxel sum larger patch 52022
# background adjusted sum 906.6551724137935
# area_small 128
# area_large 360
# voxel sum small patch 19570
# voxel sum larger patch 53089
# background adjusted sum 1076.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18821
# voxel sum larger patch 52451
# background adjusted sum 266.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 16741
# voxel sum larger patch 46494
# background adjusted sum 325.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18879
# voxel sum larger patch 52022
# background adjusted sum 593.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 20093
# voxel sum larger patch 54676
# background adjusted sum 1012.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 19846
# voxel sum larger patch 52235
# background adjusted sum 1976.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 18036
# voxel sum larger patch 48184
# background adjusted sum 1402.620689655174
# area_small 128
# area_large 342
# voxel sum small patch 18872
# voxel sum larger patch 49438
# background adjusted sum 589.5327102803749
# area_small 128
# area_large 342
# voxel sum small patch 16640
# voxel sum larger patch 43487
# background adjusted sum 581.9813084112157
# area_small 104
# area_large 270
# voxel sum small patch 14738
# voxel sum larger patch 38029
# background adjusted sum 146.04819277108436
# area_small 104
# area_large 270
# voxel sum small patch 15784
# voxel sum larger patch 39054
# background adjusted sum 1205.2048192771072
# area_small 96
# area_large 246
# voxel sum small patch 16055
# voxel sum larger patch 41622
# background adjusted sum -307.880000000001
# area_small 112
# area_large 294
# voxel sum small patch 16053
# voxel sum larger patch 41364
# background adjusted sum 477.0
# area_small 112
# area_large 294
# voxel sum small patch 14911
# voxel sum larger patch 38080
# background adjusted sum 653.1538461538457
# area_small 112
# area_large 294
# voxel sum small patch 15743
# voxel sum larger patch 40624
# background adjusted sum 431.61538461538294
# area_small 124
# area_large 318
# voxel sum small patch 16817
# voxel sum larger patch 42159
# background adjusted sum 619.0206185567022
# area_small 124
# area_large 318
# voxel sum small patch 16481
# voxel sum larger patch 41582
# background adjusted sum 437.0618556701047
# area_small 128
# area_large 348
# voxel sum small patch 17145
# voxel sum larger patch 45455
# background adjusted sum 673.7272727272721
# area_small 128
# area_large 348
# voxel sum small patch 16572
# voxel sum larger patch 43532
# background adjusted sum 886.1818181818198
# area_small 128
# area_large 336
# voxel sum small patch 20060
# voxel sum larger patch 49377
# background adjusted sum 2018.7692307692305
# area_small 128
# area_large 342
# voxel sum small patch 20521
# voxel sum larger patch 52938
# background adjusted sum 1131.3925233644877
# area_small 128
# area_large 354
# voxel sum small patch 18210
# voxel sum larger patch 49519
# background adjusted sum 477.46902654867154
# area_small 128
# area_large 354
# voxel sum small patch 23081
# voxel sum larger patch 57920
# background adjusted sum 3349.1769911504416
# area_small 128
# area_large 360
# voxel sum small patch 18307
# voxel sum larger patch 48550
# background adjusted sum 1621.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 15197
# voxel sum larger patch 42365
# background adjusted sum 207.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18571
# voxel sum larger patch 51158
# background adjusted sum 591.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 16793
# voxel sum larger patch 46314
# background adjusted sum 505.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 17744
# voxel sum larger patch 48837
# background adjusted sum 589.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 19331
# voxel sum larger patch 54501
# background adjusted sum -73.13793103448188
# area_small 128
# area_large 360
# voxel sum small patch 18311
# voxel sum larger patch 51180
# background adjusted sum 176.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 16539
# voxel sum larger patch 45721
# background adjusted sum 438.58620689655254
# area_small 128
# area_large 360
# voxel sum small patch 18185
# voxel sum larger patch 49126
# background adjusted sum 1114.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 18425
# voxel sum larger patch 47854
# background adjusted sum 2188.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 17709
# voxel sum larger patch 49838
# background adjusted sum -17.34482758620652
# area_small 128
# area_large 360
# voxel sum small patch 23919
# voxel sum larger patch 60441
# background adjusted sum 3768.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 19523
# voxel sum larger patch 53117
# background adjusted sum 988.3793103448261
# area_small 128
# area_large 360
# voxel sum small patch 18606
# voxel sum larger patch 49989
# background adjusted sum 1291.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 17999
# voxel sum larger patch 48009
# background adjusted sum 1441.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16733
# voxel sum larger patch 46087
# background adjusted sum 537.6896551724149
# area_small 128
# area_large 360
# voxel sum small patch 16806
# voxel sum larger patch 45623
# background adjusted sum 906.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 20392
# voxel sum larger patch 55145
# background adjusted sum 1217.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 17443
# voxel sum larger patch 47004
# background adjusted sum 1133.4827586206902
# area_small 128
# area_large 360
# voxel sum small patch 16443
# voxel sum larger patch 45853
# background adjusted sum 216.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 18231
# voxel sum larger patch 49659
# background adjusted sum 891.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17848
# voxel sum larger patch 49404
# background adjusted sum 437.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 16631
# voxel sum larger patch 46484
# background adjusted sum 160.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 17675
# voxel sum larger patch 48683
# background adjusted sum 567.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 19201
# voxel sum larger patch 54237
# background adjusted sum -129.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 19507
# voxel sum larger patch 52006
# background adjusted sum 1576.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18359
# voxel sum larger patch 51605
# background adjusted sum 16.37931034482608
# area_small 128
# area_large 360
# voxel sum small patch 26868
# voxel sum larger patch 70664
# background adjusted sum 2704.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 18010
# voxel sum larger patch 47734
# background adjusted sum 1610.5517241379312
# area_small 128
# area_large 360
# voxel sum small patch 19797
# voxel sum larger patch 51977
# background adjusted sum 2042.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18338
# voxel sum larger patch 49398
# background adjusted sum 1201.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 17843
# voxel sum larger patch 49458
# background adjusted sum 400.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 16261
# voxel sum larger patch 45345
# background adjusted sum 214.65517241379348
# area_small 128
# area_large 360
# voxel sum small patch 16533
# voxel sum larger patch 46055
# background adjusted sum 245.0
# area_small 128
# area_large 360
# voxel sum small patch 18275
# voxel sum larger patch 50409
# background adjusted sum 545.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 18409
# voxel sum larger patch 50799
# background adjusted sum 538.6551724137935
# area_small 128
# area_large 360
# voxel sum small patch 16595
# voxel sum larger patch 45726
# background adjusted sum 522.7241379310344
# area_small 128
# area_large 360
# voxel sum small patch 18021
# voxel sum larger patch 50229
# background adjusted sum 251.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 21271
# voxel sum larger patch 56548
# background adjusted sum 1807.8275862068986
# area_small 128
# area_large 360
# voxel sum small patch 16997
# voxel sum larger patch 46761
# background adjusted sum 575.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 20063
# voxel sum larger patch 53022
# background adjusted sum 1878.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 17445
# voxel sum larger patch 48062
# background adjusted sum 552.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 17566
# voxel sum larger patch 47450
# background adjusted sum 1078.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 20845
# voxel sum larger patch 54374
# background adjusted sum 2346.241379310344
# area_small 128
# area_large 360
# voxel sum small patch 19039
# voxel sum larger patch 50768
# background adjusted sum 1533.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 21918
# voxel sum larger patch 55639
# background adjusted sum 3313.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 18470
# voxel sum larger patch 49619
# background adjusted sum 1284.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 17484
# voxel sum larger patch 48031
# background adjusted sum 630.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 18015
# voxel sum larger patch 49252
# background adjusted sum 780.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18725
# voxel sum larger patch 50121
# background adjusted sum 1403.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 18489
# voxel sum larger patch 49536
# background adjusted sum 1359.620689655174
# area_small 128
# area_large 360
# voxel sum small patch 18347
# voxel sum larger patch 49796
# background adjusted sum 995.8275862068986
# area_small 128
# area_large 360
# voxel sum small patch 16692
# voxel sum larger patch 46583
# background adjusted sum 200.41379310344928
# area_small 128
# area_large 360
# voxel sum small patch 18708
# voxel sum larger patch 51208
# background adjusted sum 776.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 25472
# voxel sum larger patch 66492
# background adjusted sum 2840.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 21019
# voxel sum larger patch 55703
# background adjusted sum 1883.0
# area_small 128
# area_large 360
# voxel sum small patch 17860
# voxel sum larger patch 48536
# background adjusted sum 935.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 18649
# voxel sum larger patch 50994
# background adjusted sum 803.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 16555
# voxel sum larger patch 45627
# background adjusted sum 515.2758620689656
# area_small 128
# area_large 360
# voxel sum small patch 21416
# voxel sum larger patch 58630
# background adjusted sum 884.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 15886
# voxel sum larger patch 44817
# background adjusted sum -75.93103448275906
# area_small 128
# area_large 360
# voxel sum small patch 19332
# voxel sum larger patch 52551
# background adjusted sum 1004.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 21226
# voxel sum larger patch 56163
# background adjusted sum 1950.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 20668
# voxel sum larger patch 56542
# background adjusted sum 875.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 18778
# voxel sum larger patch 50059
# background adjusted sum 1519.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 16587
# voxel sum larger patch 45512
# background adjusted sum 628.3793103448279
# area_small 128
# area_large 360
# voxel sum small patch 17584
# voxel sum larger patch 48484
# background adjusted sum 535.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 22278
# voxel sum larger patch 60476
# background adjusted sum 1203.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 21182
# voxel sum larger patch 56519
# background adjusted sum 1685.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 17436
# voxel sum larger patch 47541
# background adjusted sum 826.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 20089
# voxel sum larger patch 51887
# background adjusted sum 2545.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 19145
# voxel sum larger patch 52454
# background adjusted sum 767.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 18541
# voxel sum larger patch 50250
# background adjusted sum 1046.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 23153
# voxel sum larger patch 63456
# background adjusted sum 916.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 16769
# voxel sum larger patch 47009
# background adjusted sum 84.86206896551812
# area_small 128
# area_large 360
# voxel sum small patch 19774
# voxel sum larger patch 52612
# background adjusted sum 1656.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 20359
# voxel sum larger patch 54381
# background adjusted sum 1588.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 23192
# voxel sum larger patch 60507
# background adjusted sum 2604.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18477
# voxel sum larger patch 49792
# background adjusted sum 1199.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 19919
# voxel sum larger patch 54157
# background adjusted sum 1029.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 18819
# voxel sum larger patch 51813
# background adjusted sum 615.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17630
# voxel sum larger patch 49630
# background adjusted sum -25.17241379310144
# area_small 124
# area_large 324
# voxel sum small patch 18398
# voxel sum larger patch 46579
# background adjusted sum 925.7799999999988
# area_small 120
# area_large 306
# voxel sum small patch 23025
# voxel sum larger patch 56804
# background adjusted sum 1232.0967741935492
# area_small 92
# area_large 240
# voxel sum small patch 16709
# voxel sum larger patch 41708
# background adjusted sum 1169.0810810810817
# area_small 100
# area_large 264
# voxel sum small patch 14597
# voxel sum larger patch 36764
# background adjusted sum 1080.5365853658532
# area_small 92
# area_large 240
# voxel sum small patch 13756
# voxel sum larger patch 34893
# background adjusted sum 616.7837837837851
# area_small 92
# area_large 240
# voxel sum small patch 15249
# voxel sum larger patch 39064
# background adjusted sum 445.0810810810817
# area_small 92
# area_large 240
# voxel sum small patch 12753
# voxel sum larger patch 32099
# background adjusted sum 727.1081081081084
# area_small 116
# area_large 300
# voxel sum small patch 17935
# voxel sum larger patch 43709
# background adjusted sum 1686.173913043478
# area_small 116
# area_large 300
# voxel sum small patch 15121
# voxel sum larger patch 37789
# background adjusted sum 830.3043478260861
# area_small 116
# area_large 300
# voxel sum small patch 15685
# voxel sum larger patch 39718
# background adjusted sum 533.7608695652161
# area_small 128
# area_large 342
# voxel sum small patch 17951
# voxel sum larger patch 46446
# background adjusted sum 907.2616822429918
# area_small 128
# area_large 342
# voxel sum small patch 23458
# voxel sum larger patch 58007
# background adjusted sum 2793.1775700934595
# area_small 128
# area_large 360
# voxel sum small patch 16393
# voxel sum larger patch 45693
# background adjusted sum 227.48275862069022
# area_small 128
# area_large 360
# voxel sum small patch 17778
# voxel sum larger patch 46942
# background adjusted sum 1687.5172413793098
# area_small 128
# area_large 360
# voxel sum small patch 21244
# voxel sum larger patch 56939
# background adjusted sum 1550.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 17714
# voxel sum larger patch 48013
# background adjusted sum 997.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 17932
# voxel sum larger patch 48889
# background adjusted sum 852.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 16866
# voxel sum larger patch 45737
# background adjusted sum 937.1724137931033
# area_small 128
# area_large 360
# voxel sum small patch 20332
# voxel sum larger patch 56410
# background adjusted sum 426.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 19773
# voxel sum larger patch 52869
# background adjusted sum 1513.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 18501
# voxel sum larger patch 49416
# background adjusted sum 1444.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 22005
# voxel sum larger patch 57338
# background adjusted sum 2510.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 22124
# voxel sum larger patch 58674
# background adjusted sum 1958.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 16627
# voxel sum larger patch 46426
# background adjusted sum 186.17241379310508
# area_small 128
# area_large 360
# voxel sum small patch 19814
# voxel sum larger patch 52858
# background adjusted sum 1582.8275862068986
# area_small 128
# area_large 360
# voxel sum small patch 20526
# voxel sum larger patch 55371
# background adjusted sum 1301.172413793105
# area_small 128
# area_large 360
# voxel sum small patch 18049
# voxel sum larger patch 49332
# background adjusted sum 789.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18978
# voxel sum larger patch 50230
# background adjusted sum 1735.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 19068
# voxel sum larger patch 50321
# background adjusted sum 1824.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 16348
# voxel sum larger patch 45068
# background adjusted sum 502.4827586206902
# area_small 128
# area_large 360
# voxel sum small patch 19233
# voxel sum larger patch 52996
# background adjusted sum 605.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 19612
# voxel sum larger patch 53807
# background adjusted sum 745.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 15867
# voxel sum larger patch 44277
# background adjusted sum 192.51724137930978
# area_small 128
# area_large 360
# voxel sum small patch 18698
# voxel sum larger patch 51902
# background adjusted sum 378.55172413793116
# area_small 128
# area_large 360
# voxel sum small patch 18375
# voxel sum larger patch 51104
# background adjusted sum 317.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 21991
# voxel sum larger patch 58001
# background adjusted sum 2123.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 17788
# voxel sum larger patch 48772
# background adjusted sum 693.3793103448261
# area_small 128
# area_large 360
# voxel sum small patch 20309
# voxel sum larger patch 54002
# background adjusted sum 1719.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18408
# voxel sum larger patch 50340
# background adjusted sum 790.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 19168
# voxel sum larger patch 52097
# background adjusted sum 1000.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 21148
# voxel sum larger patch 57193
# background adjusted sum 1261.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 19635
# voxel sum larger patch 54251
# background adjusted sum 536.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 17076
# voxel sum larger patch 47334
# background adjusted sum 381.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 19190
# voxel sum larger patch 51634
# background adjusted sum 1289.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 23801
# voxel sum larger patch 61045
# background adjusted sum 3252.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 19417
# voxel sum larger patch 52160
# background adjusted sum 1351.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 18140
# voxel sum larger patch 48598
# background adjusted sum 1335.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 16277
# voxel sum larger patch 45287
# background adjusted sum 271.4827586206902
# area_small 128
# area_large 360
# voxel sum small patch 21915
# voxel sum larger patch 60505
# background adjusted sum 623.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 18873
# voxel sum larger patch 52695
# background adjusted sum 212.58620689655072
# area_small 128
# area_large 360
# voxel sum small patch 21723
# voxel sum larger patch 57948
# background adjusted sum 1736.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 16877
# voxel sum larger patch 46530
# background adjusted sum 516.7241379310344
# area_small 128
# area_large 360
# voxel sum small patch 19000
# voxel sum larger patch 51090
# background adjusted sum 1295.172413793105
# area_small 128
# area_large 360
# voxel sum small patch 17818
# voxel sum larger patch 48690
# background adjusted sum 785.1724137931051
# area_small 128
# area_large 360
# voxel sum small patch 24023
# voxel sum larger patch 65462
# background adjusted sum 1160.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17652
# voxel sum larger patch 48338
# background adjusted sum 721.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18371
# voxel sum larger patch 51049
# background adjusted sum 341.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18971
# voxel sum larger patch 51702
# background adjusted sum 912.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 19346
# voxel sum larger patch 52954
# background adjusted sum 803.6551724137935
# area_small 128
# area_large 360
# voxel sum small patch 18278
# voxel sum larger patch 50131
# background adjusted sum 703.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 17523
# voxel sum larger patch 47775
# background adjusted sum 832.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 17130
# voxel sum larger patch 48018
# background adjusted sum 88.34482758620652
# area_small 128
# area_large 360
# voxel sum small patch 19638
# voxel sum larger patch 52415
# background adjusted sum 1554.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 17355
# voxel sum larger patch 46116
# background adjusted sum 1486.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 18964
# voxel sum larger patch 51811
# background adjusted sum 841.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 17380
# voxel sum larger patch 47141
# background adjusted sum 960.1379310344819
# area_small 128
# area_large 360
# voxel sum small patch 19222
# voxel sum larger patch 51459
# background adjusted sum 1436.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 19260
# voxel sum larger patch 51976
# background adjusted sum 1209.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 19277
# voxel sum larger patch 51718
# background adjusted sum 1378.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 20752
# voxel sum larger patch 56059
# background adjusted sum 1272.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 17491
# voxel sum larger patch 46510
# background adjusted sum 1480.5172413793098
# area_small 128
# area_large 360
# voxel sum small patch 16613
# voxel sum larger patch 46982
# background adjusted sum -142.31034482758696
# area_small 128
# area_large 360
# voxel sum small patch 18251
# voxel sum larger patch 48974
# background adjusted sum 1300.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 19337
# voxel sum larger patch 52477
# background adjusted sum 1052.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 21511
# voxel sum larger patch 57639
# background adjusted sum 1578.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 18711
# voxel sum larger patch 49552
# background adjusted sum 1695.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 24160
# voxel sum larger patch 63714
# background adjusted sum 2337.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 17843
# voxel sum larger patch 49921
# background adjusted sum 144.79310344827536
# area_small 128
# area_large 360
# voxel sum small patch 19906
# voxel sum larger patch 52994
# background adjusted sum 1650.5517241379312
# area_small 128
# area_large 360
# voxel sum small patch 24289
# voxel sum larger patch 61728
# background adjusted sum 3633.0
# area_small 128
# area_large 360
# voxel sum small patch 22304
# voxel sum larger patch 58085
# background adjusted sum 2562.758620689656
# area_small 128
# area_large 360
# voxel sum small patch 23672
# voxel sum larger patch 63705
# background adjusted sum 1584.8275862068986
# area_small 128
# area_large 360
# voxel sum small patch 24801
# voxel sum larger patch 66147
# background adjusted sum 1989.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 19121
# voxel sum larger patch 52350
# background adjusted sum 787.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 16731
# voxel sum larger patch 46419
# background adjusted sum 351.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 18423
# voxel sum larger patch 50053
# background adjusted sum 971.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 19905
# voxel sum larger patch 53568
# background adjusted sum 1332.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 18956
# voxel sum larger patch 51547
# ...
# background adjusted sum 1369.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 18747
# voxel sum larger patch 52679
# background adjusted sum 25.89655172413768
# area_small 128
# area_large 360
# voxel sum small patch 17702
# voxel sum larger patch 48009
# background adjusted sum 980.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 19722
# voxel sum larger patch 54882
# background adjusted sum 323.3793103448261
# area_small 96
# area_large 258
# voxel sum small patch 14308
# voxel sum larger patch 37501
# background adjusted sum 564.0
# area_small 88
# area_large 234
# voxel sum small patch 11768
# voxel sum larger patch 29666
# background adjusted sum 980.1643835616451
# area_small 128
# area_large 360
# voxel sum small patch 15764
# voxel sum larger patch 43803
# background adjusted sum 294.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 22357
# voxel sum larger patch 60075
# background adjusted sum 1547.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 17253
# voxel sum larger patch 48193
# background adjusted sum 182.65517241379348
# area_small 128
# area_large 360
# voxel sum small patch 25994
# voxel sum larger patch 68448
# background adjusted sum 2571.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 24067
# voxel sum larger patch 66383
# background adjusted sum 720.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 21364
# voxel sum larger patch 57367
# background adjusted sum 1500.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 20006
# voxel sum larger patch 53976
# background adjusted sum 1263.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 17392
# voxel sum larger patch 48936
# background adjusted sum -11.58620689655072
# area_small 128
# area_large 360
# voxel sum small patch 19841
# voxel sum larger patch 53766
# background adjusted sum 1123.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 35472
# voxel sum larger patch 93281
# background adjusted sum 3577.3793103448297
# area_small 128
# area_large 360
# voxel sum small patch 24154
# voxel sum larger patch 65560
# background adjusted sum 1309.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 24656
# voxel sum larger patch 65489
# background adjusted sum 2127.448275862069
# area_small 128
# area_large 360
# voxel sum small patch 19182
# voxel sum larger patch 52952
# background adjusted sum 550.2758620689674
# area_small 128
# area_large 360
# voxel sum small patch 19753
# voxel sum larger patch 53852
# background adjusted sum 939.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 18430
# voxel sum larger patch 50741
# background adjusted sum 603.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 18208
# voxel sum larger patch 50507
# background adjusted sum 387.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 18470
# voxel sum larger patch 50625
# background adjusted sum 729.310344827587
# area_small 128
# area_large 360
# voxel sum small patch 19333
# voxel sum larger patch 52631
# background adjusted sum 961.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 20134
# voxel sum larger patch 56065
# background adjusted sum 310.0
# area_small 128
# area_large 360
# voxel sum small patch 21521
# voxel sum larger patch 58787
# background adjusted sum 960.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 22520
# voxel sum larger patch 61500
# background adjusted sum 1013.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18717
# voxel sum larger patch 51748
# background adjusted sum 493.0
# area_small 124
# area_large 318
# voxel sum small patch 17888
# voxel sum larger patch 44734
# background adjusted sum 728.7010309278376
# area_small 116
# area_large 300
# voxel sum small patch 16747
# voxel sum larger patch 42166
# background adjusted sum 721.9782608695641
# area_small 96
# area_large 252
# voxel sum small patch 13172
# voxel sum larger patch 32301
# background adjusted sum 1400.3076923076915
# area_small 88
# area_large 234
# voxel sum small patch 12113
# voxel sum larger patch 30214
# background adjusted sum 1202.8082191780832
# area_small 128
# area_large 348
# voxel sum small patch 29054
# voxel sum larger patch 75910
# background adjusted sum 1792.3272727272742
# area_small 120
# area_large 306
# voxel sum small patch 16346
# voxel sum larger patch 40857
# background adjusted sum 532.4516129032254
# area_small 124
# area_large 324
# voxel sum small patch 19981
# voxel sum larger patch 52038
# background adjusted sum 105.65999999999985
# area_small 128
# area_large 360
# voxel sum small patch 21581
# voxel sum larger patch 58450
# background adjusted sum 1239.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 17985
# voxel sum larger patch 49746
# background adjusted sum 461.68965517241304
# area_small 128
# area_large 360
# voxel sum small patch 24523
# voxel sum larger patch 67705
# background adjusted sum 698.4482758620688
# area_small 128
# area_large 360
# voxel sum small patch 21808
# voxel sum larger patch 60374
# background adjusted sum 530.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 18462
# voxel sum larger patch 50556
# background adjusted sum 754.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 31137
# voxel sum larger patch 86810
# background adjusted sum 420.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 18138
# voxel sum larger patch 50703
# background adjusted sum 171.10344827586232
# area_small 128
# area_large 360
# voxel sum small patch 19949
# voxel sum larger patch 55627
# background adjusted sum 264.5862068965507
# area_small 128
# area_large 360
# voxel sum small patch 20272
# voxel sum larger patch 54939
# background adjusted sum 1145.379310344826
# area_small 128
# area_large 360
# voxel sum small patch 24255
# voxel sum larger patch 66164
# background adjusted sum 1132.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 15823
# voxel sum larger patch 44240
# background adjusted sum 144.65517241379348
# area_small 128
# area_large 360
# voxel sum small patch 23606
# voxel sum larger patch 60628
# background adjusted sum 3180.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 19211
# voxel sum larger patch 51253
# background adjusted sum 1532.6551724137935
# area_small 128
# area_large 360
# voxel sum small patch 22005
# voxel sum larger patch 62105
# background adjusted sum -119.13793103448188
# area_small 128
# area_large 360
# voxel sum small patch 17063
# voxel sum larger patch 47866
# background adjusted sum 68.2413793103442
# area_small 128
# area_large 360
# voxel sum small patch 17555
# voxel sum larger patch 48682
# background adjusted sum 381.4827586206884
# area_small 128
# area_large 360
# voxel sum small patch 19226
# voxel sum larger patch 52453
# background adjusted sum 893.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 26321
# voxel sum larger patch 69067
# background adjusted sum 2737.0
# area_small 112
# area_large 282
# voxel sum small patch 17181
# voxel sum larger patch 41922
# background adjusted sum 881.0470588235294
# area_small 104
# area_large 270
# voxel sum small patch 18650
# voxel sum larger patch 46953
# background adjusted sum 918.0
# area_small 124
# area_large 330
# voxel sum small patch 19801
# voxel sum larger patch 52354
# background adjusted sum 205.99029126213645
# area_small 124
# area_large 330
# voxel sum small patch 25508
# voxel sum larger patch 65842
# background adjusted sum 1229.281553398061
# area_small 128
# area_large 324
# voxel sum small patch 16128
# voxel sum larger patch 40733
# background adjusted sum 59.42857142857247
# area_small 128
# area_large 324
# voxel sum small patch 19859
# voxel sum larger patch 48818
# background adjusted sum 947.0
# area_small 128
# area_large 360
# voxel sum small patch 17809
# voxel sum larger patch 49053
# background adjusted sum 570.9310344827572
# area_small 128
# area_large 360
# voxel sum small patch 21255
# voxel sum larger patch 59611
# background adjusted sum 93.06896551724276
# area_small 128
# area_large 360
# voxel sum small patch 18295
# voxel sum larger patch 50269
# background adjusted sum 654.1724137931051
# area_small 128
# area_large 360
# voxel sum small patch 19555
# voxel sum larger patch 53533
# background adjusted sum 808.5172413793116
# area_small 128
# area_large 360
# voxel sum small patch 27674
# voxel sum larger patch 72958
# background adjusted sum 2689.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 24762
# voxel sum larger patch 66334
# background adjusted sum 1825.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 19956
# voxel sum larger patch 55220
# background adjusted sum 500.0
# area_small 128
# area_large 324
# voxel sum small patch 18555
# voxel sum larger patch 47168
# background adjusted sum -131.04081632652742
# area_small 128
# area_large 360
# voxel sum small patch 19636
# voxel sum larger patch 53467
# background adjusted sum 970.6206896551739
# area_small 128
# area_large 360
# voxel sum small patch 19772
# voxel sum larger patch 55279
# background adjusted sum 181.93103448275724
# area_small 128
# area_large 360
# voxel sum small patch 21265
# voxel sum larger patch 58551
# background adjusted sum 693.4137931034493
# area_small 116
# area_large 300
# voxel sum small patch 15984
# voxel sum larger patch 40082
# background adjusted sum 791.782608695652
# area_small 76
# area_large 168
# voxel sum small patch 10173
# voxel sum larger patch 21462
# background adjusted sum 847.3043478260861
# area_small 84
# area_large 192
# voxel sum small patch 12153
# voxel sum larger patch 27649
# background adjusted sum 100.55555555555475
# area_small 128
# area_large 360
# voxel sum small patch 23064
# voxel sum larger patch 63737
# background adjusted sum 623.7241379310362
# area_small 128
# area_large 360
# voxel sum small patch 16571
# voxel sum larger patch 45796
# background adjusted sum 446.8620689655181
# area_small 128
# area_large 360
# voxel sum small patch 23583
# voxel sum larger patch 63471
# background adjusted sum 1575.8275862068986
# area_small 128
# area_large 360
# voxel sum small patch 25676
# voxel sum larger patch 66591
# background adjusted sum 3102.2068965517246
# area_small 128
# area_large 360
# voxel sum small patch 17693
# voxel sum larger patch 48051
# background adjusted sum 943.7586206896558
# area_small 128
# area_large 360
# voxel sum small patch 21197
# voxel sum larger patch 60354
# background adjusted sum -406.8620689655181
# area_small 128
# area_large 324
# voxel sum small patch 17278
# voxel sum larger patch 43927
# background adjusted sum -125.42857142856883
# area_small 128
# area_large 360
# voxel sum small patch 18143
# voxel sum larger patch 50255
# background adjusted sum 426.03448275861956
# area_small 128
# area_large 360
# voxel sum small patch 20712
# voxel sum larger patch 57011
# background adjusted sum 684.9655172413804
# area_small 128
# area_large 360
# voxel sum small patch 23343
# voxel sum larger patch 65377
# background adjusted sum 151.82758620689856
# area_small 128
# area_large 360
# voxel sum small patch 30335
# voxel sum larger patch 80976
# background adjusted sum 2395.137931034482
# area_small 128
# area_large 360
# voxel sum small patch 18668
# voxel sum larger patch 51811
# background adjusted sum 382.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 25153
# voxel sum larger patch 68337
# background adjusted sum 1327.3448275862065
# area_small 128
# area_large 360
# voxel sum small patch 25370
# voxel sum larger patch 67476
# background adjusted sum 2139.1034482758623
# area_small 128
# area_large 360
# voxel sum small patch 24252
# voxel sum larger patch 63594
# background adjusted sum 2546.0689655172428
# area_small 128
# area_large 360
# voxel sum small patch 19610
# voxel sum larger patch 53720
# background adjusted sum 790.689655172413
# area_small 128
# area_large 324
# voxel sum small patch 20964
# voxel sum larger patch 51045
# background adjusted sum 1319.2653061224519
# area_small 128
# area_large 360
# voxel sum small patch 17667
# voxel sum larger patch 50000
# background adjusted sum -171.89655172413768
# area_small 128
# area_large 360
# voxel sum small patch 24195
# voxel sum larger patch 67063
# background adjusted sum 543.689655172413
# area_small 128
# area_large 360
# voxel sum small patch 34132
# voxel sum larger patch 94903
# background adjusted sum 603.1724137931014
# area_small 128
# area_large 360
# voxel sum small patch 18849
# voxel sum larger patch 52491
# background adjusted sum 287.8965517241377
# area_small 128
# area_large 360
# voxel sum small patch 17375
# voxel sum larger patch 48911
# background adjusted sum -24.17241379310144
# area_small 128
# area_large 360
# voxel sum small patch 19435
# voxel sum larger patch 52452
# background adjusted sum 1218.7241379310362
# area_small 128
# area_large 324
# voxel sum small patch 20202
# voxel sum larger patch 50994
# background adjusted sum 92.93877551020705
# area_small 128
# area_large 360
# voxel sum small patch 23926
# voxel sum larger patch 65222
# background adjusted sum 1142.0
# area_small 128
# area_large 360
# voxel sum small patch 26153
# voxel sum larger patch 71356
# background adjusted sum 1213.4137931034493
# area_small 128
# area_large 324
# voxel sum small patch 18494
# voxel sum larger patch 44893
# background adjusted sum 1253.8367346938794
# area_small 128
# area_large 324
# voxel sum small patch 27256
# voxel sum larger patch 68496
# background adjusted sum 323.7551020408173
# area_small 128
# area_large 324
# voxel sum small patch 18199
# voxel sum larger patch 45635
# background adjusted sum 281.6122448979622
# area_small 128
# area_large 360
# voxel sum small patch 23129
# voxel sum larger patch 62147
# background adjusted sum 1601.8275862068986
# area_small 128
# area_large 360
# voxel sum small patch 23198
# voxel sum larger patch 62792
# background adjusted sum 1353.0344827586196
# area_small 128
# area_large 324
# voxel sum small patch 18207
# voxel sum larger patch 46153
# background adjusted sum -43.44897959183436
# area_small 128
# area_large 360
# voxel sum small patch 20131
# voxel sum larger patch 55822
# background adjusted sum 439.4137931034493
# area_small 128
# area_large 360
# voxel sum small patch 27482
# voxel sum larger patch 73646
# background adjusted sum 2012.2068965517246
# area_small 128
# area_large 324
# voxel sum small patch 20490
# voxel sum larger patch 49929
# background adjusted sum 1264.5306122449
# area_small 128
# area_large 324
# voxel sum small patch 25419
# voxel sum larger patch 64403
# background adjusted sum -39.93877551020341
# area_small 128
# area_large 324
# voxel sum small patch 18118
# voxel sum larger patch 45578
# background adjusted sum 184.93877551020705
# area_small 128
# area_large 360
# voxel sum small patch 30859
# voxel sum larger patch 81062
# background adjusted sum 3160.7931034482754
# area_small 128
# area_large 360
# voxel sum small patch 18090
# voxel sum larger patch 50189
# background adjusted sum 380.20689655172464
# area_small 128
# area_large 360
# voxel sum small patch 23366
# voxel sum larger patch 63755
# background adjusted sum 1082.4137931034493
# area_small 128
# area_large 324
# voxel sum small patch 18919
# voxel sum larger patch 46627
# background adjusted sum 823.9795918367345
# area_small 128
# area_large 324
# voxel sum small patch 18900
# voxel sum larger patch 46853
# background adjusted sum 644.9795918367345
# area_small 128
# area_large 324
# voxel sum small patch 19711
# voxel sum larger patch 49855
# background adjusted sum 25.122448979593173
# area_small 128
# area_large 324
# voxel sum small patch 18976
# voxel sum larger patch 47568
# background adjusted sum 303.6734693877552
# area_small 128
# area_large 324
# voxel sum small patch 20984
# voxel sum larger patch 53565
# background adjusted sum -293.3877551020378
# area_small 128
# area_large 324
# voxel sum small patch 21225
# voxel sum larger patch 51793
# background adjusted sum 1262.2244897959208
# area_small 128
# area_large 324
# voxel sum small patch 20185
# voxel sum larger patch 50656
# background adjusted sum 285.57142857143117
# area_small 128
# area_large 324
# voxel sum small patch 19972
# voxel sum larger patch 50682
# background adjusted sum -83.51020408163095
# area_small 128
# area_large 324
# voxel sum small patch 23303
# voxel sum larger patch 58473
# background adjusted sum 334.8367346938794
# area_small 128
# area_large 324
# voxel sum small patch 25036
# voxel sum larger patch 63673
# background adjusted sum -196.32653061224119
# area_small 128
# area_large 324
# voxel sum small patch 21020
# voxel sum larger patch 49909
# background adjusted sum 2153.7142857142862
# area_small 128
# area_large 324
# voxel sum small patch 18586
# voxel sum larger patch 46966
# background adjusted sum 52.12244897959317

# %%
# pass the channel for which pixel values are needed and the coordinates around which values are supposed to be calculated
# convention for coords [z,y,x] 
# convention for channel is 1 for channel 1, 2 for channel 2 and so on 
start_time = time.time()
offset = [0,0]
col_names = ['mu_z', 'mu_y', 'mu_x']
mean,maximum,minimum,pixel_values,max_loc = extractor.extract_pixels_data_variable_bd(center_col_names = col_names, channel = 3)

end_time = time.time()
print('time taken (seconds)', end_time - start_time)

# %%
max_loc = np.array(max_loc)

# %%
track_df['c3_mean_amp'] = mean
track_df['c3_voxel_sum'] = voxel_sum_array
track_df['c3_peak_amp'] = maximum 
track_df['c3_peak_x'] = max_loc[:,2]
track_df['c3_peak_y'] = max_loc[:,1]
track_df['c3_peak_z'] = max_loc[:,0]

# %%
track_df

# %% [markdown]
# # Extract information for Channel 2

# %%
# pass the channel for which pixel values are needed and the coordinates around which values are supposed to be calculated
# convention for coords [z,y,x] 
# convention for channel is 1 for channel 1, 2 for channel 2 and so on 
start_time = time.time()
offset = [0,0]
col_names = ['mu_z', 'mu_y', 'mu_x']
mean,maximum,minimum,pixel_values,max_loc = extractor.extract_pixels_data_variable_bd(center_col_names = col_names, channel = 2)

end_time = time.time()
print('time taken (seconds)', end_time - start_time)

# %%
max_loc = np.array(max_loc)

# %% [markdown]
# ## Finding peak pixel for Channel 2 as not sure about the offset between Channel 3 and Channel 2
# **Reason for offset is being shot from different cameras**

# %%
track_df['c2_amp'] = mean
track_df['c2_peak'] = maximum
track_df['c2_peak_x'] = max_loc[:,2]
track_df['c2_peak_y'] = max_loc[:,1]
track_df['c2_peak_z'] = max_loc[:,0]

# %%
track_df

# %% [markdown]
# ## Finding mean value around the peak pixel value for channel 2

# %%
start_time = time.time()
col_names = ['c2_peak_z', 'c2_peak_y', 'c2_peak_x']
peak_mean,maxima,_,_,_ = extractor.extract_pixels_data_variable_bd(center_col_names = col_names, 
                                                     channel = 2)
end_time = time.time()
print('time taken (seconds)', end_time - start_time)

# %%
track_df['c2_peak_mean'] = peak_mean

# %%
track_df

# %% [markdown]
# ## Finding voxel sum around peak for channel 2

# %%
# pass the channel for which voxel sum is needed and the coordinates around which voxel sum is supposed to be calculated
# convention for coords [z,y,x] 
# convention for channel is 1 for channel 1, 2 for channel 2 and so on 
start_time = time.time()
voxel_sum_array, _ = extractor.voxel_sum_fixed_bd(center_col_names = ['c2_peak_z', 'c2_peak_y', 'c2_peak_x'],
                                       channel = 2)
end_time = time.time()
print('time taken (seconds)', end_time - start_time)

# %%
#calculated around the peak value coordinates
track_df['c2_voxel_sum'] = voxel_sum_array

# %%
track_df

# %% [markdown]
# ### Gaussian Fitting for Channel 2 around peak values

# %%
#Calculating the gaussian fitting estimates around peak coords for channel 2 
#expected sigma value needed for gaussian fitting 
#set all frames to False for processing limited frames 
#max_frames determines the frames to be processed if all_frames is false
start_time = time.time()
channel2_gaussians_df = extractor.run_parallel_frame_processing(expected_sigma = [4,2,2], 
                                        center_col_name = ['c2_peak_z', 'c2_peak_y', 'c2_peak_x'], 
                                       dist_between_spots = 10 , channel = 2,  max_frames =  2, all_frames = False)
end_time = time.time()
print('time taken (seconds)', end_time - start_time)

# %%
track_df['c2_gaussian_amp'] = channel2_gaussians_df['amplitude']
track_df['c2_mu_x'] = channel2_gaussians_df['mu_x']
track_df['c2_mu_y'] = channel2_gaussians_df['mu_y']
track_df['c2_mu_z'] = channel2_gaussians_df['mu_z']
track_df['c2_sigma_x'] = channel2_gaussians_df['sigma_x']
track_df['c2_sigma_y'] = channel2_gaussians_df['sigma_y']
track_df['c2_sigma_z'] = channel2_gaussians_df['sigma_z']

# %%
track_df

# %% [markdown]
# # Extract information for channel 1

# %%
offset = [0,0]
col_names = ['mu_z', 'mu_y', 'mu_x']
radi_list = ['sigma_z', 'sigma_y', 'sigma_x']
mean,maximum,minimum,pixel_values,max_loc = extractor.extract_pixels_data_variable_bd(center_col_names = col_names, channel = 1)

# %%
max_loc = np.array(max_loc)

# %%
track_df['c1_amp'] = mean
track_df['c1_peak'] = maximum
track_df['c1_peak_x'] = max_loc[:,2]
track_df['c1_peak_y'] = max_loc[:,1]
track_df['c1_peak_z'] = max_loc[:,0]

# %%
voxel_sum_array, _ = extractor.voxel_sum_fixed_bd(center_col_names = ['mu_z', 'mu_y', 'mu_x'], channel = 1)

# %%
#calculated around the peak value coordinates
track_df['c1_voxel_sum'] = voxel_sum_array

# %%
track_df

# %%
track_df.shape

# %% [markdown]
# ### Perform Guassian Fitting for channel 1

# %%
start_time = time.time()
channel1_gaussians_df = extractor.run_parallel_frame_processing(expected_sigma = [4,2,2], 
                                        center_col_name = ['c1_peak_z', 'c1_peak_y', 'c1_peak_x'], 
                                       dist_between_spots = 10, channel = 1,  max_frames =  2, all_frames = False)
end_time = time.time()
print('time taken (seconds)', end_time - start_time)

# %%
channel1_gaussians_df

# %%
track_df['c1_gaussian_amp'] = channel1_gaussians_df['amplitude']
track_df['c1_mu_x'] = channel1_gaussians_df['mu_x']
track_df['c1_mu_y'] = channel1_gaussians_df['mu_y']
track_df['c1_mu_z'] = channel1_gaussians_df['mu_z']
track_df['c1_sigma_x'] = channel1_gaussians_df['sigma_x']
track_df['c1_sigma_y'] = channel1_gaussians_df['sigma_y']
track_df['c1_sigma_z'] = channel1_gaussians_df['sigma_z']

# %%
track_df

# %%
#file_path = "/Users/apple/Desktop/Akamatsu_Lab/Data/full_movie_output_zarr/track_df_cleaned_final_full.pkl"
#track_df.to_pickle(file_path)

# %% [markdown]
# # To test the following functions change the markdown files to code files
# 1. Voxel sum using the variable sigma/radi values directly inferred from the dataset
# 2. Extracting pixel values mean,max etc using fixed radi
# 3. Performing Gaussian Fitting on peak coords for single frame

# %% [markdown]
# ### Function 1 (Voxel Sum)
# start_time = time.time()
# voxel_sum_array_variable, _ = extractor.voxel_sum_variable_bd(dataframe = track_df,center_col_names = ['mu_z', 'mu_y', 'mu_x'],
#                                                   radi_col_name = ['sigma_z','sigma_y','sigma_x'], frame_col_name = 'frame', channel = 3)
# end_time = time.time()
# print('time taken (seconds)', end_time - start_time)

# %% [markdown]
# ### Function 2 (Extracting Pixel Values)
# start_time = time.time()
# offset = [0,0]
# col_names = ['mu_z', 'mu_y', 'mu_x']
# radii = [4, 2, 2]
# mean_v,maximum_v,minimum_v,pixel_values_v,max_loc_v = extractor.extract_pixels_data_fixed_bd(center_col_names = col_names,
#                 dataframe = track_df, radii = radii, frame_col_name = 'frame', channel = 3)
#
# end_time = time.time()
# print('time taken (seconds)', end_time - start_time)

# %% [markdown]
# ### Function 3 (Gaussian fitting on one frame for one channel)
# df = extractor.gaussian_fitting_single_frame(expected_sigma = [4,2,2],
#                               center_col_names = ['c2_peak_z', 'c2_peak_y', 'c2_peak_x'],
#                                       frame = 0, channel = 2, dist_between_spots = 10)
