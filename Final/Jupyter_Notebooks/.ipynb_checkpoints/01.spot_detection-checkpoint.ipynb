# %% [markdown]
# # SPOTS DETECTOR
# ## This notebook takes input of raw images(one channel at a time) and outputs spots for that channel over all frames in the image. For detailed analysis of a single frame use other notebooks in this folder.
# ## Note
# 1. The code to generate csv files as output has been commented out and can be used if needed
# 2. Pickle files will be outputted to save memory

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


### package for 3d visualization
#from itkwidgets import view                              
#from aicssegmentation.core.visual import seg_fluo_side_by_side,  single_fluorescent_view, segmentation_quick_view
#import skimage

### local new python segmentation functions
import os
import sys
pythonPackagePath = os.path.abspath('../src/')
sys.path.append(pythonPackagePath)
from peak_local_max_3d import peak_local_max_3d 
from gaussian_fitting import fit_multiple_gaussians
from extract_data import extract_data_from_filename
from gaussian_visualization import visualize_3D_gaussians
from gaussian_fitting import check_fitting_error
import matplotlib.pyplot as plt

# %% [markdown]
# ## Change the following before running the code
# 1. input_filename
# 2. save_dir

# %%
input_filename = '/Users/apple/Desktop/Akamatsu_Lab/pyLattice_tutorials/test_data/Channel3_complete.tif'

# Specify the directory where you want to save the pickle files
save_dir = '/Users/apple/Desktop/Akamatsu_Lab/pyLattice_tutorials/DataFrames/Channel_3_pkl'

# csv saving directory 
#csv_save_dir = '../DataFrames/Channel_3_csv'

# %% [markdown]
# ## Change the following before running the code
# 1. Intensity for Channel 2(set to 170) and for Channel 3(set to 180)
# 2. Output Pickle File Name for channel 2 and channel 3

# %%
import time

#original image shape is (t,z,y,x)
image_raw = extract_data_from_filename(input_filename)
#print(image_raw.shape)

#transpose the image such that we get (t,z,x,y)
image_raw = np.transpose(image_raw, axes =(0,1,3,2))

#get the number of frames for our original data for automated analysis for all frames 
frames = image_raw.shape[0]

start_time = time.time()

for frame in range(frames):
    
    print('frame number is', frame)
    
    single_frame_input = image_raw[frame]

    #define threshold: a value(intensity) for the pixel below which all values would be considered noise and dropped 
    #define min_distance: min_distance/2 is the radius within which we will keep the peak with max value/intensity or 
    #if two peaks have the same value they will be kept 
    maximas = peak_local_max_3d(single_frame_input,min_distance=10,threshold=180)
    print('local_maximas detected are', maximas.shape[0])


    #give the expected std dev/radius of our particles for x,y,z 
    sigmaExpected_x__pixels = 2
    sigmaExpected_y__pixels = 2
    sigmaExpected_z__pixels = 4

    sigmas_guesses = []
    for i in range(len(maximas)):
        sigmas_guesses.append([sigmaExpected_z__pixels,sigmaExpected_x__pixels,sigmaExpected_y__pixels])
        
    #last parameter in the fit_multiple_gaussians is similar to min_distance above, we should give half of the 
    #value here of min_distance   
    gaussians, gaussians_popt = fit_multiple_gaussians(single_frame_input,maximas,sigmas_guesses,5)
        
    accumulator = []
    for gaussian in gaussians:

        if(gaussian!=-1):
            amplitude = gaussian[0]

            #print(gaussian)
            mu_x     = int(gaussian[1][1]) ##this is going to be mu_z, previous code [1][0]
            mu_y     = int(gaussian[1][2]) ##need to finalise what this is (x or y) [1][1]
            mu_z     = int(gaussian[1][0]) ##need to finalise what this is (x or y) [1][2]
            ##sigmas will also change due to the above 
            sigma_x  = int(gaussian[2][1]) 
            sigma_y  = int(gaussian[2][2])
            sigma_z  = int(gaussian[2][0])
            accumulator.append(np.array([amplitude,mu_x,mu_y,mu_z,sigma_x,sigma_y,sigma_z]))
            
    accumulator = np.array(accumulator)
    df = pd.DataFrame()
    df['amplitude'] = accumulator[:,0]
    df['mu_x'] = accumulator[:,1]
    df['mu_y'] = accumulator[:,2]
    df['mu_z'] = accumulator[:,3]
    df['sigma_x'] = accumulator[:,4]
    df['sigma_y'] = accumulator[:,5]
    df['sigma_z'] = accumulator[:,6]
    df.head()
    
    error_list = check_fitting_error(single_frame_input,maximas,gaussians,sigmas_guesses)
    
    # Construct the filename
    '''
    filename_csv = f'df_c2_t{frame}.csv'
    file_path_csv = os.path.join(csv_save_dir, filename_csv)
    df.to_csv(file_path_csv)
    '''

    # Construct the filename based on the loop index (time_frame)
    filename_pkl = f'df_c3_t{frame}.pkl'

    # Construct the full file path by joining the directory and filename
    file_path = os.path.join(save_dir, filename_pkl)

    # Save the DataFrame to a pickle file with the specified path
    df.to_pickle(file_path)
end_time = time.time()

print('time taken (seconds)', end_time - start_time)
# Out:
# (130, 1, 75, 258, 275)
# (130, 75, 258, 275)
# frame number is 0
# local_maximas detected are 578
# 10%(58 of 578)
# 20%(116 of 578)
# 30%(174 of 578)
# 40%(232 of 578)
# 50%(289 of 578)
# 60%(347 of 578)
# 70%(405 of 578)
# 80%(463 of 578)
# 90%(521 of 578)
# 100%(578 of 578)
# frame number is 1
# local_maximas detected are 552
# 10%(56 of 552)
# 20%(111 of 552)
# 30%(166 of 552)
# 40%(221 of 552)
# 50%(276 of 552)
# 60%(332 of 552)
# 70%(387 of 552)
# 80%(442 of 552)
# 90%(497 of 552)
# 100%(552 of 552)
# frame number is 2
# local_maximas detected are 567
# 10%(57 of 567)
# 20%(114 of 567)
# 30%(171 of 567)
# 40%(227 of 567)
# 50%(284 of 567)
# 60%(341 of 567)
# 70%(397 of 567)
# 80%(454 of 567)
# 90%(511 of 567)
# 100%(567 of 567)
# frame number is 3
# local_maximas detected are 552
# 10%(56 of 552)
# 20%(111 of 552)
# 30%(166 of 552)
# 40%(221 of 552)
# 50%(276 of 552)
# 60%(332 of 552)
# 70%(387 of 552)
# 80%(442 of 552)
# 90%(497 of 552)
# 100%(552 of 552)
# frame number is 4
# local_maximas detected are 544
# 10%(55 of 544)
# 20%(109 of 544)
# 30%(164 of 544)
# 40%(218 of 544)
# 50%(272 of 544)
# 60%(327 of 544)
# 70%(381 of 544)
# 80%(436 of 544)
# 90%(490 of 544)
# 100%(544 of 544)
# frame number is 5
# local_maximas detected are 558
# 10%(56 of 558)
# 20%(112 of 558)
# 30%(168 of 558)
# 40%(224 of 558)
# 50%(279 of 558)
# 60%(335 of 558)
# 70%(391 of 558)
# 80%(447 of 558)
# 90%(503 of 558)
# 100%(558 of 558)
# frame number is 6
# local_maximas detected are 542
# 10%(55 of 542)
# 20%(109 of 542)
# 30%(163 of 542)
# 40%(217 of 542)
# 50%(271 of 542)
# 60%(326 of 542)
# 70%(380 of 542)
# 80%(434 of 542)
# 90%(488 of 542)
# 100%(542 of 542)
# frame number is 7
# local_maximas detected are 544
# 10%(55 of 544)
# 20%(109 of 544)
# 30%(164 of 544)
# 40%(218 of 544)
# 50%(272 of 544)
# 60%(327 of 544)
# 70%(381 of 544)
# 80%(436 of 544)
# 90%(490 of 544)
# 100%(544 of 544)
# frame number is 8
# local_maximas detected are 546
# 10%(55 of 546)
# 20%(110 of 546)
# 30%(164 of 546)
# 40%(219 of 546)
# 50%(273 of 546)
# 60%(328 of 546)
# 70%(383 of 546)
# 80%(437 of 546)
# 90%(492 of 546)
# 100%(546 of 546)
# frame number is 9
# local_maximas detected are 525
# 10%(53 of 525)
# 20%(105 of 525)
# 30%(158 of 525)
# 40%(210 of 525)
# 50%(263 of 525)
# 60%(315 of 525)
# 70%(368 of 525)
# 80%(420 of 525)
# 90%(473 of 525)
# 100%(525 of 525)
# frame number is 10
# local_maximas detected are 547
# 10%(55 of 547)
# 20%(110 of 547)
# 30%(165 of 547)
# 40%(219 of 547)
# 50%(274 of 547)
# 60%(329 of 547)
# 70%(383 of 547)
# 80%(438 of 547)
# 90%(493 of 547)
# 100%(547 of 547)
# frame number is 11
# local_maximas detected are 551
# 10%(56 of 551)
# 20%(111 of 551)
# 30%(166 of 551)
# 40%(221 of 551)
# 50%(276 of 551)
# 60%(331 of 551)
# 70%(386 of 551)
# 80%(441 of 551)
# 90%(496 of 551)
# 100%(551 of 551)
# frame number is 12
# local_maximas detected are 535
# 10%(54 of 535)
# 20%(107 of 535)
# 30%(161 of 535)
# 40%(214 of 535)
# 50%(268 of 535)
# 60%(321 of 535)
# 70%(375 of 535)
# 80%(428 of 535)
# 90%(482 of 535)
# 100%(535 of 535)
# frame number is 13
# local_maximas detected are 551
# 10%(56 of 551)
# 20%(111 of 551)
# 30%(166 of 551)
# 40%(221 of 551)
# 50%(276 of 551)
# 60%(331 of 551)
# 70%(386 of 551)
# 80%(441 of 551)
# 90%(496 of 551)
# 100%(551 of 551)
# frame number is 14
# local_maximas detected are 547
# 10%(55 of 547)
# 20%(110 of 547)
# 30%(165 of 547)
# 40%(219 of 547)
# 50%(274 of 547)
# 60%(329 of 547)
# 70%(383 of 547)
# 80%(438 of 547)
# 90%(493 of 547)
# 100%(547 of 547)
# frame number is 15
# local_maximas detected are 511
# 10%(52 of 511)
# 20%(103 of 511)
# 30%(154 of 511)
# 40%(205 of 511)
# 50%(256 of 511)
# 60%(307 of 511)
# 70%(358 of 511)
# 80%(409 of 511)
# 90%(460 of 511)
# 100%(511 of 511)
# frame number is 16
# local_maximas detected are 509
# 10%(51 of 509)
# 20%(102 of 509)
# 30%(153 of 509)
# 40%(204 of 509)
# 50%(255 of 509)
# 60%(306 of 509)
# 70%(357 of 509)
# 80%(408 of 509)
# 90%(459 of 509)
# 100%(509 of 509)
# frame number is 17
# local_maximas detected are 521
# 10%(53 of 521)
# 20%(105 of 521)
# 30%(157 of 521)
# 40%(209 of 521)
# 50%(261 of 521)
# 60%(313 of 521)
# 70%(365 of 521)
# 80%(417 of 521)
# 90%(469 of 521)
# 100%(521 of 521)
# frame number is 18
# local_maximas detected are 522
# 10%(53 of 522)
# 20%(105 of 522)
# 30%(157 of 522)
# 40%(209 of 522)
# 50%(261 of 522)
# 60%(314 of 522)
# 70%(366 of 522)
# 80%(418 of 522)
# 90%(470 of 522)
# 100%(522 of 522)
# frame number is 19
# local_maximas detected are 531
# 10%(54 of 531)
# 20%(107 of 531)
# 30%(160 of 531)
# 40%(213 of 531)
# 50%(266 of 531)
# 60%(319 of 531)
# 70%(372 of 531)
# 80%(425 of 531)
# 90%(478 of 531)
# 100%(531 of 531)
# frame number is 20
# local_maximas detected are 503
# 10%(51 of 503)
# 20%(101 of 503)
# 30%(151 of 503)
# 40%(202 of 503)
# 50%(252 of 503)
# 60%(302 of 503)
# 70%(353 of 503)
# 80%(403 of 503)
# 90%(453 of 503)
# 100%(503 of 503)
# frame number is 21
# local_maximas detected are 507
# 10%(51 of 507)
# 20%(102 of 507)
# 30%(153 of 507)
# 40%(203 of 507)
# 50%(254 of 507)
# 60%(305 of 507)
# 70%(355 of 507)
# 80%(406 of 507)
# 90%(457 of 507)
# 100%(507 of 507)
# frame number is 22
# local_maximas detected are 546
# 10%(55 of 546)
# 20%(110 of 546)
# 30%(164 of 546)
# 40%(219 of 546)
# 50%(273 of 546)
# 60%(328 of 546)
# 70%(383 of 546)
# 80%(437 of 546)
# 90%(492 of 546)
# 100%(546 of 546)
# frame number is 23
# local_maximas detected are 519
# 10%(52 of 519)
# 20%(104 of 519)
# 30%(156 of 519)
# 40%(208 of 519)
# 50%(260 of 519)
# 60%(312 of 519)
# 70%(364 of 519)
# 80%(416 of 519)
# 90%(468 of 519)
# 100%(519 of 519)
# frame number is 24
# local_maximas detected are 517
# 10%(52 of 517)
# 20%(104 of 517)
# 30%(156 of 517)
# 40%(207 of 517)
# 50%(259 of 517)
# 60%(311 of 517)
# 70%(362 of 517)
# 80%(414 of 517)
# 90%(466 of 517)
# 100%(517 of 517)
# frame number is 25
# local_maximas detected are 512
# 10%(52 of 512)
# 20%(103 of 512)
# 30%(154 of 512)
# 40%(205 of 512)
# 50%(256 of 512)
# 60%(308 of 512)
# 70%(359 of 512)
# 80%(410 of 512)
# 90%(461 of 512)
# 100%(512 of 512)
# frame number is 26
# local_maximas detected are 502
# 10%(51 of 502)
# 20%(101 of 502)
# 30%(151 of 502)
# 40%(201 of 502)
# 50%(251 of 502)
# 60%(302 of 502)
# 70%(352 of 502)
# 80%(402 of 502)
# 90%(452 of 502)
# 100%(502 of 502)
# frame number is 27
# local_maximas detected are 491
# 10%(50 of 491)
# 20%(99 of 491)
# 30%(148 of 491)
# 40%(197 of 491)
# 50%(246 of 491)
# 60%(295 of 491)
# 70%(344 of 491)
# 80%(393 of 491)
# 90%(442 of 491)
# 100%(491 of 491)
# frame number is 28
# local_maximas detected are 514
# 10%(52 of 514)
# 20%(103 of 514)
# 30%(155 of 514)
# 40%(206 of 514)
# 50%(257 of 514)
# 60%(309 of 514)
# 70%(360 of 514)
# 80%(412 of 514)
# 90%(463 of 514)
# 100%(514 of 514)
# frame number is 29
# local_maximas detected are 530
# 10%(53 of 530)
# 20%(106 of 530)
# 30%(159 of 530)
# 40%(212 of 530)
# 50%(265 of 530)
# 60%(318 of 530)
# 70%(371 of 530)
# 80%(424 of 530)
# 90%(477 of 530)
# 100%(530 of 530)
# frame number is 30
# local_maximas detected are 506
# 10%(51 of 506)
# 20%(102 of 506)
# 30%(152 of 506)
# 40%(203 of 506)
# 50%(253 of 506)
# 60%(304 of 506)
# 70%(355 of 506)
# 80%(405 of 506)
# 90%(456 of 506)
# 100%(506 of 506)
# frame number is 31
# local_maximas detected are 509
# 10%(51 of 509)
# 20%(102 of 509)
# 30%(153 of 509)
# 40%(204 of 509)
# 50%(255 of 509)
# 60%(306 of 509)
# 70%(357 of 509)
# 80%(408 of 509)
# 90%(459 of 509)
# 100%(509 of 509)
# frame number is 32
# local_maximas detected are 482
# 10%(49 of 482)
# 20%(97 of 482)
# 30%(145 of 482)
# 40%(193 of 482)
# 50%(241 of 482)
# 60%(290 of 482)
# 70%(338 of 482)
# 80%(386 of 482)
# 90%(434 of 482)
# 100%(482 of 482)
# frame number is 33
# local_maximas detected are 522
# 10%(53 of 522)
# 20%(105 of 522)
# 30%(157 of 522)
# 40%(209 of 522)
# 50%(261 of 522)
# 60%(314 of 522)
# 70%(366 of 522)
# 80%(418 of 522)
# 90%(470 of 522)
# 100%(522 of 522)
# frame number is 34
# local_maximas detected are 509
# 10%(51 of 509)
# 20%(102 of 509)
# 30%(153 of 509)
# 40%(204 of 509)
# 50%(255 of 509)
# 60%(306 of 509)
# 70%(357 of 509)
# 80%(408 of 509)
# 90%(459 of 509)
# 100%(509 of 509)
# frame number is 35
# local_maximas detected are 500
# 10%(50 of 500)
# 20%(100 of 500)
# 30%(150 of 500)
# 40%(200 of 500)
# 50%(250 of 500)
# 60%(300 of 500)
# 70%(350 of 500)
# 80%(400 of 500)
# 90%(450 of 500)
# 100%(500 of 500)
# frame number is 36
# local_maximas detected are 506
# 10%(51 of 506)
# 20%(102 of 506)
# 30%(152 of 506)
# 40%(203 of 506)
# 50%(253 of 506)
# 60%(304 of 506)
# 70%(355 of 506)
# 80%(405 of 506)
# 90%(456 of 506)
# 100%(506 of 506)
# frame number is 37
# local_maximas detected are 494
# 10%(50 of 494)
# 20%(99 of 494)
# 30%(149 of 494)
# 40%(198 of 494)
# 50%(247 of 494)
# 60%(297 of 494)
# 70%(346 of 494)
# 80%(396 of 494)
# 90%(445 of 494)
# 100%(494 of 494)
# frame number is 38
# local_maximas detected are 507
# 10%(51 of 507)
# 20%(102 of 507)
# 30%(153 of 507)
# 40%(203 of 507)
# 50%(254 of 507)
# 60%(305 of 507)
# 70%(355 of 507)
# 80%(406 of 507)
# 90%(457 of 507)
# 100%(507 of 507)
# frame number is 39
# local_maximas detected are 506
# 10%(51 of 506)
# 20%(102 of 506)
# 30%(152 of 506)
# 40%(203 of 506)
# 50%(253 of 506)
# 60%(304 of 506)
# 70%(355 of 506)
# 80%(405 of 506)
# 90%(456 of 506)
# 100%(506 of 506)
# frame number is 40
# local_maximas detected are 502
# 10%(51 of 502)
# 20%(101 of 502)
# 30%(151 of 502)
# 40%(201 of 502)
# 50%(251 of 502)
# 60%(302 of 502)
# 70%(352 of 502)
# 80%(402 of 502)
# 90%(452 of 502)
# 100%(502 of 502)
# frame number is 41
# local_maximas detected are 489
# 10%(49 of 489)
# 20%(98 of 489)
# 30%(147 of 489)
# 40%(196 of 489)
# 50%(245 of 489)
# 60%(294 of 489)
# 70%(343 of 489)
# 80%(392 of 489)
# 90%(441 of 489)
# 100%(489 of 489)
# frame number is 42
# local_maximas detected are 507
# 10%(51 of 507)
# 20%(102 of 507)
# 30%(153 of 507)
# 40%(203 of 507)
# 50%(254 of 507)
# 60%(305 of 507)
# 70%(355 of 507)
# 80%(406 of 507)
# 90%(457 of 507)
# 100%(507 of 507)
# frame number is 43
# local_maximas detected are 476
# 10%(48 of 476)
# 20%(96 of 476)
# 30%(143 of 476)
# 40%(191 of 476)
# 50%(238 of 476)
# 60%(286 of 476)
# 70%(334 of 476)
# 80%(381 of 476)
# 90%(429 of 476)
# 100%(476 of 476)
# frame number is 44
# local_maximas detected are 471
# 10%(48 of 471)
# 20%(95 of 471)
# 30%(142 of 471)
# 40%(189 of 471)
# 50%(236 of 471)
# 60%(283 of 471)
# 70%(330 of 471)
# 80%(377 of 471)
# 90%(424 of 471)
# 100%(471 of 471)
# frame number is 45
# local_maximas detected are 477
# 10%(48 of 477)
# 20%(96 of 477)
# 30%(144 of 477)
# 40%(191 of 477)
# 50%(239 of 477)
# 60%(287 of 477)
# 70%(334 of 477)
# 80%(382 of 477)
# 90%(430 of 477)
# 100%(477 of 477)
# the gaussian did not fit
# frame number is 46
# local_maximas detected are 486
# 10%(49 of 486)
# 20%(98 of 486)
# 30%(146 of 486)
# 40%(195 of 486)
# 50%(243 of 486)
# 60%(292 of 486)
# 70%(341 of 486)
# 80%(389 of 486)
# 90%(438 of 486)
# 100%(486 of 486)
# frame number is 47
# local_maximas detected are 473
# 10%(48 of 473)
# 20%(95 of 473)
# 30%(142 of 473)
# 40%(190 of 473)
# 50%(237 of 473)
# 60%(284 of 473)
# 70%(332 of 473)
# 80%(379 of 473)
# 90%(426 of 473)
# 100%(473 of 473)
# frame number is 48
# local_maximas detected are 483
# 10%(49 of 483)
# 20%(97 of 483)
# 30%(145 of 483)
# 40%(194 of 483)
# 50%(242 of 483)
# 60%(290 of 483)
# 70%(339 of 483)
# 80%(387 of 483)
# 90%(435 of 483)
# 100%(483 of 483)
# frame number is 49
# local_maximas detected are 482
# 10%(49 of 482)
# 20%(97 of 482)
# 30%(145 of 482)
# 40%(193 of 482)
# 50%(241 of 482)
# 60%(290 of 482)
# 70%(338 of 482)
# 80%(386 of 482)
# 90%(434 of 482)
# 100%(482 of 482)
# frame number is 50
# local_maximas detected are 462
# 10%(47 of 462)
# 20%(93 of 462)
# 30%(139 of 462)
# 40%(185 of 462)
# 50%(231 of 462)
# 60%(278 of 462)
# 70%(324 of 462)
# 80%(370 of 462)
# 90%(416 of 462)
# 100%(462 of 462)
# frame number is 51
# local_maximas detected are 494
# 10%(50 of 494)
# 20%(99 of 494)
# 30%(149 of 494)
# 40%(198 of 494)
# 50%(247 of 494)
# 60%(297 of 494)
# 70%(346 of 494)
# 80%(396 of 494)
# 90%(445 of 494)
# 100%(494 of 494)
# frame number is 52
# local_maximas detected are 485
# 10%(49 of 485)
# 20%(97 of 485)
# 30%(146 of 485)
# 40%(194 of 485)
# 50%(243 of 485)
# 60%(291 of 485)
# 70%(340 of 485)
# 80%(388 of 485)
# 90%(437 of 485)
# 100%(485 of 485)
# frame number is 53
# local_maximas detected are 463
# 10%(47 of 463)
# 20%(93 of 463)
# 30%(139 of 463)
# 40%(186 of 463)
# 50%(232 of 463)
# 60%(278 of 463)
# 70%(325 of 463)
# 80%(371 of 463)
# 90%(417 of 463)
# 100%(463 of 463)
# frame number is 54
# local_maximas detected are 465
# 10%(47 of 465)
# 20%(93 of 465)
# 30%(140 of 465)
# 40%(186 of 465)
# 50%(233 of 465)
# 60%(279 of 465)
# 70%(326 of 465)
# 80%(372 of 465)
# 90%(419 of 465)
# 100%(465 of 465)
# frame number is 55
# local_maximas detected are 469
# 10%(47 of 469)
# 20%(94 of 469)
# 30%(141 of 469)
# 40%(188 of 469)
# 50%(235 of 469)
# 60%(282 of 469)
# 70%(329 of 469)
# 80%(376 of 469)
# 90%(423 of 469)
# 100%(469 of 469)
# frame number is 56
# local_maximas detected are 457
# 10%(46 of 457)
# 20%(92 of 457)
# 30%(138 of 457)
# 40%(183 of 457)
# 50%(229 of 457)
# 60%(275 of 457)
# 70%(320 of 457)
# 80%(366 of 457)
# 90%(412 of 457)
# 100%(457 of 457)
# frame number is 57
# local_maximas detected are 458
# 10%(46 of 458)
# 20%(92 of 458)
# 30%(138 of 458)
# 40%(184 of 458)
# 50%(229 of 458)
# 60%(275 of 458)
# 70%(321 of 458)
# 80%(367 of 458)
# 90%(413 of 458)
# 100%(458 of 458)
# frame number is 58
# local_maximas detected are 457
# 10%(46 of 457)
# 20%(92 of 457)
# 30%(138 of 457)
# 40%(183 of 457)
# 50%(229 of 457)
# 60%(275 of 457)
# 70%(320 of 457)
# 80%(366 of 457)
# 90%(412 of 457)
# 100%(457 of 457)
# frame number is 59
# local_maximas detected are 451
# 10%(46 of 451)
# 20%(91 of 451)
# 30%(136 of 451)
# 40%(181 of 451)
# 50%(226 of 451)
# 60%(271 of 451)
# 70%(316 of 451)
# 80%(361 of 451)
# 90%(406 of 451)
# 100%(451 of 451)
# frame number is 60
# local_maximas detected are 460
# 10%(46 of 460)
# 20%(92 of 460)
# 30%(138 of 460)
# 40%(184 of 460)
# 50%(230 of 460)
# 60%(276 of 460)
# 70%(322 of 460)
# 80%(368 of 460)
# 90%(414 of 460)
# 100%(460 of 460)
# frame number is 61
# local_maximas detected are 444
# 10%(45 of 444)
# 20%(89 of 444)
# 30%(134 of 444)
# 40%(178 of 444)
# 50%(222 of 444)
# 60%(267 of 444)
# 70%(311 of 444)
# 80%(356 of 444)
# 90%(400 of 444)
# 100%(444 of 444)
# frame number is 62
# local_maximas detected are 486
# 10%(49 of 486)
# 20%(98 of 486)
# 30%(146 of 486)
# 40%(195 of 486)
# 50%(243 of 486)
# 60%(292 of 486)
# 70%(341 of 486)
# 80%(389 of 486)
# 90%(438 of 486)
# 100%(486 of 486)
# the gaussian did not fit
# frame number is 63
# local_maximas detected are 452
# 10%(46 of 452)
# 20%(91 of 452)
# 30%(136 of 452)
# 40%(181 of 452)
# 50%(226 of 452)
# 60%(272 of 452)
# 70%(317 of 452)
# 80%(362 of 452)
# 90%(407 of 452)
# 100%(452 of 452)
# frame number is 64
# local_maximas detected are 437
# 10%(44 of 437)
# 20%(88 of 437)
# 30%(132 of 437)
# 40%(175 of 437)
# 50%(219 of 437)
# 60%(263 of 437)
# 70%(306 of 437)
# 80%(350 of 437)
# 90%(394 of 437)
# 100%(437 of 437)
# frame number is 65
# local_maximas detected are 432
# 10%(44 of 432)
# 20%(87 of 432)
# 30%(130 of 432)
# 40%(173 of 432)
# 50%(216 of 432)
# 60%(260 of 432)
# 70%(303 of 432)
# 80%(346 of 432)
# 90%(389 of 432)
# 100%(432 of 432)
# frame number is 66
# local_maximas detected are 455
# 10%(46 of 455)
# 20%(91 of 455)
# 30%(137 of 455)
# 40%(182 of 455)
# 50%(228 of 455)
# 60%(273 of 455)
# 70%(319 of 455)
# 80%(364 of 455)
# 90%(410 of 455)
# 100%(455 of 455)
# frame number is 67
# local_maximas detected are 450
# 10%(45 of 450)
# 20%(90 of 450)
# 30%(135 of 450)
# 40%(180 of 450)
# 50%(225 of 450)
# 60%(270 of 450)
# 70%(315 of 450)
# 80%(360 of 450)
# 90%(405 of 450)
# 100%(450 of 450)
# frame number is 68
# local_maximas detected are 451
# 10%(46 of 451)
# 20%(91 of 451)
# 30%(136 of 451)
# 40%(181 of 451)
# 50%(226 of 451)
# 60%(271 of 451)
# 70%(316 of 451)
# 80%(361 of 451)
# 90%(406 of 451)
# 100%(451 of 451)
# frame number is 69
# local_maximas detected are 465
# 10%(47 of 465)
# 20%(93 of 465)
# 30%(140 of 465)
# 40%(186 of 465)
# 50%(233 of 465)
# 60%(279 of 465)
# 70%(326 of 465)
# 80%(372 of 465)
# 90%(419 of 465)
# 100%(465 of 465)
# frame number is 70
# local_maximas detected are 438
# 10%(44 of 438)
# 20%(88 of 438)
# 30%(132 of 438)
# 40%(176 of 438)
# 50%(219 of 438)
# 60%(263 of 438)
# 70%(307 of 438)
# 80%(351 of 438)
# 90%(395 of 438)
# 100%(438 of 438)
# frame number is 71
# local_maximas detected are 450
# 10%(45 of 450)
# 20%(90 of 450)
# 30%(135 of 450)
# 40%(180 of 450)
# 50%(225 of 450)
# 60%(270 of 450)
# 70%(315 of 450)
# 80%(360 of 450)
# 90%(405 of 450)
# 100%(450 of 450)
# frame number is 72
# local_maximas detected are 459
# 10%(46 of 459)
# 20%(92 of 459)
# 30%(138 of 459)
# 40%(184 of 459)
# 50%(230 of 459)
# 60%(276 of 459)
# 70%(322 of 459)
# 80%(368 of 459)
# 90%(414 of 459)
# 100%(459 of 459)
# frame number is 73
# local_maximas detected are 457
# 10%(46 of 457)
# 20%(92 of 457)
# 30%(138 of 457)
# 40%(183 of 457)
# 50%(229 of 457)
# 60%(275 of 457)
# 70%(320 of 457)
# 80%(366 of 457)
# 90%(412 of 457)
# 100%(457 of 457)
# frame number is 74
# local_maximas detected are 456
# 10%(46 of 456)
# 20%(92 of 456)
# 30%(137 of 456)
# 40%(183 of 456)
# 50%(228 of 456)
# 60%(274 of 456)
# 70%(320 of 456)
# 80%(365 of 456)
# 90%(411 of 456)
# 100%(456 of 456)
# frame number is 75
# local_maximas detected are 434
# 10%(44 of 434)
# 20%(87 of 434)
# 30%(131 of 434)
# 40%(174 of 434)
# 50%(217 of 434)
# 60%(261 of 434)
# 70%(304 of 434)
# 80%(348 of 434)
# 90%(391 of 434)
# 100%(434 of 434)
# frame number is 76
# local_maximas detected are 431
# 10%(44 of 431)
# 20%(87 of 431)
# 30%(130 of 431)
# 40%(173 of 431)
# 50%(216 of 431)
# 60%(259 of 431)
# 70%(302 of 431)
# 80%(345 of 431)
# 90%(388 of 431)
# 100%(431 of 431)
# frame number is 77
# local_maximas detected are 424
# 10%(43 of 424)
# 20%(85 of 424)
# 30%(128 of 424)
# 40%(170 of 424)
# 50%(212 of 424)
# 60%(255 of 424)
# 70%(297 of 424)
# 80%(340 of 424)
# 90%(382 of 424)
# 100%(424 of 424)
# frame number is 78
# local_maximas detected are 439
# 10%(44 of 439)
# 20%(88 of 439)
# 30%(132 of 439)
# 40%(176 of 439)
# 50%(220 of 439)
# 60%(264 of 439)
# 70%(308 of 439)
# 80%(352 of 439)
# 90%(396 of 439)
# 100%(439 of 439)
# frame number is 79
# local_maximas detected are 434
# 10%(44 of 434)
# 20%(87 of 434)
# 30%(131 of 434)
# 40%(174 of 434)
# 50%(217 of 434)
# 60%(261 of 434)
# 70%(304 of 434)
# 80%(348 of 434)
# 90%(391 of 434)
# 100%(434 of 434)
# frame number is 80
# local_maximas detected are 444
# 10%(45 of 444)
# 20%(89 of 444)
# 30%(134 of 444)
# 40%(178 of 444)
# 50%(222 of 444)
# 60%(267 of 444)
# 70%(311 of 444)
# 80%(356 of 444)
# 90%(400 of 444)
# 100%(444 of 444)
# frame number is 81
# local_maximas detected are 428
# 10%(43 of 428)
# 20%(86 of 428)
# 30%(129 of 428)
# 40%(172 of 428)
# 50%(214 of 428)
# 60%(257 of 428)
# 70%(300 of 428)
# 80%(343 of 428)
# 90%(386 of 428)
# 100%(428 of 428)
# frame number is 82
# local_maximas detected are 420
# 10%(42 of 420)
# 20%(84 of 420)
# 30%(126 of 420)
# 40%(168 of 420)
# 50%(210 of 420)
# 60%(252 of 420)
# 70%(294 of 420)
# 80%(336 of 420)
# 90%(378 of 420)
# 100%(420 of 420)
# frame number is 83
# local_maximas detected are 427
# 10%(43 of 427)
# 20%(86 of 427)
# 30%(129 of 427)
# 40%(171 of 427)
# 50%(214 of 427)
# 60%(257 of 427)
# 70%(299 of 427)
# 80%(342 of 427)
# 90%(385 of 427)
# 100%(427 of 427)
# frame number is 84
# local_maximas detected are 429
# 10%(43 of 429)
# 20%(86 of 429)
# 30%(129 of 429)
# 40%(172 of 429)
# 50%(215 of 429)
# 60%(258 of 429)
# 70%(301 of 429)
# 80%(344 of 429)
# 90%(387 of 429)
# 100%(429 of 429)
# frame number is 85
# local_maximas detected are 415
# 10%(42 of 415)
# 20%(83 of 415)
# 30%(125 of 415)
# 40%(166 of 415)
# 50%(208 of 415)
# 60%(249 of 415)
# 70%(291 of 415)
# 80%(332 of 415)
# 90%(374 of 415)
# 100%(415 of 415)
# frame number is 86
# local_maximas detected are 423
# 10%(43 of 423)
# 20%(85 of 423)
# 30%(127 of 423)
# 40%(170 of 423)
# 50%(212 of 423)
# 60%(254 of 423)
# 70%(297 of 423)
# 80%(339 of 423)
# 90%(381 of 423)
# 100%(423 of 423)
# frame number is 87
# local_maximas detected are 429
# 10%(43 of 429)
# 20%(86 of 429)
# 30%(129 of 429)
# 40%(172 of 429)
# 50%(215 of 429)
# 60%(258 of 429)
# 70%(301 of 429)
# 80%(344 of 429)
# 90%(387 of 429)
# 100%(429 of 429)
# frame number is 88
# local_maximas detected are 426
# 10%(43 of 426)
# 20%(86 of 426)
# 30%(128 of 426)
# 40%(171 of 426)
# 50%(213 of 426)
# 60%(256 of 426)
# 70%(299 of 426)
# 80%(341 of 426)
# 90%(384 of 426)
# 100%(426 of 426)
# frame number is 89
# local_maximas detected are 414
# 10%(42 of 414)
# 20%(83 of 414)
# 30%(125 of 414)
# 40%(166 of 414)
# 50%(207 of 414)
# 60%(249 of 414)
# 70%(290 of 414)
# 80%(332 of 414)
# 90%(373 of 414)
# 100%(414 of 414)
# frame number is 90
# local_maximas detected are 418
# 10%(42 of 418)
# 20%(84 of 418)
# 30%(126 of 418)
# 40%(168 of 418)
# 50%(209 of 418)
# 60%(251 of 418)
# 70%(293 of 418)
# 80%(335 of 418)
# 90%(377 of 418)
# 100%(418 of 418)
# frame number is 91
# local_maximas detected are 427
# 10%(43 of 427)
# 20%(86 of 427)
# 30%(129 of 427)
# 40%(171 of 427)
# 50%(214 of 427)
# 60%(257 of 427)
# 70%(299 of 427)
# 80%(342 of 427)
# 90%(385 of 427)
# 100%(427 of 427)
# frame number is 92
# local_maximas detected are 426
# 10%(43 of 426)
# 20%(86 of 426)
# 30%(128 of 426)
# 40%(171 of 426)
# 50%(213 of 426)
# 60%(256 of 426)
# 70%(299 of 426)
# 80%(341 of 426)
# 90%(384 of 426)
# 100%(426 of 426)
# frame number is 93
# local_maximas detected are 422
# 10%(43 of 422)
# 20%(85 of 422)
# 30%(127 of 422)
# 40%(169 of 422)
# 50%(211 of 422)
# 60%(254 of 422)
# 70%(296 of 422)
# 80%(338 of 422)
# 90%(380 of 422)
# 100%(422 of 422)
# frame number is 94
# local_maximas detected are 411
# 10%(42 of 411)
# 20%(83 of 411)
# 30%(124 of 411)
# 40%(165 of 411)
# 50%(206 of 411)
# 60%(247 of 411)
# 70%(288 of 411)
# 80%(329 of 411)
# 90%(370 of 411)
# 100%(411 of 411)
# frame number is 95
# local_maximas detected are 393
# 10%(40 of 393)
# 20%(79 of 393)
# 30%(118 of 393)
# 40%(158 of 393)
# 50%(197 of 393)
# 60%(236 of 393)
# 70%(276 of 393)
# 80%(315 of 393)
# 90%(354 of 393)
# 100%(393 of 393)
# frame number is 96
# local_maximas detected are 427
# 10%(43 of 427)
# 20%(86 of 427)
# 30%(129 of 427)
# 40%(171 of 427)
# 50%(214 of 427)
# 60%(257 of 427)
# 70%(299 of 427)
# 80%(342 of 427)
# 90%(385 of 427)
# 100%(427 of 427)
# frame number is 97
# local_maximas detected are 418
# 10%(42 of 418)
# 20%(84 of 418)
# 30%(126 of 418)
# 40%(168 of 418)
# 50%(209 of 418)
# 60%(251 of 418)
# 70%(293 of 418)
# 80%(335 of 418)
# 90%(377 of 418)
# 100%(418 of 418)
# frame number is 98
# local_maximas detected are 408
# 10%(41 of 408)
# 20%(82 of 408)
# 30%(123 of 408)
# 40%(164 of 408)
# 50%(204 of 408)
# 60%(245 of 408)
# 70%(286 of 408)
# 80%(327 of 408)
# 90%(368 of 408)
# 100%(408 of 408)
# frame number is 99
# local_maximas detected are 431
# 10%(44 of 431)
# 20%(87 of 431)
# 30%(130 of 431)
# 40%(173 of 431)
# 50%(216 of 431)
# 60%(259 of 431)
# 70%(302 of 431)
# 80%(345 of 431)
# 90%(388 of 431)
# 100%(431 of 431)
# the gaussian did not fit
# frame number is 100
# local_maximas detected are 409
# 10%(41 of 409)
# 20%(82 of 409)
# 30%(123 of 409)
# 40%(164 of 409)
# 50%(205 of 409)
# 60%(246 of 409)
# 70%(287 of 409)
# 80%(328 of 409)
# 90%(369 of 409)
# 100%(409 of 409)
# frame number is 101
# local_maximas detected are 423
# 10%(43 of 423)
# 20%(85 of 423)
# 30%(127 of 423)
# 40%(170 of 423)
# 50%(212 of 423)
# 60%(254 of 423)
# 70%(297 of 423)
# 80%(339 of 423)
# 90%(381 of 423)
# 100%(423 of 423)
# frame number is 102
# local_maximas detected are 408
# 10%(41 of 408)
# 20%(82 of 408)
# 30%(123 of 408)
# 40%(164 of 408)
# 50%(204 of 408)
# 60%(245 of 408)
# 70%(286 of 408)
# 80%(327 of 408)
# 90%(368 of 408)
# 100%(408 of 408)
# frame number is 103
# local_maximas detected are 419
# 10%(42 of 419)
# 20%(84 of 419)
# 30%(126 of 419)
# 40%(168 of 419)
# 50%(210 of 419)
# 60%(252 of 419)
# 70%(294 of 419)
# 80%(336 of 419)
# 90%(378 of 419)
# 100%(419 of 419)
# frame number is 104
# local_maximas detected are 399
# 10%(40 of 399)
# 20%(80 of 399)
# 30%(120 of 399)
# 40%(160 of 399)
# 50%(200 of 399)
# 60%(240 of 399)
# 70%(280 of 399)
# 80%(320 of 399)
# 90%(360 of 399)
# 100%(399 of 399)
# frame number is 105
# local_maximas detected are 394
# 10%(40 of 394)
# 20%(79 of 394)
# 30%(119 of 394)
# 40%(158 of 394)
# 50%(197 of 394)
# 60%(237 of 394)
# 70%(276 of 394)
# 80%(316 of 394)
# 90%(355 of 394)
# 100%(394 of 394)
# frame number is 106
# local_maximas detected are 397
# 10%(40 of 397)
# 20%(80 of 397)
# 30%(120 of 397)
# 40%(159 of 397)
# 50%(199 of 397)
# 60%(239 of 397)
# 70%(278 of 397)
# 80%(318 of 397)
# 90%(358 of 397)
# 100%(397 of 397)
# frame number is 107
# local_maximas detected are 375
# 10%(38 of 375)
# 20%(75 of 375)
# 30%(113 of 375)
# 40%(150 of 375)
# 50%(188 of 375)
# 60%(225 of 375)
# 70%(263 of 375)
# 80%(300 of 375)
# 90%(338 of 375)
# 100%(375 of 375)
# frame number is 108
# local_maximas detected are 398
# 10%(40 of 398)
# 20%(80 of 398)
# 30%(120 of 398)
# 40%(160 of 398)
# 50%(199 of 398)
# 60%(239 of 398)
# 70%(279 of 398)
# 80%(319 of 398)
# 90%(359 of 398)
# 100%(398 of 398)
# frame number is 109
# local_maximas detected are 387
# 10%(39 of 387)
# 20%(78 of 387)
# 30%(117 of 387)
# 40%(155 of 387)
# 50%(194 of 387)
# 60%(233 of 387)
# 70%(271 of 387)
# 80%(310 of 387)
# 90%(349 of 387)
# 100%(387 of 387)
# frame number is 110
# local_maximas detected are 360
# 10%(36 of 360)
# 20%(72 of 360)
# 30%(108 of 360)
# 40%(144 of 360)
# 50%(180 of 360)
# 60%(216 of 360)
# 70%(252 of 360)
# 80%(288 of 360)
# 90%(324 of 360)
# 100%(360 of 360)
# frame number is 111
# local_maximas detected are 413
# 10%(42 of 413)
# 20%(83 of 413)
# 30%(124 of 413)
# 40%(166 of 413)
# 50%(207 of 413)
# 60%(248 of 413)
# 70%(290 of 413)
# 80%(331 of 413)
# 90%(372 of 413)
# 100%(413 of 413)
# frame number is 112
# local_maximas detected are 390
# 10%(39 of 390)
# 20%(78 of 390)
# 30%(117 of 390)
# 40%(156 of 390)
# 50%(195 of 390)
# 60%(234 of 390)
# 70%(273 of 390)
# 80%(312 of 390)
# 90%(351 of 390)
# 100%(390 of 390)
# frame number is 113
# local_maximas detected are 390
# 10%(39 of 390)
# 20%(78 of 390)
# 30%(117 of 390)
# 40%(156 of 390)
# 50%(195 of 390)
# 60%(234 of 390)
# 70%(273 of 390)
# 80%(312 of 390)
# 90%(351 of 390)
# 100%(390 of 390)
# frame number is 114
# local_maximas detected are 378
# 10%(38 of 378)
# 20%(76 of 378)
# 30%(114 of 378)
# 40%(152 of 378)
# 50%(189 of 378)
# 60%(227 of 378)
# 70%(265 of 378)
# 80%(303 of 378)
# 90%(341 of 378)
# 100%(378 of 378)
# frame number is 115
# local_maximas detected are 370
# 10%(37 of 370)
# 20%(74 of 370)
# 30%(111 of 370)
# 40%(148 of 370)
# 50%(185 of 370)
# 60%(222 of 370)
# 70%(259 of 370)
# 80%(296 of 370)
# 90%(333 of 370)
# 100%(370 of 370)
# frame number is 116
# local_maximas detected are 379
# 10%(38 of 379)
# 20%(76 of 379)
# 30%(114 of 379)
# 40%(152 of 379)
# 50%(190 of 379)
# 60%(228 of 379)
# 70%(266 of 379)
# 80%(304 of 379)
# 90%(342 of 379)
# 100%(379 of 379)
# frame number is 117
# local_maximas detected are 357
# 10%(36 of 357)
# 20%(72 of 357)
# 30%(108 of 357)
# 40%(143 of 357)
# 50%(179 of 357)
# 60%(215 of 357)
# 70%(250 of 357)
# 80%(286 of 357)
# 90%(322 of 357)
# 100%(357 of 357)
# frame number is 118
# local_maximas detected are 371
# 10%(38 of 371)
# 20%(75 of 371)
# 30%(112 of 371)
# 40%(149 of 371)
# 50%(186 of 371)
# 60%(223 of 371)
# 70%(260 of 371)
# 80%(297 of 371)
# 90%(334 of 371)
# 100%(371 of 371)
# frame number is 119
# local_maximas detected are 360
# 10%(36 of 360)
# 20%(72 of 360)
# 30%(108 of 360)
# 40%(144 of 360)
# 50%(180 of 360)
# 60%(216 of 360)
# 70%(252 of 360)
# 80%(288 of 360)
# 90%(324 of 360)
# 100%(360 of 360)
# frame number is 120
# local_maximas detected are 354
# 10%(36 of 354)
# 20%(71 of 354)
# 30%(107 of 354)
# 40%(142 of 354)
# 50%(177 of 354)
# 60%(213 of 354)
# 70%(248 of 354)
# 80%(284 of 354)
# 90%(319 of 354)
# 100%(354 of 354)
# frame number is 121
# local_maximas detected are 345
# 10%(35 of 345)
# 20%(69 of 345)
# 30%(104 of 345)
# 40%(138 of 345)
# 50%(173 of 345)
# 60%(207 of 345)
# 70%(242 of 345)
# 80%(276 of 345)
# 90%(311 of 345)
# 100%(345 of 345)
# frame number is 122
# local_maximas detected are 362
# 10%(37 of 362)
# 20%(73 of 362)
# 30%(109 of 362)
# 40%(145 of 362)
# 50%(181 of 362)
# 60%(218 of 362)
# 70%(254 of 362)
# 80%(290 of 362)
# 90%(326 of 362)
# 100%(362 of 362)
# frame number is 123
# local_maximas detected are 358
# 10%(36 of 358)
# 20%(72 of 358)
# 30%(108 of 358)
# 40%(144 of 358)
# 50%(179 of 358)
# 60%(215 of 358)
# 70%(251 of 358)
# 80%(287 of 358)
# 90%(323 of 358)
# 100%(358 of 358)
# frame number is 124
# local_maximas detected are 349
# 10%(35 of 349)
# 20%(70 of 349)
# 30%(105 of 349)
# 40%(140 of 349)
# 50%(175 of 349)
# 60%(210 of 349)
# 70%(245 of 349)
# 80%(280 of 349)
# 90%(315 of 349)
# 100%(349 of 349)
# frame number is 125
# local_maximas detected are 349
# 10%(35 of 349)
# 20%(70 of 349)
# 30%(105 of 349)
# 40%(140 of 349)
# 50%(175 of 349)
# 60%(210 of 349)
# 70%(245 of 349)
# 80%(280 of 349)
# 90%(315 of 349)
# 100%(349 of 349)
# frame number is 126
# local_maximas detected are 344
# 10%(35 of 344)
# 20%(69 of 344)
# 30%(104 of 344)
# 40%(138 of 344)
# 50%(172 of 344)
# 60%(207 of 344)
# 70%(241 of 344)
# 80%(276 of 344)
# 90%(310 of 344)
# 100%(344 of 344)
# frame number is 127
# local_maximas detected are 348
# 10%(35 of 348)
# 20%(70 of 348)
# 30%(105 of 348)
# 40%(140 of 348)
# 50%(174 of 348)
# 60%(209 of 348)
# 70%(244 of 348)
# 80%(279 of 348)
# 90%(314 of 348)
# 100%(348 of 348)
# the gaussian did not fit
# frame number is 128
# local_maximas detected are 335
# 10%(34 of 335)
# 20%(67 of 335)
# 30%(101 of 335)
# 40%(134 of 335)
# 50%(168 of 335)
# 60%(201 of 335)
# 70%(235 of 335)
# 80%(268 of 335)
# 90%(302 of 335)
# 100%(335 of 335)
# frame number is 129
# local_maximas detected are 349
# 10%(35 of 349)
# 20%(70 of 349)
# 30%(105 of 349)
# 40%(140 of 349)
# 50%(175 of 349)
# 60%(210 of 349)
# 70%(245 of 349)
# 80%(280 of 349)
# 90%(315 of 349)
# 100%(349 of 349)
# time taken (seconds) 1196.535185098648
