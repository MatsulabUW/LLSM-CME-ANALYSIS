# %% [markdown]
# # Measure intensity for all channels based on coordinates from the tracked channel

# %%
from os import path
import pandas as pd
from IPython.display import display
import numpy as np 
import sys 
import time 
import zarr
import glob
import os
import re
import matplotlib.pyplot as plt

pythonPackagePath = os.path.abspath(r'C:\Users\Kenny\LLSM-CME-ANALYSIS\Final\src')
sys.path.append(pythonPackagePath)

from extract_pixel_data import Extractor

# %% [markdown]
# Do not change the code in the cell below

# %%
base_dir =  r'\\10.158.28.194\ActiveNAS\Kenny'
input_file_directory = 'lumenoid_2_analysis/'

# If a folder named 'datasets' doesn't exist in base_dir + input_file_directory, it will be created
if not os.path.exists(os.path.join(base_dir, input_file_directory, 'datasets')):
    os.makedirs(os.path.join(base_dir, input_file_directory, 'datasets'))

zarr_file_directory = input_file_directory + 'zarr_file/all_channels_data'
zarr_full_path = os.path.join(base_dir, zarr_file_directory)

input_directory = os.path.join(base_dir, input_file_directory) + 'tracks/Channel_1_tracking_result.pkl'
# input_directory = os.path.join(base_dir, input_file_directory) + 'tracking_results/12/Channel_1_tracking_result_12.pkl'

# List which channel was used for detection and tracking
channel_detected = 3

output_directory = 'datasets'
output_file_name = 'track_df_cleaned_final_full.pkl'
output_directory_full = os.path.join(base_dir, input_file_directory, output_directory, output_file_name)

# %%
track_df = pd.read_pickle(input_directory)
# read the zarr file which contains the data of all three channels 
z = zarr.open(zarr_full_path, mode='r')

# Add columns sigma_z, sigma_y, sigma_x to track_df with values 3, 2, 2
track_df['sigma_z'] = 3
track_df['sigma_y'] = 2
track_df['sigma_x'] = 2

# Dropping rows of track_df with NaN values in mu_z, mu_y, mu_x, and amplitude.
track_df_cleaned = track_df.dropna(subset=['mu_z', 'mu_y', 'mu_x', 'amplitude']).copy()
# Move frame back by 1 for track_df_cleaned, such that 1 is 0, 2 is 1, 120 is 119, etc. Don't try to set the value on a copy of a slice from a DataFrame
track_df_cleaned.loc[:, 'frame'] = track_df_cleaned['frame'] - 1
# Sorting tracks by frame, this is crucial for accuracy of the background corrected intensity measurement
track_df_cleaned = track_df_cleaned.sort_values(by=['frame']).reset_index(drop=True)

# %%
track_df_cleaned.head()
# Out:
#    frame   mu_x   mu_y  mu_z  amplitude  track_id  segment_id  sigma_z  \
# 0      0  126.0  523.0  34.0      533.0      2213         NaN        3
# 1      0  159.0  422.0  37.0       17.0      2212         NaN        3
# 2      0   98.0  483.0  38.0      372.0      2222         NaN        3
# 3      0   90.0  533.0  38.0       36.0      2221         NaN        3
# 4      0   85.0  352.0  37.0     1199.0      2220         NaN        3
#
#    sigma_y  sigma_x
# 0        2        2
# 1        2        2
# 2        2        2
# 3        2        2
# 4        2        2

# %% [markdown]
# The following parameters usually don't have to be adjusted, but you can adjust them based on the sizes of your spots

# %%
# radii for sum intensity ("voxel sum") calculation, in [z,y,x]. a radius of 2 will measure 5 pixels across
radii_extractor = [3,2,2] 

# the radius (in pixels) of the shell for background subtraction
# used in "_voxel_sum_adjusted" calculation
background_radius_for_voxel_sum = [1,1,1] 

# number of CPUs used for parallel processing; this isn't currently used
n_cores = -1

# %% [markdown]
# Optionally set an offset value in XY between channel 2 and 3

# %%
# If you see an offset between the cameras (channel 2 and 3), set that value here to correct for it.
# For example, if channel 2 shows up 4 pixels to the right of channel 2, set offset_x_ch2vs3 to 4

offset_x_ch2vs3 = 0
offset_y_ch2vs3 = 0

offset_ch2vs3 = [offset_y_ch2vs3, offset_x_ch2vs3]


# this line reverses the offset if you detected channel 2
if channel_detected == 2:
    offset_ch3vs2 = [-offset_ch2vs3[0], -offset_ch2vs3[1]]
else:
    offset_ch3vs2 = [0,0]
# if you don't know the offset, it will be estimated below

# %% [markdown]
# Calculate intensities for three channels

# %%
extractor = Extractor(z, dataframe = track_df_cleaned, radii=radii_extractor, frame_col_name = 'frame', 
                      radi_col_name = ['sigma_z', 'sigma_y', 'sigma_x'], n_jobs = n_cores)

channels_list = [1,2,3]

for channel in channels_list:

    offset = [0, 0]
    # need to verify that this offset works in the right direction
    if channel_detected == 2 and channel == 2:
        offset = offset_ch3vs2

    if channel_detected != 2 and channel == 2:
        offset = offset_ch2vs3

    col_names = ['mu_z', 'mu_y', 'mu_x']

    # calculate mean, max, sum intensity around the track coordinates
    peak_mean,peak_max,_,_,peak_loc,peak_sum = extractor.extract_pixels_data_fixed_bd(center_col_names = col_names, 
                                                        channel = channel, offset = offset)

    # calculate background subtracted sum intensity: "adjusted voxel sum"
    # voxel_sum_array, _, adj_voxel_sum, adj_voxel_sum_vol, vol_sig, vol_bg  = extractor.voxel_sum_fixed_background(center_col_names = ['mu_z', 'mu_y', 'mu_x'], channel = channel,                                                                            
        # background_radius=background_radius_for_voxel_sum, offset=offset)

    voxel_sum_array, _, _, adj_voxel_sum_vol, vol_sig, vol_bg  = extractor.voxel_sum_fixed_background(center_col_names = ['mu_z', 'mu_y', 'mu_x'], channel = channel,                                                                            
        background_radius=background_radius_for_voxel_sum, offset=offset)

    track_df_cleaned.loc[:,f'c{channel}_peak_mean']= peak_mean
    track_df_cleaned.loc[:,f'c{channel}_peak_max'] = peak_max
    track_df_cleaned.loc[:,f'c{channel}_voxel_sum'] = peak_sum
    # track_df_cleaned.loc[:,f'c{channel}_voxel_sum_adjusted'] = adj_voxel_sum
    track_df_cleaned.loc[:,f'c{channel}_voxel_sum_adjusted'] = adj_voxel_sum_vol
    track_df_cleaned.loc[:,f'c{channel}_peak_x'] = [t[2] for t in peak_loc]
    track_df_cleaned.loc[:,f'c{channel}_peak_y'] = [t[1] for t in peak_loc]
    track_df_cleaned.loc[:,f'c{channel}_peak_z'] = [t[0] for t in peak_loc]
    track_df_cleaned.loc[:,f'c{channel}_vol_sig'] = vol_sig
    track_df_cleaned.loc[:,f'c{channel}_vol_bg'] = vol_bg
    
    print(f'Channel {channel} done')

track_df_cleaned.to_pickle(output_directory_full)
print(f'Track intensities saved, you can continue to the next notebook.')
# track_df.head()
# Out:
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 11 z: 39.0 y: 281.0 x: 133.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 11 z: 39.0 y: 281.0 x: 133.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 12 z: 38.0 y: 282.0 x: 131.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 12 z: 38.0 y: 282.0 x: 131.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 17 z: 55.0 y: 221.0 x: 161.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 17 z: 55.0 y: 221.0 x: 161.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 25 z: 58.0 y: 218.0 x: 171.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 25 z: 58.0 y: 218.0 x: 171.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 26 z: 111.0 y: 91.0 x: 215.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 26 z: 111.0 y: 91.0 x: 215.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 28 z: 26.0 y: 283.0 x: 130.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 28 z: 26.0 y: 283.0 x: 130.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 31 z: 42.0 y: 355.0 x: 125.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 31 z: 42.0 y: 355.0 x: 125.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 39 z: 43.0 y: 349.0 x: 129.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 39 z: 43.0 y: 349.0 x: 129.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 40 z: 41.0 y: 352.0 x: 128.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 40 z: 41.0 y: 352.0 x: 128.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 47 z: 42.0 y: 280.0 x: 141.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 47 z: 42.0 y: 280.0 x: 141.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 48 z: 45.0 y: 280.0 x: 141.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 48 z: 45.0 y: 280.0 x: 141.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 48 z: 60.0 y: 219.0 x: 160.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 48 z: 60.0 y: 219.0 x: 160.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 49 z: 56.0 y: 217.0 x: 159.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 49 z: 56.0 y: 217.0 x: 159.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 54 z: 99.0 y: 182.0 x: 177.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 54 z: 99.0 y: 182.0 x: 177.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 56 z: 71.0 y: 170.0 x: 169.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 56 z: 71.0 y: 170.0 x: 169.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 57 z: 53.0 y: 274.0 x: 144.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 57 z: 53.0 y: 274.0 x: 144.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 58 z: 69.0 y: 170.0 x: 167.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 58 z: 69.0 y: 170.0 x: 167.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 64 z: 80.0 y: 226.0 x: 170.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 64 z: 80.0 y: 226.0 x: 170.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 65 z: 80.0 y: 227.0 x: 172.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 65 z: 80.0 y: 227.0 x: 172.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 65 z: 84.0 y: 171.0 x: 179.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 65 z: 84.0 y: 171.0 x: 179.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 65 z: 46.0 y: 346.0 x: 132.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 65 z: 46.0 y: 346.0 x: 132.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 68 z: 25.0 y: 353.0 x: 119.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 68 z: 25.0 y: 353.0 x: 119.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 69 z: 26.0 y: 355.0 x: 119.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 69 z: 26.0 y: 355.0 x: 119.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 70 z: 47.0 y: 355.0 x: 120.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 70 z: 47.0 y: 355.0 x: 120.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 70 z: 74.0 y: 173.0 x: 172.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 70 z: 74.0 y: 173.0 x: 172.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 71 z: 49.0 y: 358.0 x: 120.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 71 z: 49.0 y: 358.0 x: 120.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 73 z: 38.0 y: 211.0 x: 168.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 73 z: 38.0 y: 211.0 x: 168.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 73 z: 75.0 y: 174.0 x: 166.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 73 z: 75.0 y: 174.0 x: 166.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 73 z: 82.0 y: 174.0 x: 178.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 73 z: 82.0 y: 174.0 x: 178.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 74 z: 77.0 y: 171.0 x: 168.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 74 z: 77.0 y: 171.0 x: 168.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 74 z: 80.0 y: 177.0 x: 177.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 74 z: 80.0 y: 177.0 x: 177.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 76 z: 40.0 y: 213.0 x: 172.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 76 z: 40.0 y: 213.0 x: 172.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 76 z: 48.0 y: 227.0 x: 157.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 76 z: 48.0 y: 227.0 x: 157.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 77 z: 41.0 y: 213.0 x: 168.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 77 z: 41.0 y: 213.0 x: 168.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 78 z: 38.0 y: 212.0 x: 168.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 78 z: 38.0 y: 212.0 x: 168.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 78 z: 38.0 y: 220.0 x: 168.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 78 z: 38.0 y: 220.0 x: 168.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 79 z: 78.0 y: 170.0 x: 169.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 79 z: 78.0 y: 170.0 x: 169.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 80 z: 77.0 y: 170.0 x: 166.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 80 z: 77.0 y: 170.0 x: 166.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 80 z: 37.0 y: 217.0 x: 167.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 80 z: 37.0 y: 217.0 x: 167.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 80 z: 42.0 y: 349.0 x: 136.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 80 z: 42.0 y: 349.0 x: 136.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 80 z: 82.0 y: 158.0 x: 175.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 80 z: 82.0 y: 158.0 x: 175.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 81 z: 36.0 y: 219.0 x: 166.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 81 z: 36.0 y: 219.0 x: 166.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 81 z: 78.0 y: 161.0 x: 174.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 81 z: 78.0 y: 161.0 x: 174.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 81 z: 42.0 y: 351.0 x: 136.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 81 z: 42.0 y: 351.0 x: 136.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 82 z: 50.0 y: 224.0 x: 160.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 82 z: 50.0 y: 224.0 x: 160.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 82 z: 49.0 y: 356.0 x: 120.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 82 z: 49.0 y: 356.0 x: 120.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 82 z: 36.0 y: 218.0 x: 166.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 82 z: 36.0 y: 218.0 x: 166.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 82 z: 36.0 y: 357.0 x: 120.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 82 z: 36.0 y: 357.0 x: 120.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 48.0 y: 283.0 x: 149.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 48.0 y: 283.0 x: 149.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 74.0 y: 174.0 x: 171.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 74.0 y: 174.0 x: 171.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 36.0 y: 216.0 x: 166.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 36.0 y: 216.0 x: 166.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 35.0 y: 354.0 x: 117.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 35.0 y: 354.0 x: 117.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 50.0 y: 220.0 x: 158.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 50.0 y: 220.0 x: 158.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 51.0 y: 212.0 x: 157.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 83 z: 51.0 y: 212.0 x: 157.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 84 z: 73.0 y: 173.0 x: 170.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 84 z: 73.0 y: 173.0 x: 170.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 85 z: 66.0 y: 227.0 x: 163.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 85 z: 66.0 y: 227.0 x: 163.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 85 z: 41.0 y: 217.0 x: 171.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 85 z: 41.0 y: 217.0 x: 171.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 86 z: 63.0 y: 226.0 x: 162.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 86 z: 63.0 y: 226.0 x: 162.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 87 z: 103.0 y: 110.0 x: 200.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 87 z: 103.0 y: 110.0 x: 200.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 89 z: 44.0 y: 286.0 x: 114.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 89 z: 44.0 y: 286.0 x: 114.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 90 z: 52.0 y: 281.0 x: 156.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 90 z: 52.0 y: 281.0 x: 156.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 93 z: 106.0 y: 111.0 x: 200.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 93 z: 106.0 y: 111.0 x: 200.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 94 z: 43.0 y: 354.0 x: 138.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 94 z: 43.0 y: 354.0 x: 138.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 98 z: 59.0 y: 230.0 x: 174.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 98 z: 59.0 y: 230.0 x: 174.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 99 z: 62.0 y: 228.0 x: 173.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 99 z: 62.0 y: 228.0 x: 173.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 100 z: 54.0 y: 228.0 x: 154.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 100 z: 54.0 y: 228.0 x: 154.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 101 z: 58.0 y: 227.0 x: 156.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 101 z: 58.0 y: 227.0 x: 156.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 102 z: 56.0 y: 228.0 x: 158.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 102 z: 56.0 y: 228.0 x: 158.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 104 z: 37.0 y: 228.0 x: 167.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 104 z: 37.0 y: 228.0 x: 167.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 106 z: 44.0 y: 208.0 x: 156.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 106 z: 44.0 y: 208.0 x: 156.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 108 z: 106.0 y: 357.0 x: 265.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 108 z: 106.0 y: 357.0 x: 265.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 109 z: 44.0 y: 358.0 x: 126.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 109 z: 44.0 y: 358.0 x: 126.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 110 z: 39.0 y: 356.0 x: 125.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 110 z: 39.0 y: 356.0 x: 125.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 111 z: 77.0 y: 158.0 x: 180.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 111 z: 77.0 y: 158.0 x: 180.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 112 z: 103.0 y: 107.0 x: 203.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 112 z: 103.0 y: 107.0 x: 203.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 112 z: 74.0 y: 161.0 x: 180.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 112 z: 74.0 y: 161.0 x: 180.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 112 z: 41.0 y: 282.0 x: 114.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 112 z: 41.0 y: 282.0 x: 114.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 113 z: 38.0 y: 281.0 x: 118.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 113 z: 38.0 y: 281.0 x: 118.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 113 z: 46.0 y: 234.0 x: 151.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 113 z: 46.0 y: 234.0 x: 151.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 114 z: 46.0 y: 234.0 x: 153.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 114 z: 46.0 y: 234.0 x: 153.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 116 z: 65.0 y: 165.0 x: 179.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 116 z: 65.0 y: 165.0 x: 179.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 116 z: 55.0 y: 281.0 x: 161.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 116 z: 55.0 y: 281.0 x: 161.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 116 z: 56.0 y: 226.0 x: 168.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 116 z: 56.0 y: 226.0 x: 168.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 117 z: 60.0 y: 228.0 x: 169.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 117 z: 60.0 y: 228.0 x: 169.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 117 z: 55.0 y: 280.0 x: 161.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 117 z: 55.0 y: 280.0 x: 161.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 117 z: 63.0 y: 221.0 x: 161.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 117 z: 63.0 y: 221.0 x: 161.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 65.0 y: 220.0 x: 162.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 65.0 y: 220.0 x: 162.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 47.0 y: 229.0 x: 163.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 47.0 y: 229.0 x: 163.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 57.0 y: 281.0 x: 156.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 57.0 y: 281.0 x: 156.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 73.0 y: 161.0 x: 178.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 73.0 y: 161.0 x: 178.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 118 z: 104.0 y: 352.0 x: 268.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# ...
# Channel: 1 Frame: 126 z: 62.0 y: 235.0 x: 154.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 126 z: 62.0 y: 235.0 x: 154.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 126 z: 66.0 y: 509.0 x: 214.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 126 z: 66.0 y: 509.0 x: 214.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 126 z: 64.0 y: 172.0 x: 178.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 126 z: 64.0 y: 172.0 x: 178.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 127 z: 67.0 y: 174.0 x: 177.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 127 z: 67.0 y: 174.0 x: 177.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 128 z: 37.0 y: 276.0 x: 116.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 128 z: 37.0 y: 276.0 x: 116.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 128 z: 49.0 y: 237.0 x: 159.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 128 z: 49.0 y: 237.0 x: 159.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 128 z: 67.0 y: 172.0 x: 176.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 128 z: 67.0 y: 172.0 x: 176.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 129 z: 63.0 y: 171.0 x: 176.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 129 z: 63.0 y: 171.0 x: 176.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 129 z: 50.0 y: 234.0 x: 157.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 129 z: 50.0 y: 234.0 x: 157.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 129 z: 35.0 y: 280.0 x: 115.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 129 z: 35.0 y: 280.0 x: 115.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 129 z: 37.0 y: 229.0 x: 149.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 129 z: 37.0 y: 229.0 x: 149.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 130 z: 63.0 y: 172.0 x: 177.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 130 z: 63.0 y: 172.0 x: 177.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 131 z: 45.0 y: 357.0 x: 119.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 131 z: 45.0 y: 357.0 x: 119.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 131 z: 64.0 y: 168.0 x: 171.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 131 z: 64.0 y: 168.0 x: 171.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 131 z: 61.0 y: 282.0 x: 155.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 131 z: 61.0 y: 282.0 x: 155.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 132 z: 65.0 y: 171.0 x: 173.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 132 z: 65.0 y: 171.0 x: 173.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 132 z: 69.0 y: 231.0 x: 166.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 132 z: 69.0 y: 231.0 x: 166.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 133 z: 68.0 y: 233.0 x: 169.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 133 z: 68.0 y: 233.0 x: 169.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 133 z: 63.0 y: 169.0 x: 174.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 133 z: 63.0 y: 169.0 x: 174.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 133 z: 54.0 y: 224.0 x: 162.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 133 z: 54.0 y: 224.0 x: 162.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 134 z: 52.0 y: 222.0 x: 159.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 134 z: 52.0 y: 222.0 x: 159.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 136 z: 41.0 y: 218.0 x: 174.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 136 z: 41.0 y: 218.0 x: 174.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 136 z: 61.0 y: 281.0 x: 138.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 136 z: 61.0 y: 281.0 x: 138.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 136 z: 64.0 y: 172.0 x: 168.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 136 z: 64.0 y: 172.0 x: 168.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 137 z: 65.0 y: 170.0 x: 170.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 137 z: 65.0 y: 170.0 x: 170.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 137 z: 33.0 y: 228.0 x: 161.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 137 z: 33.0 y: 228.0 x: 161.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 138 z: 93.0 y: 477.0 x: 228.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 138 z: 93.0 y: 477.0 x: 228.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 138 z: 89.0 y: 334.0 x: 170.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 138 z: 89.0 y: 334.0 x: 170.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 139 z: 93.0 y: 478.0 x: 227.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 139 z: 93.0 y: 478.0 x: 227.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Warning: area_large and area_small are equal, which may lead to division by zero.
# Channel: 1 Frame: 140 z: 88.0 y: 331.0 x: 168.0
# Warning: volume_background and volume_signal are equal, which may lead to division by zero.
# Channel: 1 Frame: 140 z: 88.0 y: 331.0 x: 168.0 Volume Background: 0 Volume Signal: 0
# Warning: area_large and area_small are equal, hence setting the background adjusted voxel sum to NaN.
# Warning: volume_background and volume_signal are equal, hence setting the background adjusted voxel sum by volume to NaN.
# Channel 1 done
# Channel 2 done
# Channel 3 done
# Track intensities saved, you can continue to the next notebook.

# %% [markdown]
# Optionally use this cell to assess offset between channel 2 and channel 3 peak intensity

# %%
difs_x = track_df_cleaned['c2_peak_x'] - track_df_cleaned['c3_peak_x']
difs_x = difs_x[~np.isnan(difs_x)]
offset_x_ch2vs3 = int(difs_x.median())

difs_y = track_df_cleaned['c2_peak_y'] - track_df_cleaned['c3_peak_y']
difs_y = difs_y[~np.isnan(difs_y)]
offset_y_ch2vs3 = int(difs_y.median())

plt.hist(difs_x, bins=20, alpha=0.5)
plt.hist(difs_y, bins=20, alpha=0.5)
plt.legend(['x', 'y'])

plt.xlabel('Difference between channel 2 and channel 3 (pixels)')

plt.title('Histogram of differences between channel 2 and channel 3')

print(f'Median offset between channel 2 and channel 3 in x: {offset_x_ch2vs3}')
print(f'Median offset between channel 2 and channel 3 in y: {offset_y_ch2vs3}')
# Out:
# Median offset between channel 2 and channel 3 in x: -1
# Median offset between channel 2 and channel 3 in y: 1

# %% [markdown]
# ### If there is a systematic offset between the two channels, set those values in the above "set offset" cell and rerun the cells until here

# %%
# plot intensity histograms for fun
# change the 'c3_voxel_sum_adjusted' value to plot other intensity metrics

# plt.hist(track_df_cleaned['c3_voxel_sum_adjusted'], bins=100, alpha=0.5, label='Channel 3')
# plt.hist(track_df_cleaned['c2_voxel_sum_adjusted'], bins=100, alpha=0.5, label='Channel 2')
# plt.hist(track_df_cleaned['c1_voxel_sum_adjusted'], bins=100, alpha=0.5, label='Channel 1')

# histogram of three channels with uniform bin sizes
plt.hist(track_df_cleaned['c3_voxel_sum_adjusted'], bins=np.linspace(-5000, 60000, 100), alpha=0.5, label='Channel 3')
plt.hist(track_df_cleaned['c2_voxel_sum_adjusted'], bins=np.linspace(-5000, 60000, 100), alpha=0.5, label='Channel 2')
plt.hist(track_df_cleaned['c1_voxel_sum_adjusted'], bins=np.linspace(-5000, 60000, 100), alpha=0.5, label='Channel 1')

plt.legend()
plt.title('Voxel sum adjusted')
plt.xlabel('Voxel sum')
plt.ylabel('Count')
plt.xlim(-5000, 40000)
plt.show()

# %%
# Extract information for channel 1
# track_df['c1_gaussian_amp'] = channel1_gaussians_df['amplitude']
# track_df['c1_mu_x'] = channel1_gaussians_df['mu_x']
# track_df['c1_mu_y'] = channel1_gaussians_df['mu_y']
# track_df['c1_mu_z'] = channel1_gaussians_df['mu_z']
# track_df['c1_sigma_x'] = channel1_gaussians_df['sigma_x']
# track_df['c1_sigma_y'] = channel1_gaussians_df['sigma_y']
# track_df['c1_sigma_z'] = channel1_gaussians_df['sigma_z']

# ### In the below steps dataframe is being cleaned to make column names consistent for next steps 
# ##Renaming columns to maintain data integrity 
# new_col_names = {
#     'amplitude': 'c3_gaussian_amp', 
#     'mu_x': 'c3_mu_x', 
#     'mu_y': 'c3_mu_y', 
#     'mu_z': 'c3_mu_z', 
#     'sigma_x': 'c3_sigma_x', 
#     'sigma_y': 'c3_sigma_y', 
#     'sigma_z': 'c3_sigma_z', 
#     'c2_peak': 'c2_peak_amp', 
#     'c1_peak': 'c1_peak_amp'
# }
# track_df.rename(columns=new_col_names, inplace=True)
