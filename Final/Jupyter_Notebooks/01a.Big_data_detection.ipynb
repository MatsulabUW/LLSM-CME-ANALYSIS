# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from aicsimageio import AICSImage
import time

### package for 3d visualization
#from itkwidgets import view                              
#from aicssegmentation.core.visual import seg_fluo_side_by_side,  single_fluorescent_view, segmentation_quick_view
#import skimage

### local new python segmentation functions
import os
import sys
pythonPackagePath = os.path.abspath('../src/')
sys.path.append(pythonPackagePath)
from peak_local_max_3d import peak_local_max_3d 
from gaussian_fitting import fit_multiple_gaussians
from extract_data import extract_data_from_filename
from gaussian_visualization import visualize_3D_gaussians
from gaussian_fitting import check_fitting_error
import matplotlib.pyplot as plt
from skimage import io
import tifffile

# %%
# input_file_path = '/Users/makamats/Documents/Local-microscopy-data/TwoSlide_Left_JFXRapidWithWash-05_processed-cropped.ome.tiff'
input_file_path = '/Users/makamats/Documents/Local-microscopy-data/TwoSlide_Left_JFXRapidWithWash-05_processed-cropped-double-crop.ome.tif'
save_dir = '/Users/makamats/Documents/Local-microscopy-data/Tracked'

# Load the file
img = AICSImage(input_file_path)

# %%
# Check which reader is being used
print(type(img.reader))
# Out:
# <class 'aicsimageio.readers.tiff_reader.TiffReader'>

# %%
img.dask_data
# Out:
# dask.array<transpose, shape=(130, 3, 75, 150, 275), dtype=uint16, chunksize=(1, 1, 75, 150, 275), chunktype=numpy.ndarray>

# %%
import time

# Load the CZI file
#img = AICSImage(input_filename_czi)

file_label = input_file_path.split('/')[-1].split('.')[0]

#get the number of frames for our original data for automated analysis for all frames 
frames = img.dims.T
start_frame = 0
end_frame = frames

# channels = img.dims.C

threshold = [150]
### an otsu or other type of threshold might be better here

start_time = time.time()

# Single channel detection, to start

# pick which channel to detect (starts at 0)
channel = 2

# for channel in range(channels):
#     print('processing channel ' + str(channel))
### This is where we can replace deep learning detection, or parallel detection on multiple CPUs for example

# input_file_path

detections_df = pd.DataFrame()

for frame in range(start_frame,end_frame):
    
    print('frame number is', frame)
    lazy_single_frame_input = img.get_image_dask_data("ZYX", T=frame, C=channel)
    
    single_frame_input = lazy_single_frame_input.compute()
    print(single_frame_input.shape)
    single_frame_input = np.transpose(single_frame_input,axes =(0,2,1))
    print(single_frame_input.shape)

    #define threshold: a value(intensity) for the pixel below which all values would be considered noise and dropped 
    #define min_distance: min_distance/2 is the radius within which we will keep the peak with max value/intensity or 
    #if two peaks have the same value they will be kept 
    
    ### we should be able to determine the threshold intelligently, i.e. with an otsu filter or some other method, for each
    maximas = peak_local_max_3d(single_frame_input,min_distance=10,threshold=threshold)
    print('local_maximas detected are', maximas.shape[0])


    #give the expected std dev/radius of our particles for x,y,z 
    sigmaExpected_x__pixels = 2
    sigmaExpected_y__pixels = 2
    sigmaExpected_z__pixels = 4

    sigmas_guesses = []
    for i in range(len(maximas)):
        sigmas_guesses.append([sigmaExpected_z__pixels,sigmaExpected_x__pixels,sigmaExpected_y__pixels])
        
    #last parameter in the fit_multiple_gaussians is similar to min_distance above, we should give half of the 
    #value here of min_distance   
    gaussians, gaussians_popt = fit_multiple_gaussians(single_frame_input,maximas,sigmas_guesses,5)
        
    accumulator = []
    for gaussian in gaussians:

        if(gaussian!=-1):
            amplitude = gaussian[0]

            #print(gaussian)
            mu_x     = int(gaussian[1][1]) ##this is going to be mu_z, previous code [1][0]
            mu_y     = int(gaussian[1][2]) ##need to finalise what this is (x or y) [1][1]
            mu_z     = int(gaussian[1][0]) ##need to finalise what this is (x or y) [1][2]
            ##sigmas will also change due to the above 
            sigma_x  = int(gaussian[2][1]) 
            sigma_y  = int(gaussian[2][2])
            sigma_z  = int(gaussian[2][0])
            accumulator.append(np.array([amplitude,mu_x,mu_y,mu_z,sigma_x,sigma_y,sigma_z]))
            
    accumulator = np.array(accumulator)
    print(accumulator.shape)
    df = pd.DataFrame()
    df['amplitude'] = accumulator[:,0]
    df['mu_x'] = accumulator[:,1]
    df['mu_y'] = accumulator[:,2]
    df['mu_z'] = accumulator[:,3]
    df['sigma_x'] = accumulator[:,4]
    df['sigma_y'] = accumulator[:,5]
    df['sigma_z'] = accumulator[:,6]
    df['channel'] = channel
    df['frame'] = frame
    # df.head()
    
    error_list, index_list = check_fitting_error(single_frame_input,maximas,gaussians,sigmas_guesses)
    
    # Construct the filename
    '''
    filename_csv = f'df_c2_t{frame}.csv'
    file_path_csv = os.path.join(csv_save_dir, filename_csv)
    df.to_csv(file_path_csv)
    '''
    # concatenate the dataframes

    detections_df = pd.concat([detections_df,df])
    
# Save the DataFrame to a pickle file with the specified path
file_path =   os.path.join(save_dir,file_label+'_detections_c'+str(channel)+'.pkl')

detections_df.to_pickle(file_path)
end_time = time.time()

print('time taken (seconds)', end_time - start_time)
# Out:
# frame number is 0
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 456
# 10%(46 of 456)
# 20%(92 of 456)
# 30%(137 of 456)
# 40%(183 of 456)
# 50%(228 of 456)
# 60%(274 of 456)
# 70%(320 of 456)
# 80%(365 of 456)
# 90%(411 of 456)
# 100%(456 of 456)
# (456, 7)
# the number of times the gaussian fitting worked was456and the number of times the gaussian did not fit was 0
# frame number is 1
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 446
# 10%(45 of 446)
# 20%(90 of 446)
# 30%(134 of 446)
# 40%(179 of 446)
# 50%(223 of 446)
# 60%(268 of 446)
# 70%(313 of 446)
# 80%(357 of 446)
# 90%(402 of 446)
# 100%(446 of 446)
# (446, 7)
# the number of times the gaussian fitting worked was446and the number of times the gaussian did not fit was 0
# frame number is 2
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 464
# 10%(47 of 464)
# 20%(93 of 464)
# 30%(140 of 464)
# 40%(186 of 464)
# 50%(232 of 464)
# 60%(279 of 464)
# 70%(325 of 464)
# 80%(372 of 464)
# 90%(418 of 464)
# 100%(464 of 464)
# (464, 7)
# the number of times the gaussian fitting worked was464and the number of times the gaussian did not fit was 0
# frame number is 3
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 445
# 10%(45 of 445)
# 20%(89 of 445)
# 30%(134 of 445)
# 40%(178 of 445)
# 50%(223 of 445)
# 60%(267 of 445)
# 70%(312 of 445)
# 80%(356 of 445)
# 90%(401 of 445)
# 100%(445 of 445)
# (445, 7)
# the number of times the gaussian fitting worked was445and the number of times the gaussian did not fit was 0
# frame number is 4
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 452
# 10%(46 of 452)
# 20%(91 of 452)
# 30%(136 of 452)
# 40%(181 of 452)
# 50%(226 of 452)
# 60%(272 of 452)
# 70%(317 of 452)
# 80%(362 of 452)
# 90%(407 of 452)
# 100%(452 of 452)
# (452, 7)
# the number of times the gaussian fitting worked was452and the number of times the gaussian did not fit was 0
# frame number is 5
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 516
# 10%(52 of 516)
# 20%(104 of 516)
# 30%(155 of 516)
# 40%(207 of 516)
# 50%(258 of 516)
# 60%(310 of 516)
# 70%(362 of 516)
# 80%(413 of 516)
# 90%(465 of 516)
# 100%(516 of 516)
# (516, 7)
# the number of times the gaussian fitting worked was516and the number of times the gaussian did not fit was 0
# frame number is 60
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 519
# 10%(52 of 519)
# 20%(104 of 519)
# 30%(156 of 519)
# 40%(208 of 519)
# 50%(260 of 519)
# 60%(312 of 519)
# 70%(364 of 519)
# 80%(416 of 519)
# 90%(468 of 519)
# 100%(519 of 519)
# (519, 7)
# the number of times the gaussian fitting worked was519and the number of times the gaussian did not fit was 0
# frame number is 61
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 525
# 10%(53 of 525)
# 20%(105 of 525)
# 30%(158 of 525)
# 40%(210 of 525)
# 50%(263 of 525)
# 60%(315 of 525)
# 70%(368 of 525)
# 80%(420 of 525)
# 90%(473 of 525)
# 100%(525 of 525)
# (525, 7)
# the number of times the gaussian fitting worked was525and the number of times the gaussian did not fit was 0
# frame number is 62
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 553
# 10%(56 of 553)
# 20%(111 of 553)
# 30%(166 of 553)
# 40%(222 of 553)
# 50%(277 of 553)
# 60%(332 of 553)
# 70%(388 of 553)
# 80%(443 of 553)
# 90%(498 of 553)
# 100%(553 of 553)
# (552, 7)
# the gaussian did not fit
# the number of times the gaussian fitting worked was552and the number of times the gaussian did not fit was 1
# frame number is 63
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 526
# 10%(53 of 526)
# 20%(106 of 526)
# 30%(158 of 526)
# 40%(211 of 526)
# 50%(263 of 526)
# 60%(316 of 526)
# 70%(369 of 526)
# 80%(421 of 526)
# 90%(474 of 526)
# 100%(526 of 526)
# (526, 7)
# the number of times the gaussian fitting worked was526and the number of times the gaussian did not fit was 0
# frame number is 64
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 514
# 10%(52 of 514)
# 20%(103 of 514)
# 30%(155 of 514)
# 40%(206 of 514)
# 50%(257 of 514)
# 60%(309 of 514)
# 70%(360 of 514)
# 80%(412 of 514)
# 90%(463 of 514)
# 100%(514 of 514)
# (514, 7)
# the number of times the gaussian fitting worked was514and the number of times the gaussian did not fit was 0
# frame number is 65
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 524
# 10%(53 of 524)
# 20%(105 of 524)
# 30%(158 of 524)
# 40%(210 of 524)
# 50%(262 of 524)
# 60%(315 of 524)
# 70%(367 of 524)
# 80%(420 of 524)
# 90%(472 of 524)
# 100%(524 of 524)
# (524, 7)
# the number of times the gaussian fitting worked was524and the number of times the gaussian did not fit was 0
# frame number is 66
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 544
# 10%(55 of 544)
# 20%(109 of 544)
# 30%(164 of 544)
# 40%(218 of 544)
# 50%(272 of 544)
# 60%(327 of 544)
# 70%(381 of 544)
# 80%(436 of 544)
# 90%(490 of 544)
# 100%(544 of 544)
# (544, 7)
# the number of times the gaussian fitting worked was544and the number of times the gaussian did not fit was 0
# frame number is 67
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 533
# 10%(54 of 533)
# 20%(107 of 533)
# 30%(160 of 533)
# 40%(214 of 533)
# 50%(267 of 533)
# 60%(320 of 533)
# 70%(374 of 533)
# 80%(427 of 533)
# 90%(480 of 533)
# 100%(533 of 533)
# (533, 7)
# the number of times the gaussian fitting worked was533and the number of times the gaussian did not fit was 0
# frame number is 68
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 548
# 10%(55 of 548)
# 20%(110 of 548)
# 30%(165 of 548)
# 40%(220 of 548)
# 50%(274 of 548)
# 60%(329 of 548)
# 70%(384 of 548)
# 80%(439 of 548)
# 90%(494 of 548)
# 100%(548 of 548)
# (548, 7)
# the number of times the gaussian fitting worked was548and the number of times the gaussian did not fit was 0
# frame number is 69
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 557
# 10%(56 of 557)
# 20%(112 of 557)
# 30%(168 of 557)
# 40%(223 of 557)
# 50%(279 of 557)
# 60%(335 of 557)
# 70%(390 of 557)
# 80%(446 of 557)
# 90%(502 of 557)
# 100%(557 of 557)
# (557, 7)
# the number of times the gaussian fitting worked was557and the number of times the gaussian did not fit was 0
# frame number is 70
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 540
# 10%(54 of 540)
# 20%(108 of 540)
# 30%(162 of 540)
# 40%(216 of 540)
# 50%(270 of 540)
# 60%(324 of 540)
# 70%(378 of 540)
# 80%(432 of 540)
# 90%(486 of 540)
# 100%(540 of 540)
# (540, 7)
# the number of times the gaussian fitting worked was540and the number of times the gaussian did not fit was 0
# frame number is 71
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 545
# 10%(55 of 545)
# 20%(109 of 545)
# 30%(164 of 545)
# 40%(218 of 545)
# 50%(273 of 545)
# 60%(327 of 545)
# 70%(382 of 545)
# 80%(436 of 545)
# 90%(491 of 545)
# 100%(545 of 545)
# (545, 7)
# the number of times the gaussian fitting worked was545and the number of times the gaussian did not fit was 0
# frame number is 72
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 525
# 10%(53 of 525)
# 20%(105 of 525)
# 30%(158 of 525)
# 40%(210 of 525)
# 50%(263 of 525)
# 60%(315 of 525)
# 70%(368 of 525)
# 80%(420 of 525)
# 90%(473 of 525)
# 100%(525 of 525)
# (525, 7)
# the number of times the gaussian fitting worked was525and the number of times the gaussian did not fit was 0
# frame number is 73
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 556
# 10%(56 of 556)
# 20%(112 of 556)
# 30%(167 of 556)
# 40%(223 of 556)
# 50%(278 of 556)
# 60%(334 of 556)
# 70%(390 of 556)
# 80%(445 of 556)
# 90%(501 of 556)
# 100%(556 of 556)
# (556, 7)
# the number of times the gaussian fitting worked was556and the number of times the gaussian did not fit was 0
# frame number is 74
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 549
# 10%(55 of 549)
# 20%(110 of 549)
# 30%(165 of 549)
# 40%(220 of 549)
# 50%(275 of 549)
# 60%(330 of 549)
# 70%(385 of 549)
# 80%(440 of 549)
# 90%(495 of 549)
# 100%(549 of 549)
# (549, 7)
# the number of times the gaussian fitting worked was549and the number of times the gaussian did not fit was 0
# frame number is 75
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 562
# 10%(57 of 562)
# 20%(113 of 562)
# 30%(169 of 562)
# 40%(225 of 562)
# 50%(281 of 562)
# 60%(338 of 562)
# 70%(394 of 562)
# 80%(450 of 562)
# 90%(506 of 562)
# 100%(562 of 562)
# (562, 7)
# the number of times the gaussian fitting worked was562and the number of times the gaussian did not fit was 0
# frame number is 76
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 557
# 10%(56 of 557)
# 20%(112 of 557)
# 30%(168 of 557)
# 40%(223 of 557)
# 50%(279 of 557)
# 60%(335 of 557)
# 70%(390 of 557)
# 80%(446 of 557)
# 90%(502 of 557)
# 100%(557 of 557)
# (557, 7)
# the number of times the gaussian fitting worked was557and the number of times the gaussian did not fit was 0
# frame number is 77
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 536
# 10%(54 of 536)
# 20%(108 of 536)
# 30%(161 of 536)
# 40%(215 of 536)
# 50%(268 of 536)
# 60%(322 of 536)
# 70%(376 of 536)
# 80%(429 of 536)
# 90%(483 of 536)
# 100%(536 of 536)
# (536, 7)
# the number of times the gaussian fitting worked was536and the number of times the gaussian did not fit was 0
# frame number is 78
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 533
# 10%(54 of 533)
# 20%(107 of 533)
# 30%(160 of 533)
# 40%(214 of 533)
# 50%(267 of 533)
# 60%(320 of 533)
# 70%(374 of 533)
# 80%(427 of 533)
# 90%(480 of 533)
# 100%(533 of 533)
# (533, 7)
# the number of times the gaussian fitting worked was533and the number of times the gaussian did not fit was 0
# frame number is 79
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 540
# 10%(54 of 540)
# 20%(108 of 540)
# 30%(162 of 540)
# 40%(216 of 540)
# 50%(270 of 540)
# 60%(324 of 540)
# 70%(378 of 540)
# 80%(432 of 540)
# 90%(486 of 540)
# 100%(540 of 540)
# (540, 7)
# the number of times the gaussian fitting worked was540and the number of times the gaussian did not fit was 0
# frame number is 80
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 547
# 10%(55 of 547)
# 20%(110 of 547)
# 30%(165 of 547)
# 40%(219 of 547)
# 50%(274 of 547)
# 60%(329 of 547)
# 70%(383 of 547)
# 80%(438 of 547)
# 90%(493 of 547)
# 100%(547 of 547)
# (547, 7)
# the number of times the gaussian fitting worked was547and the number of times the gaussian did not fit was 0
# frame number is 81
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 527
# 10%(53 of 527)
# 20%(106 of 527)
# 30%(159 of 527)
# 40%(211 of 527)
# 50%(264 of 527)
# 60%(317 of 527)
# 70%(369 of 527)
# 80%(422 of 527)
# 90%(475 of 527)
# 100%(527 of 527)
# (527, 7)
# the number of times the gaussian fitting worked was527and the number of times the gaussian did not fit was 0
# frame number is 82
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 519
# 10%(52 of 519)
# 20%(104 of 519)
# 30%(156 of 519)
# 40%(208 of 519)
# 50%(260 of 519)
# 60%(312 of 519)
# 70%(364 of 519)
# 80%(416 of 519)
# 90%(468 of 519)
# 100%(519 of 519)
# (519, 7)
# the number of times the gaussian fitting worked was519and the number of times the gaussian did not fit was 0
# frame number is 83
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 522
# 10%(53 of 522)
# 20%(105 of 522)
# 30%(157 of 522)
# 40%(209 of 522)
# 50%(261 of 522)
# 60%(314 of 522)
# 70%(366 of 522)
# 80%(418 of 522)
# 90%(470 of 522)
# 100%(522 of 522)
# (522, 7)
# the number of times the gaussian fitting worked was522and the number of times the gaussian did not fit was 0
# frame number is 84
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 546
# 10%(55 of 546)
# 20%(110 of 546)
# 30%(164 of 546)
# 40%(219 of 546)
# 50%(273 of 546)
# 60%(328 of 546)
# 70%(383 of 546)
# 80%(437 of 546)
# 90%(492 of 546)
# 100%(546 of 546)
# (546, 7)
# the number of times the gaussian fitting worked was546and the number of times the gaussian did not fit was 0
# frame number is 85
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 512
# 10%(52 of 512)
# 20%(103 of 512)
# 30%(154 of 512)
# 40%(205 of 512)
# 50%(256 of 512)
# 60%(308 of 512)
# 70%(359 of 512)
# 80%(410 of 512)
# 90%(461 of 512)
# 100%(512 of 512)
# (512, 7)
# the number of times the gaussian fitting worked was512and the number of times the gaussian did not fit was 0
# frame number is 86
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 555
# 10%(56 of 555)
# 20%(111 of 555)
# 30%(167 of 555)
# 40%(222 of 555)
# 50%(278 of 555)
# 60%(333 of 555)
# 70%(389 of 555)
# 80%(444 of 555)
# 90%(500 of 555)
# 100%(555 of 555)
# (555, 7)
# the number of times the gaussian fitting worked was555and the number of times the gaussian did not fit was 0
# frame number is 87
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 552
# 10%(56 of 552)
# 20%(111 of 552)
# 30%(166 of 552)
# 40%(221 of 552)
# 50%(276 of 552)
# 60%(332 of 552)
# 70%(387 of 552)
# 80%(442 of 552)
# 90%(497 of 552)
# 100%(552 of 552)
# (552, 7)
# the number of times the gaussian fitting worked was552and the number of times the gaussian did not fit was 0
# frame number is 88
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 540
# 10%(54 of 540)
# 20%(108 of 540)
# 30%(162 of 540)
# 40%(216 of 540)
# 50%(270 of 540)
# 60%(324 of 540)
# 70%(378 of 540)
# 80%(432 of 540)
# 90%(486 of 540)
# 100%(540 of 540)
# (540, 7)
# the number of times the gaussian fitting worked was540and the number of times the gaussian did not fit was 0
# frame number is 89
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 536
# 10%(54 of 536)
# 20%(108 of 536)
# 30%(161 of 536)
# 40%(215 of 536)
# 50%(268 of 536)
# 60%(322 of 536)
# 70%(376 of 536)
# 80%(429 of 536)
# 90%(483 of 536)
# 100%(536 of 536)
# (536, 7)
# the number of times the gaussian fitting worked was536and the number of times the gaussian did not fit was 0
# frame number is 90
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 532
# 10%(54 of 532)
# 20%(107 of 532)
# 30%(160 of 532)
# 40%(213 of 532)
# 50%(266 of 532)
# 60%(320 of 532)
# 70%(373 of 532)
# 80%(426 of 532)
# 90%(479 of 532)
# 100%(532 of 532)
# (532, 7)
# the number of times the gaussian fitting worked was532and the number of times the gaussian did not fit was 0
# frame number is 91
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 537
# 10%(54 of 537)
# 20%(108 of 537)
# 30%(162 of 537)
# 40%(215 of 537)
# 50%(269 of 537)
# 60%(323 of 537)
# 70%(376 of 537)
# 80%(430 of 537)
# 90%(484 of 537)
# 100%(537 of 537)
# (537, 7)
# the number of times the gaussian fitting worked was537and the number of times the gaussian did not fit was 0
# frame number is 92
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 554
# 10%(56 of 554)
# 20%(111 of 554)
# 30%(167 of 554)
# 40%(222 of 554)
# 50%(277 of 554)
# 60%(333 of 554)
# 70%(388 of 554)
# 80%(444 of 554)
# 90%(499 of 554)
# 100%(554 of 554)
# (554, 7)
# the number of times the gaussian fitting worked was554and the number of times the gaussian did not fit was 0
# frame number is 93
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 540
# 10%(54 of 540)
# 20%(108 of 540)
# 30%(162 of 540)
# 40%(216 of 540)
# 50%(270 of 540)
# 60%(324 of 540)
# 70%(378 of 540)
# 80%(432 of 540)
# 90%(486 of 540)
# 100%(540 of 540)
# (539, 7)
# the gaussian did not fit
# the number of times the gaussian fitting worked was539and the number of times the gaussian did not fit was 1
# frame number is 94
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 549
# 10%(55 of 549)
# 20%(110 of 549)
# 30%(165 of 549)
# 40%(220 of 549)
# 50%(275 of 549)
# 60%(330 of 549)
# 70%(385 of 549)
# 80%(440 of 549)
# 90%(495 of 549)
# 100%(549 of 549)
# (549, 7)
# the number of times the gaussian fitting worked was549and the number of times the gaussian did not fit was 0
# frame number is 95
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 552
# 10%(56 of 552)
# 20%(111 of 552)
# 30%(166 of 552)
# 40%(221 of 552)
# 50%(276 of 552)
# 60%(332 of 552)
# 70%(387 of 552)
# 80%(442 of 552)
# 90%(497 of 552)
# 100%(552 of 552)
# (552, 7)
# the number of times the gaussian fitting worked was552and the number of times the gaussian did not fit was 0
# frame number is 96
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 555
# 10%(56 of 555)
# 20%(111 of 555)
# 30%(167 of 555)
# 40%(222 of 555)
# 50%(278 of 555)
# 60%(333 of 555)
# 70%(389 of 555)
# 80%(444 of 555)
# 90%(500 of 555)
# 100%(555 of 555)
# (555, 7)
# the number of times the gaussian fitting worked was555and the number of times the gaussian did not fit was 0
# frame number is 97
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 560
# 10%(56 of 560)
# 20%(112 of 560)
# 30%(168 of 560)
# 40%(224 of 560)
# 50%(280 of 560)
# 60%(336 of 560)
# 70%(392 of 560)
# 80%(448 of 560)
# 90%(504 of 560)
# 100%(560 of 560)
# (560, 7)
# the number of times the gaussian fitting worked was560and the number of times the gaussian did not fit was 0
# frame number is 98
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 530
# 10%(53 of 530)
# 20%(106 of 530)
# 30%(159 of 530)
# 40%(212 of 530)
# 50%(265 of 530)
# 60%(318 of 530)
# 70%(371 of 530)
# 80%(424 of 530)
# 90%(477 of 530)
# 100%(530 of 530)
# (530, 7)
# the number of times the gaussian fitting worked was530and the number of times the gaussian did not fit was 0
# frame number is 99
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 523
# 10%(53 of 523)
# 20%(105 of 523)
# 30%(157 of 523)
# 40%(210 of 523)
# 50%(262 of 523)
# 60%(314 of 523)
# 70%(367 of 523)
# 80%(419 of 523)
# 90%(471 of 523)
# 100%(523 of 523)
# (523, 7)
# the number of times the gaussian fitting worked was523and the number of times the gaussian did not fit was 0
# frame number is 100
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 519
# 10%(52 of 519)
# 20%(104 of 519)
# 30%(156 of 519)
# 40%(208 of 519)
# 50%(260 of 519)
# 60%(312 of 519)
# 70%(364 of 519)
# 80%(416 of 519)
# 90%(468 of 519)
# 100%(519 of 519)
# (519, 7)
# the number of times the gaussian fitting worked was519and the number of times the gaussian did not fit was 0
# frame number is 101
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 498
# 10%(50 of 498)
# 20%(100 of 498)
# 30%(150 of 498)
# 40%(200 of 498)
# 50%(249 of 498)
# 60%(299 of 498)
# 70%(349 of 498)
# 80%(399 of 498)
# 90%(449 of 498)
# 100%(498 of 498)
# (498, 7)
# the number of times the gaussian fitting worked was498and the number of times the gaussian did not fit was 0
# frame number is 102
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 524
# 10%(53 of 524)
# 20%(105 of 524)
# 30%(158 of 524)
# 40%(210 of 524)
# 50%(262 of 524)
# 60%(315 of 524)
# 70%(367 of 524)
# 80%(420 of 524)
# 90%(472 of 524)
# 100%(524 of 524)
# (524, 7)
# the number of times the gaussian fitting worked was524and the number of times the gaussian did not fit was 0
# frame number is 103
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 539
# 10%(54 of 539)
# 20%(108 of 539)
# 30%(162 of 539)
# 40%(216 of 539)
# 50%(270 of 539)
# 60%(324 of 539)
# 70%(378 of 539)
# 80%(432 of 539)
# 90%(486 of 539)
# 100%(539 of 539)
# (539, 7)
# the number of times the gaussian fitting worked was539and the number of times the gaussian did not fit was 0
# frame number is 113
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 541
# 10%(55 of 541)
# 20%(109 of 541)
# 30%(163 of 541)
# 40%(217 of 541)
# 50%(271 of 541)
# 60%(325 of 541)
# 70%(379 of 541)
# 80%(433 of 541)
# 90%(487 of 541)
# 100%(541 of 541)
# (541, 7)
# the number of times the gaussian fitting worked was541and the number of times the gaussian did not fit was 0
# frame number is 114
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 545
# 10%(55 of 545)
# 20%(109 of 545)
# 30%(164 of 545)
# 40%(218 of 545)
# 50%(273 of 545)
# 60%(327 of 545)
# 70%(382 of 545)
# 80%(436 of 545)
# 90%(491 of 545)
# 100%(545 of 545)
# (545, 7)
# the number of times the gaussian fitting worked was545and the number of times the gaussian did not fit was 0
# frame number is 115
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 537
# 10%(54 of 537)
# 20%(108 of 537)
# 30%(162 of 537)
# 40%(215 of 537)
# 50%(269 of 537)
# 60%(323 of 537)
# 70%(376 of 537)
# 80%(430 of 537)
# 90%(484 of 537)
# 100%(537 of 537)
# (537, 7)
# the number of times the gaussian fitting worked was537and the number of times the gaussian did not fit was 0
# frame number is 116
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 557
# 10%(56 of 557)
# 20%(112 of 557)
# 30%(168 of 557)
# 40%(223 of 557)
# 50%(279 of 557)
# 60%(335 of 557)
# 70%(390 of 557)
# 80%(446 of 557)
# 90%(502 of 557)
# 100%(557 of 557)
# (557, 7)
# the number of times the gaussian fitting worked was557and the number of times the gaussian did not fit was 0
# frame number is 117
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 548
# 10%(55 of 548)
# 20%(110 of 548)
# 30%(165 of 548)
# 40%(220 of 548)
# 50%(274 of 548)
# 60%(329 of 548)
# 70%(384 of 548)
# 80%(439 of 548)
# 90%(494 of 548)
# 100%(548 of 548)
# (548, 7)
# the number of times the gaussian fitting worked was548and the number of times the gaussian did not fit was 0
# frame number is 118
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 552
# 10%(56 of 552)
# 20%(111 of 552)
# 30%(166 of 552)
# 40%(221 of 552)
# 50%(276 of 552)
# 60%(332 of 552)
# 70%(387 of 552)
# 80%(442 of 552)
# 90%(497 of 552)
# 100%(552 of 552)
# (552, 7)
# the number of times the gaussian fitting worked was552and the number of times the gaussian did not fit was 0
# frame number is 119
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 567
# 10%(57 of 567)
# 20%(114 of 567)
# 30%(171 of 567)
# 40%(227 of 567)
# 50%(284 of 567)
# 60%(341 of 567)
# 70%(397 of 567)
# 80%(454 of 567)
# 90%(511 of 567)
# 100%(567 of 567)
# (567, 7)
# the number of times the gaussian fitting worked was567and the number of times the gaussian did not fit was 0
# frame number is 120
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are 554
# 10%(56 of 554)
# 20%(111 of 554)
# 30%(167 of 554)
# 40%(222 of 554)
# 50%(277 of 554)
# 60%(333 of 554)
# 70%(388 of 554)
# 80%(444 of 554)
# 90%(499 of 554)
# 100%(554 of 554)
# (554, 7)
# the number of times the gaussian fitting worked was554and the number of times the gaussian did not fit was 0
# frame number is 121
# (75, 150, 275)
# (75, 275, 150)
# local_maximas detected are