# %% [markdown]
# # Exploring both tracks from both channels in Napari overlayed
# 1. **Napari Visualisation**
# 2. **Amplitude over time of selected tracks**

# %%
from os import path
import pandas as pd
from IPython.display import display
from matplotlib import pyplot as plt
from laptrack import LapTrack
from laptrack import datasets
import napari
from skimage import io

# %%
##loading spots 
# Assuming 'your_file.pkl' is the name of your pickle file
file_path_c2 = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/track_df_c2.pkl'
file_path_c3 = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/track_df_c3.pkl'

# Read the pickle file into a Pandas DataFrame
c2_track_df = pd.read_pickle(file_path_c2)
c3_track_df = pd.read_pickle(file_path_c3)

# %% [markdown]
# For Channel 2 filter out tracks which are present in 8 frames
#
# For Channel 3 filter out tracks which are present in 9 frames

# %%
# Find the count of each tree_id
c2_tree_id_counts =  c2_track_df['track_id'].value_counts()

# Get the tree_ids that have occurred more than 8 times
c2_selected_tree_ids = c2_tree_id_counts[c2_tree_id_counts > 8].index

# Filter the DataFrame to get rows with the selected tree_ids
c2_filtered_df = c2_track_df[c2_track_df['track_id'].isin(c2_selected_tree_ids)]
c2_filtered_df = c2_filtered_df.reset_index()

# Print the filtered DataFrame
#c2_filtered_df.head()

# %%
# Find the count of each tree_id
c3_tree_id_counts =  c3_track_df['track_id'].value_counts()

# Get the tree_ids that have occurred more than 8 times
c3_selected_tree_ids = c3_tree_id_counts[c3_tree_id_counts > 9].index

# Filter the DataFrame to get rows with the selected tree_ids
c3_filtered_df = c3_track_df[c3_track_df['track_id'].isin(c3_selected_tree_ids)]
c3_filtered_df = c3_filtered_df.reset_index()

# Print the filtered DataFrame
#c3_filtered_df.head()

# %%
# Create a napari viewer
viewer = napari.Viewer()

# Replace 'your_file.tif' with the path to your 4D TIFF file
file_path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/Channel_3.tif'

# Load the TIFF file using skimage
raw_image = io.imread(file_path)

# Add the 4D stack to the viewer
layer_raw = viewer.add_image(raw_image)
# Out:
# 1   HIToolbox                           0x00007ff817ccb726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff817ccb2b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff817c3acd7 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1113
# 4   HIToolbox                           0x00007ff817ccb173 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 175
# 5   AppKit                              0x00007ff81179c4b7 -[NSApplication _setPresentationOptions:instance:flags:] + 1145
# 6   AppKit                              0x00007ff8115f1165 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 582
# 7   AppKit                              0x00007ff81203fa40 -[_NSFullScreenSpace(PresentationInstance) activateFullScreenPresentationOptions] + 207
# 8   AppKit                              0x00007ff811e92848 -[_NSEnterFullScreenTransitionController _doSucceededToEnterFullScreen] + 721
# 9   AppKit                              0x00007ff811e93357 __65-[_NSEnterFullScreenTransitionController _performEnterFullScreen]_block_invoke + 451
# 10  AppKit                              0x00007ff81183f85e __NSFullScreenDockConnectionSendEnterForSpace_block_invoke + 135
# 11  libxpc.dylib                        0x00007ff80dfa7fb3 _xpc_connection_reply_callout + 36
# 12  libxpc.dylib                        0x00007ff80dfa7f3b _xpc_connection_call_reply_async + 69
# 13  libdispatch.dylib                   0x00007ff80e0baaaa _dispatch_client_callout3 + 8
# 14  libdispatch.dylib                   0x00007ff80e0d5c6f _dispatch_mach_msg_async_reply_invoke + 387
# 15  libdispatch.dylib                   0x00007ff80e0c76ee _dispatch_main_queue_drain + 749
# 16  libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 17  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 18  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 19  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 20  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 21  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 22  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 23  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 24  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 25  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 26  libqcocoa.dylib                     0x0000000120bd850a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff817c580c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff817c94638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff812f3a74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81324d04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81324cf71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff80e0b97fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff80e0baa44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff80e0c77b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x0000000120bd850a qt_plugin_instance + 148153

# %%
layer_raw.bounding_box.visible = True

# %% [markdown]
# **Add tracks from both channel 2 & channel 3**

# %%
viewer.add_tracks(c3_filtered_df[["track_id", "frame", "mu_z", "mu_y", "mu_x"]], name = 'tracks Channel 3')
viewer.add_tracks(c2_filtered_df[["track_id", "frame", "mu_z", "mu_y", "mu_x"]], name = 'tracks Channel 2')
# Out:
# <Tracks layer 'tracks Channel 2' at 0x7fddabdfafb0>

# %% [markdown]
# **Add points for which tracks are being displayed**

# %%
points_layer = viewer.add_points(c3_filtered_df[["frame", "mu_z", "mu_y", "mu_x"]], size=2,
                                name = 'channel 3 points', face_color = 'red', symbol = 'o')
points_layer = viewer.add_points(c2_filtered_df[["frame", "mu_z", "mu_y", "mu_x"]], size=2,
                                name = 'channel 2 points', face_color = 'green', symbol = 'o')
# Out:
# 1   HIToolbox                           0x00007ff817ccb726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff817c6f852 SetMenuBarObscured + 226
# 3   HIToolbox                           0x00007ff817c6f4ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 4   HIToolbox                           0x00007ff817c69996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 5   HIToolbox                           0x00007ff817c31bd2 _NotifyEventLoopObservers + 153
# 6   HIToolbox                           0x00007ff817c693e6 AcquireEventFromQueue + 494
# 7   HIToolbox                           0x00007ff817c583ec ReceiveNextEventCommon + 285
# 8   HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 9   AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 10  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 11  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 12  libqcocoa.dylib                     0x0000000120bd850a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff817c580c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff817c3ace3 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1125
# 3   HIToolbox                           0x00007ff817c3a7a4 _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 46
# 4   HIToolbox                           0x00007ff817c3a762 SetSystemUIMode + 209
# 5   AppKit                              0x00007ff81179c4c3 -[NSApplication _setPresentationOptions:instance:flags:] + 1157
# 6   AppKit                              0x00007ff8115f1185 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 614
# 7   CoreFoundation                      0x00007ff80e30b3f4 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff80e3a543a ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00007ff80e3a5389 _CFXRegistrationPost + 536
# 10  CoreFoundation                      0x00007ff80e2de919 _CFXNotificationPost + 735
# 11  Foundation                          0x00007ff80f118f2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff81179cb28 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff812f3a74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff81324d04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 15  SkyLight                            0x00007ff81324cf71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 16  libdispatch.dylib                   0x00007ff80e0b97fb _dispatch_call_block_and_release + 12
# 17  libdispatch.dylib                   0x00007ff80e0baa44 _dispatch_client_callout + 8
# 18  libdispatch.dylib                   0x00007ff80e0c77b9 _dispatch_main_queue_drain + 952
# 19  libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 20  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 21  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 22  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 23  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 24  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 25  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 26  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 27  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 28  libqcocoa.dylib                     0x0000000120bd81f8 qt_plugin_instance + 147367

# %%
'''
points_layer = viewer.add_points(c3_filtered_df[["frame", "mu_z", "mu_y", "mu_x"]], size=2,
                                name = 'all_points', face_color = 'red', symbol = 'ring')
points_layer = viewer.add_points(c2_filtered_df[["frame", "mu_z", "mu_y", "mu_x"]], size=2,
                                name = 'all_points', face_color = 'yellow', symbol = 'ring')
'''

# %%
# Replace 'your_file.tif' with the path to your 4D TIFF file
file_path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/Channel_3.tif'

# Load the TIFF file using skimage
raw_image = io.imread(file_path)

# Add the 4D stack to the viewer
layer_c3 = viewer.add_image(raw_image)

layer_c3.bounding_box.visible = True
# Out:
# 1   HIToolbox                           0x00007ff817ccb726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff817c6f852 SetMenuBarObscured + 226
# 3   HIToolbox                           0x00007ff817c6f4ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 4   HIToolbox                           0x00007ff817c69996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 5   HIToolbox                           0x00007ff817c31bd2 _NotifyEventLoopObservers + 153
# 6   HIToolbox                           0x00007ff817c693e6 AcquireEventFromQueue + 494
# 7   HIToolbox                           0x00007ff817c583ec ReceiveNextEventCommon + 285
# 8   HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 9   AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 10  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 11  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 12  libqcocoa.dylib                     0x00000001206b550a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff817c580c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff817c3ace3 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1125
# 3   HIToolbox                           0x00007ff817c3a7a4 _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 46
# 4   HIToolbox                           0x00007ff817c3a762 SetSystemUIMode + 209
# 5   AppKit                              0x00007ff81179c4c3 -[NSApplication _setPresentationOptions:instance:flags:] + 1157
# 6   AppKit                              0x00007ff8115f1185 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 614
# 7   CoreFoundation                      0x00007ff80e30b3f4 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff80e3a543a ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00007ff80e3a5389 _CFXRegistrationPost + 536
# 10  CoreFoundation                      0x00007ff80e2de919 _CFXNotificationPost + 735
# 11  Foundation                          0x00007ff80f118f2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff81179cb28 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff812f3a74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff81324d04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 15  SkyLight                            0x00007ff81324cf71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 16  libdispatch.dylib                   0x00007ff80e0b97fb _dispatch_call_block_and_release + 12
# 17  libdispatch.dylib                   0x00007ff80e0baa44 _dispatch_client_callout + 8
# 18  libdispatch.dylib                   0x00007ff80e0c77b9 _dispatch_main_queue_drain + 952
# 19  libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 20  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 21  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 22  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 23  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 24  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 25  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 26  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 27  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 28  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 29  libqcocoa.dylib                     0x00000001206b550a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff817ccb726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff817c94638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff812f3a74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81324d04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81324cf71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff80e0b97fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff80e0baa44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff80e0c77b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x00000001206b550a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff817c580c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff817c3ace3 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1125
# 3   HIToolbox                           0x00007ff817c3a7a4 _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 46
# 4   HIToolbox                           0x00007ff817c3a762 SetSystemUIMode + 209
# 5   AppKit                              0x00007ff81179c4c3 -[NSApplication _setPresentationOptions:instance:flags:] + 1157
# 6   AppKit                              0x00007ff8115f1185 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 614
# 7   CoreFoundation                      0x00007ff80e30b3f4 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff80e3a543a ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00007ff80e3a5389 _CFXRegistrationPost + 536
# 10  CoreFoundation                      0x00007ff80e2de919 _CFXNotificationPost + 735
# 11  Foundation                          0x00007ff80f118f2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff81179cb28 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff812f3a74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff81324d04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 15  SkyLight                            0x00007ff81324cf71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 16  libdispatch.dylib                   0x00007ff80e0b97fb _dispatch_call_block_and_release + 12
# 17  libdispatch.dylib                   0x00007ff80e0baa44 _dispatch_client_callout + 8
# 18  libdispatch.dylib                   0x00007ff80e0c77b9 _dispatch_main_queue_drain + 952
# 19  libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 20  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 21  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 22  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 23  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 24  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 25  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 26  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 27  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 28  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 29  libqcocoa.dylib                     0x00000001206b550a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff817ccb726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff817c94638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff812f3a74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81324d04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81324cf71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff80e0b97fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff80e0baa44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff80e0c77b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x00000001206b550a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff817c580c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff817c3ace3 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1125
# 3   HIToolbox                           0x00007ff817c3a7a4 _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 46
# 4   HIToolbox                           0x00007ff817c3a762 SetSystemUIMode + 209
# 5   AppKit                              0x00007ff81179c4c3 -[NSApplication _setPresentationOptions:instance:flags:] + 1157
# 6   AppKit                              0x00007ff8115f1185 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 614
# 7   CoreFoundation                      0x00007ff80e30b3f4 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff80e3a543a ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00007ff80e3a5389 _CFXRegistrationPost + 536
# 10  CoreFoundation                      0x00007ff80e2de919 _CFXNotificationPost + 735
# 11  Foundation                          0x00007ff80f118f2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff81179cb28 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff812f3a74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff81324d04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 15  SkyLight                            0x00007ff81324cf71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 16  libdispatch.dylib                   0x00007ff80e0b97fb _dispatch_call_block_and_release + 12
# 17  libdispatch.dylib                   0x00007ff80e0baa44 _dispatch_client_callout + 8
# 18  libdispatch.dylib                   0x00007ff80e0c77b9 _dispatch_main_queue_drain + 952
# 19  libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 20  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 21  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 22  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 23  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 24  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 25  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 26  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 27  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 28  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 29  libqcocoa.dylib                     0x00000001206b550a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff817ccb726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff817c94638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff812f3a74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81324d04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81324cf71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff80e0b97fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff80e0baa44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff80e0c77b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff80e0c73f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff80e354610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff80e314b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff80e313b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff817c58766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff817c58576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x00000001206b550a qt_plugin_instance + 148153
# WARNING: Traceback (most recent call last):
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 461, in advance_eventloop
#     eventloop(self)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/ipykernel/eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 97, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/scene/canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/napari/_vispy/camera.py", line 248, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/Users/apple/miniconda3/envs/lap_track/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method add_mouse_pan_zoom_toggles.<locals>._vispy_camera_cls.viewbox_mouse_event of <_vispy_camera_cls at 0x7fd7492d2530>> for SceneMouseEvent
# 1   HIToolbox                           0x00007ff817c580c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff817c6f852 SetMenuBarObscured + 226
# 3   HIToolbox                           0x00007ff817c6f4ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 4   HIToolbox                           0x00007ff817c69996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 5   HIToolbox                           0x00007ff817c31bd2 _NotifyEventLoopObservers + 153
# 6   HIToolbox                           0x00007ff817c693e6 AcquireEventFromQueue + 494
# 7   HIToolbox                           0x00007ff817c585a4 ReceiveNextEventCommon + 725
# 8   HIToolbox                           0x00007ff817c582b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 9   AppKit                              0x00007ff81145ff33 _DPSNextEvent + 909
# 10  AppKit                              0x00007ff81145edb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 11  AppKit                              0x00007ff8114513f7 -[NSApplication run] + 586
# 12  libqcocoa.dylib                     0x00000001206b550a qt_plugin_instance + 148153
