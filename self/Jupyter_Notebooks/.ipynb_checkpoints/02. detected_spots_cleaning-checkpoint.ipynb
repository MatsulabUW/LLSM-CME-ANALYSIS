# %%
from os import path
import pandas as pd
from IPython.display import display
from matplotlib import pyplot as plt
import napari
from skimage import io
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams["font.family"] = ""

# %%
path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/spots_intensities_c3_all.pkl'
spots_df = pd.read_pickle(path)

# %%
spots_df.head()
# Out:
#     amplitude   mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  frame
# 0  206.593249   11.0   12.0   0.0      2.0      2.0      4.0      0
# 1  198.333333   69.0   52.0  -2.0      2.0      2.0      7.0      0
# 2  207.348417  103.0  123.0   4.0      3.0      2.0     36.0      0
# 3  185.333333  104.0  244.0  -2.0      4.0      2.0      7.0      0
# 4  191.000000   36.0   88.0   1.0      2.0      1.0      2.0      0

# %%
spots_df.shape
# Out:
# (60142, 8)

# %% [markdown]
# # Analysing Amplitude
# 1. Box and Whisker Plot to find the upper and lower quartiles and caps
# 2. Histogram to try and understand the distribution of the amplitude

# %%
#to store the upper and lower whisker edge
limits = []

# Plot the box and whisker plot
plt.figure(figsize=(10, 6))
boxplot = plt.boxplot(spots_df['amplitude'])

# Add annotations for edges (minimum, 25th percentile, median, 75th percentile, maximum)
edges = ['min', '25%', 'median', '75%', 'max']
values = [item.get_ydata()[0] for item in boxplot['whiskers']]

# Add annotations for caps
for value in [item.get_ydata()[0] for item in boxplot['caps']]:
    plt.text(0.5, value,
             f'Cap: {value:.2f}',
             horizontalalignment='right',
             verticalalignment='center',
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightyellow")
             )
    limits.append(value)

#getting the lower and upper limits for the whiskers
upper_limit_amp = limits[1]
lower_limit_amp = limits[0]
    

# Add annotations for 25th percentile, mean, and 75th percentile
for value, label in zip([spots_df['amplitude'].quantile(0.25),
                         spots_df['amplitude'].mean(),
                         spots_df['amplitude'].quantile(0.75)],
                        ['25th Percentile', 'Mean', '75th Percentile']):
    plt.text(1.5, value,
             f'{label}: {value:.2f}',
             horizontalalignment='left',
             verticalalignment='center',
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightyellow")
             )


plt.xlabel('Spots')
plt.ylabel('Amplitude')
plt.title('Box and Whisker Plot of Amplitude of spots')

plt.show()

# %%
print(len(spots_df[spots_df['amplitude'] > upper_limit_amp]))
# Out:
# 2535

# %% [markdown]
# **Use the below dataframe for visualisation in napari and determine the final cuttoff**

# %%
high_amplitude_df = spots_df[spots_df['amplitude'] > upper_limit_amp].sort_values(by = 'amplitude', ascending = False)
high_amplitude_df.head()
# Out:
#         amplitude   mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  frame
# 4334   564.000000  202.0  229.0  56.0      1.0      1.0      2.0      7
# 1031   558.000000  223.0   95.0  60.0      1.0      1.0      2.0      1
# 1114   539.472079  136.0  152.0  72.0      2.0      2.0      2.0      1
# 25718  532.666667  122.0  177.0  65.0      0.0      2.0      1.0     48
# 3923   528.000000  198.0  182.0  76.0      2.0      1.0      5.0      6

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Create the histogram with seaborn
ax = sns.histplot(spots_df['amplitude'], bins=range(175, 651, 50), kde=True, color = 'blue',
             kde_kws={'bw_method': 1}, line_kws = dict(color='green'), edgecolor='black', alpha=0.7)
ax.get_lines()[0].set_color('green') 
# Add a mean line
mean_amplitude = spots_df['amplitude'].mean()
plt.axvline(x=mean_amplitude, color='red', linestyle='--', label=f'Mean: {mean_amplitude:.2f}')

# Set labels and title
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.title('Amplitude Histogram with Mean Line and KDE')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Analysing Std Dev of X
# 1. Box and Whisker Plot to find the upper and lower quartiles and caps
# 2. Histogram to try and understand the distribution of the sigma_x

# %%
# store the upper and lower edge of the whiskers (lower,upper)
limits = []

# Plot the box and whisker plot
plt.figure(figsize=(10, 6))
boxplot = plt.boxplot(spots_df['sigma_x'])

# Add annotations for edges (minimum, 25th percentile, median, 75th percentile, maximum)
edges = ['min', '25%', 'median', '75%', 'max']
values = [item.get_ydata()[0] for item in boxplot['whiskers']]


# Add annotations for caps
for value in [item.get_ydata()[0] for item in boxplot['caps']]:
    plt.text(0.5, value,
             f'Cap: {value:.2f}',
             horizontalalignment='right',
             verticalalignment='center',
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightyellow")
             )
    limits.append(value)

upper_limit_sigmax = limits[1]
lower_limit_sigmax = limits[0]

# Add annotations for 25th percentile, mean, and 75th percentile
for value, label in zip([spots_df['sigma_x'].quantile(0.25),
                         spots_df['sigma_x'].mean(),
                         spots_df['sigma_x'].quantile(0.75)],
                        ['25th Percentile', 'Mean', '75th Percentile']):
    plt.text(1.5, value,
             f'{label}: {value:.2f}',
             horizontalalignment='left',
             verticalalignment='center',
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightyellow")
             )

# Set the y-axis range (adjust the values accordingly)
#plt.ylim(0, 10)  # Change the range as needed
plt.xlabel('Tracks')
plt.ylabel('Movement')
plt.title('Box and Whisker Plot of Sigma_x of spots')

plt.show()

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Create the histogram with seaborn for sigma_x
ax = sns.histplot(spots_df['sigma_x'], bins=range(0, 41, 1), kde=True, color='blue',
              kde_kws={'bw_method': 1}, edgecolor='black', alpha=1)
ax.get_lines()[0].set_color('green') 
ax.set_xlim(0, 20)

# Add a mean line
mean_sigma_x = spots_df['sigma_x'].mean()
plt.axvline(x=mean_sigma_x, color='red', linestyle='--', label=f'Mean: {mean_sigma_x:.2f}')

# Set labels and title
plt.xlabel('sigma_x')
plt.ylabel('Frequency')
plt.title('Histogram with Mean Line and KDE Curve for sigma_x')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
high_sigmax_df = spots_df[spots_df['sigma_x'] > 4].sort_values(by = 'sigma_x', ascending = False)
high_sigmax_df.head()
# Out:
#         amplitude   mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  frame
# 32154  184.009140  195.0  190.0  31.0     47.0      2.0      4.0     62
# 46749  203.126035  104.0  244.0  35.0     38.0      2.0      3.0     95
# 14586  196.319373  126.0   29.0  68.0     37.0      2.0     11.0     26
# 30112  226.381945  112.0  146.0   2.0     30.0      1.0      3.0     58
# 50301  199.616651  234.0   33.0  65.0     27.0      2.0      4.0    103

# %%
high_sigmax_df.shape
# Out:
# (1227, 8)

# %%
low_sigmax_df = spots_df[spots_df['sigma_x'] == 0].sort_values(by = 'sigma_x', ascending = False)
low_sigmax_df.head()
# Out:
#         amplitude   mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  frame
# 16     208.666667   10.0   12.0   1.0      0.0      2.0      1.0      0
# 37844  197.333333  121.0  203.0  64.0      0.0      7.0      1.0     74
# 37609  202.333333   48.0   61.0  22.0      0.0      1.0      1.0     74
# 37741  277.666667   95.0   22.0  49.0      0.0      1.0      1.0     74
# 37746  192.024639   96.0  102.0  49.0      0.0      1.0      2.0     74

# %%
low_sigmax_df.shape
# Out:
# (2704, 8)

# %% [markdown]
# # NOTES FOR SIGMA_X
# # Two cases for sigma_x need to be tackled
# 1. **Spots with standard deviation of 0**
# 2. **Spots with standard deviation of more than 4**

# %% [markdown]
# # Analysing Std Dev of Y
# 1. Box and Whisker Plot to find the upper and lower quartiles and caps
# 2. Histogram to try and understand the distribution of the sigma_y

# %%
# store the upper and lower edge of the whiskers (lower,upper)
limits = []

# Plot the box and whisker plot
plt.figure(figsize=(10, 6))
boxplot = plt.boxplot(spots_df['sigma_y'])

# Add annotations for edges (minimum, 25th percentile, median, 75th percentile, maximum)
edges = ['min', '25%', 'median', '75%', 'max']
values = [item.get_ydata()[0] for item in boxplot['whiskers']]

# Add annotations for caps
for value in [item.get_ydata()[0] for item in boxplot['caps']]:
    plt.text(0.5, value,
             f'Cap: {value:.2f}',
             horizontalalignment='right',
             verticalalignment='center',
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightyellow")
             )
    limits.append(value)

upper_limit_sigmay = limits[1]
lower_limit_sigmay = limits[0]

# Add annotations for 25th percentile, mean, and 75th percentile
for value, label in zip([spots_df['sigma_y'].quantile(0.25),
                         spots_df['sigma_y'].mean(),
                         spots_df['sigma_y'].quantile(0.75)],
                        ['25th Percentile', 'Mean', '75th Percentile']):
    plt.text(1.5, value,
             f'{label}: {value:.2f}',
             horizontalalignment='left',
             verticalalignment='center',
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightyellow")
             )


plt.xlabel('Tracks')
plt.ylabel('Movement')
plt.title('Box and Whisker Plot of Sigma_y')

plt.show()

# %%
print(upper_limit_sigmay)
print(lower_limit_sigmay)
# Out:
# 3.0
# 1.0

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Create the histogram with seaborn for sigma_y
ax = sns.histplot(spots_df['sigma_y'], bins=range(0, 41, 1), kde=True, color='blue',
              kde_kws={'bw_method': 1}, edgecolor='black', alpha=1)
ax.get_lines()[0].set_color('green') 
ax.set_xlim(0, 20)

# Add a mean line
mean_sigma_x = spots_df['sigma_y'].mean()
plt.axvline(x=mean_sigma_x, color='red', linestyle='--', label=f'Mean: {mean_sigma_x:.2f}')

# Set labels and title
plt.xlabel('sigma_y')
plt.ylabel('Frequency')
plt.title('Histogram with Mean Line and KDE Curve for sigma_y')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
high_sigmay_df = spots_df[spots_df['sigma_y']>4].sort_values(by='sigma_y', ascending = False)
high_sigmay_df.head()
# Out:
#         amplitude   mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  frame
# 7005   197.333333   81.0   56.0  40.0      0.0    152.0      2.0     12
# 58148  190.632666  122.0  199.0  32.0      2.0     30.0      4.0    124
# 11471  296.000000  231.0  149.0  70.0      2.0     29.0      4.0     20
# 21266  180.333333  117.0   76.0  62.0      0.0     28.0      1.0     39
# 140    221.333333   29.0   28.0  10.0      0.0     26.0      2.0      0

# %%
high_sigmay_df.shape
# Out:
# (2142, 8)

# %% [markdown]
# # Analysing Std Dev of Z
# 1. Box and Whisker Plot to find the upper and lower quartiles and caps
# 2. Histogram to try and understand the distribution of the sigma_z

# %%
# store the upper and lower edge of the whiskers (lower,upper)
limits = []

# Plot the box and whisker plot
plt.figure(figsize=(10, 6))
boxplot = plt.boxplot(spots_df['sigma_z'])

# Add annotations for edges (minimum, 25th percentile, median, 75th percentile, maximum)
edges = ['min', '25%', 'median', '75%', 'max']
values = [item.get_ydata()[0] for item in boxplot['whiskers']]


# Add annotations for caps
for value in [item.get_ydata()[0] for item in boxplot['caps']]:
    plt.text(0.5, value,
             f'Cap: {value:.2f}',
             horizontalalignment='right',
             verticalalignment='center',
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightyellow")
             )
    limits.append(value)
    
upper_limit_sigmaz = limits[1]
lower_limit_sigmaz = limits[0]


# Add annotations for 25th percentile, mean, and 75th percentile
for value, label in zip([spots_df['sigma_z'].quantile(0.25),
                         spots_df['sigma_z'].mean(),
                         spots_df['sigma_z'].quantile(0.75)],
                        ['25th Percentile', 'Mean', '75th Percentile']):
    plt.text(1.5, value,
             f'{label}: {value:.2f}',
             horizontalalignment='left',
             verticalalignment='center',
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightyellow")
             )


plt.xlabel('Tracks')
plt.ylabel('Movement')
plt.title('Box and Whisker Plot of Sigma Z')

plt.show()

# %%
print(upper_limit_sigmaz)
print(lower_limit_sigmaz)
# Out:
# 5.0
# 2.0

# %%
print(len(spots_df[spots_df['sigma_z'] > 6]))
# Out:
# 5650

# %%
high_sigmaz_df = spots_df[spots_df['sigma_z'] > 6]

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Create the histogram with seaborn for sigma_z
ax = sns.histplot(spots_df['sigma_z'], bins=range(0, 41, 1), kde=True, color='blue',
              kde_kws={'bw_method': 0.1}, edgecolor='black', alpha=1)
ax.set_xlim(0, 20)
ax.get_lines()[0].set_color('green') 

# Add a mean line
mean_sigma_z = spots_df['sigma_z'].mean()
plt.axvline(x=mean_sigma_z, color='red', linestyle='--', label=f'Mean: {mean_sigma_z:.2f}')

# Set labels and title
plt.xlabel('sigma_z')
plt.ylabel('Frequency')
plt.title('Histogram with Mean Line and KDE Curve for sigma_z')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
spots_df['sigma_z'].describe()
# Out:
# count    60142.000000
# mean         4.757757
# std        127.680828
# min        -13.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max      21142.000000
# Name: sigma_z, dtype: float64

# %%
spots_df['sigma_y'].describe()
# Out:
# count    60142.000000
# mean         1.829071
# std          1.467726
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max        152.000000
# Name: sigma_y, dtype: float64

# %%
spots_df['sigma_x'].describe()
# Out:
# count    60142.000000
# mean         2.024276
# std          1.152124
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max         47.000000
# Name: sigma_x, dtype: float64

# %% [markdown]
# # NAPARI VISUALISATION

# %% [markdown]
# # HIGH AMPLITUDE POINTS VISUALISATION

# %%
# Create a napari viewer
viewer = napari.Viewer()

# Replace 'your_file.tif' with the path to your 4D TIFF file
file_path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/Channel3_complete.tif'

# Load the TIFF file using skimage
raw_image_3 = io.imread(file_path)

# Add the 4D stack to the viewer
layer_raw = viewer.add_image(raw_image)

# Add Bounding Box
layer_raw.bounding_box.visible = True

# %%
points_layer = viewer.add_points(high_amplitude_df[["frame", "mu_z", "mu_y", "mu_x"]], size=3, 
                                name = 'High Amplitude Points', face_color = 'white', symbol = 'ring')

# %%
high_amplitude_df.iloc[185:195]
# Out:
#         amplitude   mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  frame
# 271    433.305421  197.0  218.0  36.0      2.0      2.0      3.0      0
# 8234   433.000000  237.0   62.0  57.0      2.0      1.0      2.0     14
# 45220  433.000000  124.0  176.0  65.0      1.0      1.0      2.0     91
# 2791   433.000000  135.0  153.0  71.0      2.0      2.0      4.0      4
# 18215  432.333333  122.0  175.0  65.0      1.0      1.0      2.0     33
# 38728  432.202747  127.0  177.0  65.0      9.0      2.0      2.0     76
# 31484  432.200323  208.0  182.0  75.0      2.0      2.0      5.0     60
# 12549  432.000000  135.0  153.0  70.0      2.0      2.0      3.0     22
# 10403  431.933123  124.0  177.0  66.0      0.0      2.0      1.0     18
# 15694  431.757733  204.0  182.0  75.0      4.0      3.0      5.0     28

# %%
high_amplitude_df[high_amplitude_df['frame'] == 115]
# Out:
#         amplitude   mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  frame
# 55055  388.000000  253.0  151.0  70.0      3.0      1.0      3.0    115
# 55020  378.333333  122.0  175.0  65.0      0.0      1.0      1.0    115
# 55071  358.333333  206.0  186.0  72.0      2.0      1.0      3.0    115
# 54798  346.000000  122.0  201.0  14.0      2.0      1.0      3.0    115
# 55029  345.000000  137.0  153.0  68.0      1.0      1.0      2.0    115
# 55046  331.474447  263.0  149.0  71.0      2.0      2.0      2.0    115
# 55085  324.453822  195.0  190.0  73.0      3.0      2.0      3.0    115

# %%
'''
One way of accessing points data from napari is finding the point on napari and then accessing its coords by 
getting that specific row from numpy array, for example to access point 1014 do the following. 
coords = points_layer.data
coords[1014]
'''
# Out:
# '\nOne way of accessing points data from napari is finding the point on napari and then accessing its coords by \ngetting that specific row from numpy array, for example to access point 1014 do the following. \ncoords = points_layer.data\ncoords[1014]\n'

# %%
high_amplitude_df.iloc[1034]
# Out:
# amplitude    357.936267
# mu_x         179.000000
# mu_y         193.000000
# mu_z          53.000000
# sigma_x        2.000000
# sigma_y        1.000000
# sigma_z        3.000000
# frame          0.000000
# Name: 394, dtype: float64

# %%
coords = points_layer.data
coords[184]
# Out:
# array([  0.,  54., 230., 105.])

# %%
high_amplitude_df['amplitude'].min()
# Out:
# 319.8917667125093

# %% [markdown]
# ## High Sigma X points analysis in Napari

# %%
points_layer = viewer.add_points(high_sigmax_df[["frame", "mu_z", "mu_y", "mu_x"]], size=3, 
                                name = 'High Sigma X points', face_color = 'white', symbol = 'ring')

# %%
high_sigmax_df.iloc[972]
# Out:
# amplitude    454.068257
# mu_x         206.000000
# mu_y         179.000000
# mu_z          75.000000
# sigma_x        5.000000
# sigma_y        3.000000
# sigma_z        4.000000
# frame          0.000000
# Name: 577, dtype: float64

# %%
points_layer = viewer.add_points(low_sigmax_df[["frame", "mu_z", "mu_y", "mu_x"]], size=3, 
                                name = 'Low Sigma X points', face_color = 'white', symbol = 'ring')

# %%
low_sigmax_df.iloc[1906]
# Out:
# amplitude    295.666667
# mu_x         114.000000
# mu_y         208.000000
# mu_z          60.000000
# sigma_x        0.000000
# sigma_y        3.000000
# sigma_z        1.000000
# frame         10.000000
# Name: 6048, dtype: float64

# %% [markdown]
# # Testing for Sigma y in napari

# %%
points_layer = viewer.add_points(high_sigmay_df[["frame", "mu_z", "mu_y", "mu_x"]], size=3, 
                                name = 'High Sigma Y points', face_color = 'white', symbol = 'ring')

# %% [markdown]
# # Testing for Sigma z in napari

# %%
points_layer = viewer.add_points(high_sigmaz_df[["frame", "mu_z", "mu_y", "mu_x"]], size=3, 
                                name = 'High Sigma Z points', face_color = 'white', symbol = 'ring')

# %%
high_sigmaz_df.iloc[662]
# Out:
# amplitude    329.0
# mu_x         235.0
# mu_y         169.0
# mu_z          76.0
# sigma_x        4.0
# sigma_y        2.0
# sigma_z       10.0
# frame         12.0
# Name: 7246, dtype: float64

# %% [markdown]
# # DROPPING VALUES OUTSIDE OF CUTOFF LIMITS
# ## Selected Cut off Values are
# 1. Amplitude is 350
# 2. Sigma x upper bound is 4
# 3. Sigma y upper bound is 4
# 4. Sigma z upper bound is 6

# %%
# Define the conditions
condition_1 = spots_df['amplitude'] <= 350
condition_2 = spots_df['sigma_x'] <= 4
condition_3 = spots_df['sigma_y'] <= 4
condition_4 = spots_df['sigma_z'] <= 6
condition_5 = spots_df['mu_z'] >= 0
condition_6 = spots_df['mu_z'] <= 74


# Combine the conditions using logical AND (&)
cleaned_spots_df = spots_df[condition_1 & condition_2 & condition_3 & condition_4 & condition_5 & condition_6]

# Display the resulting DataFrame
cleaned_spots_df.head()
# Out:
#     amplitude  mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  frame
# 0  206.593249  11.0   12.0   0.0      2.0      2.0      4.0      0
# 4  191.000000  36.0   88.0   1.0      2.0      1.0      2.0      0
# 5  231.007679  40.0  141.0   1.0      2.0      2.0      2.0      0
# 6  185.152538  40.0   58.0   1.0      2.0      1.0      3.0      0
# 7  202.000000  46.0   73.0   1.0      2.0      2.0      3.0      0

# %%
dropped_spots = spots_df[~(condition_1 & condition_2 & condition_3 & condition_4 & condition_5 & condition_6)]

# %%
cleaned_spots_df['mu_z'].min()
# Out:
# 0.0

# %%
cleaned_spots_df.shape
# Out:
# (49867, 8)

# %%
# Set up subplots as a 2x2 grid
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Box plot for Amplitude
sns.boxplot(y='amplitude', data=cleaned_spots_df, ax=axes[0], showmeans=True, meanline=True, showfliers=False)
axes[0].set_title('Amplitude')

# Box plot for sigma_x
sns.boxplot(y='sigma_x', data=cleaned_spots_df, ax=axes[1], showmeans=True, meanline=True, showfliers=False)
axes[1].set_title('Sigma_x')

# Box plot for sigma_y
sns.boxplot(y='sigma_y', data=cleaned_spots_df, ax=axes[2], showmeans=True, meanline=True, showfliers=False)
axes[2].set_title('Sigma_y')

# Box plot for sigma_z
sns.boxplot(y='sigma_z', data=cleaned_spots_df, ax=axes[3], showmeans=True, meanline=True, showfliers=False)
axes[3].set_title('Sigma_z')

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming cleaned_spots_df is your DataFrame with columns 'Amplitude', 'sigma_x', 'sigma_y', 'sigma_z'

# Set up subplots as a 2x2 grid
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Histogram for Amplitude with bins of size 50 starting from 180
axes[0].hist(cleaned_spots_df['amplitude'].dropna(), bins=range(180, int(cleaned_spots_df['amplitude'].max()) + 50, 50))
axes[0].set_title('Amplitude Histogram')

# Histogram for sigma_x with bins of size 1 starting from 0
axes[1].hist(cleaned_spots_df['sigma_x'].dropna(), bins=range(0, int(cleaned_spots_df['sigma_x'].max()) + 1, 1))
axes[1].set_title('Sigma_x Histogram')

# Histogram for sigma_y with bins of size 1 starting from 0
axes[2].hist(cleaned_spots_df['sigma_y'].dropna(), bins=range(0, int(cleaned_spots_df['sigma_y'].max()) + 1, 1))
axes[2].set_title('Sigma_y Histogram')

# Histogram for sigma_z with bins of size 1 starting from 0
axes[3].hist(cleaned_spots_df['sigma_z'].dropna(), bins=range(0, int(cleaned_spots_df['sigma_z'].max()) + 1, 1))
axes[3].set_title('Sigma_z Histogram')

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Set up subplots as a 2x2 grid
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Histogram for Amplitude with bins of size 50 starting from 180
ax = axes[0].hist(cleaned_spots_df['amplitude'], bins=range(175,375,10), edgecolor='black', density = True,alpha=0.7)
sns.kdeplot(cleaned_spots_df['amplitude'], ax=axes[0], color='red', linewidth=2, bw_method=1)
axes[0].set_title('Amplitude Histogram')

# Histogram for sigma_x with bins of size 1 starting from 0
axes[1].hist(cleaned_spots_df['sigma_x'], bins=range(0, int(cleaned_spots_df['sigma_x'].max()) + 1, 1), 
              density = True, edgecolor='black', alpha=0.7)
sns.kdeplot(cleaned_spots_df['sigma_x'], ax=axes[1], color='red', linewidth=2, bw_method=1)
axes[1].set_title('Sigma_x Histogram')

# Histogram for sigma_y with bins of size 1 starting from 0
axes[2].hist(cleaned_spots_df['sigma_y'], bins=range(0, int(cleaned_spots_df['sigma_y'].max()) + 1, 1), 
             density=True, edgecolor='black', alpha=0.7)
sns.kdeplot(cleaned_spots_df['sigma_y'], ax=axes[2], color='red', linewidth=2, bw_method=1)
axes[2].set_title('Sigma_y Histogram')

# Histogram for sigma_z with bins of size 1 starting from 0
axes[3].hist(cleaned_spots_df['sigma_z'], bins=range(0, int(cleaned_spots_df['sigma_z'].max()) + 1, 1), 
             density=True, edgecolor='black', alpha=0.7)
sns.kdeplot(cleaned_spots_df['sigma_z'], ax=axes[3], color='red', linewidth=2, bw_method=1)
axes[3].set_title('Sigma_z Histogram')

# Set x-axis limit for sigma_z KDE plot
axes[1].set_xlim(0, cleaned_spots_df['sigma_z'].max())
axes[2].set_xlim(0, cleaned_spots_df['sigma_z'].max())
axes[3].set_xlim(0, cleaned_spots_df['sigma_z'].max())

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# 1   HIToolbox                           0x00007ff81cd90726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81cd902b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff81ccffcd7 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1113
# 4   HIToolbox                           0x00007ff81cd90173 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 175
# 5   AppKit                              0x00007ff8168614b7 -[NSApplication _setPresentationOptions:instance:flags:] + 1145
# 6   AppKit                              0x00007ff8166b6165 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 582
# 7   AppKit                              0x00007ff817104a40 -[_NSFullScreenSpace(PresentationInstance) activateFullScreenPresentationOptions] + 207
# 8   AppKit                              0x00007ff816f57848 -[_NSEnterFullScreenTransitionController _doSucceededToEnterFullScreen] + 721
# 9   AppKit                              0x00007ff816f58357 __65-[_NSEnterFullScreenTransitionController _performEnterFullScreen]_block_invoke + 451
# 10  AppKit                              0x00007ff81690485e __NSFullScreenDockConnectionSendEnterForSpace_block_invoke + 135
# 11  libxpc.dylib                        0x00007ff81306cfb3 _xpc_connection_reply_callout + 36
# 12  libxpc.dylib                        0x00007ff81306cf3b _xpc_connection_call_reply_async + 69
# 13  libdispatch.dylib                   0x00007ff81317faaa _dispatch_client_callout3 + 8
# 14  libdispatch.dylib                   0x00007ff81319ac6f _dispatch_mach_msg_async_reply_invoke + 387
# 15  libdispatch.dylib                   0x00007ff81318c6ee _dispatch_main_queue_drain + 749
# 16  libdispatch.dylib                   0x00007ff81318c3f3 _dispatch_main_queue_callback_4CF + 31
# 17  CoreFoundation                      0x00007ff813419610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 18  CoreFoundation                      0x00007ff8133d9b90 __CFRunLoopRun + 2454
# 19  CoreFoundation                      0x00007ff8133d8b80 CFRunLoopRunSpecific + 560
# 20  HIToolbox                           0x00007ff81cd1d766 RunCurrentEventLoopInMode + 292
# 21  HIToolbox                           0x00007ff81cd1d576 ReceiveNextEventCommon + 679
# 22  HIToolbox                           0x00007ff81cd1d2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 23  AppKit                              0x00007ff816524f33 _DPSNextEvent + 909
# 24  AppKit                              0x00007ff816523db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 25  AppKit                              0x00007ff8165163f7 -[NSApplication run] + 586
# 26  libqcocoa.dylib                     0x00000001184ba50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cd1d0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81cd59638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817fff74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81831204a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff818311f71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff81317e7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff81317fa44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff81318c7b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff81318c3f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813419610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8133d9b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8133d8b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cd1d766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cd1d576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cd1d2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816524f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816523db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8165163f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x00000001184ba50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cd90726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81cd59638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817fff74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81831204a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff818311f71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff81317e7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff81317fa44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff81318c7b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff81318c3f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813419610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8133d9b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8133d8b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cd1d766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cd1d576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cd1d2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816524f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816523db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8165163f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x00000001184ba50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cd1d0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81cd90f72 _ZN15MenuBarInstance15DisableAutoShowEv + 24
# 3   HIToolbox                           0x00007ff81cd91077 _ZN15MenuBarInstanceD2Ev + 113
# 4   HIToolbox                           0x00007ff81cd90ebb _ZN15MenuBarInstance7ReleaseEv + 35
# 5   AppKit                              0x00007ff816c9ca0d -[NSHIPresentationInstance discard] + 277
# 6   AppKit                              0x00007ff817104952 -[_NSFullScreenSpace(PresentationInstance) discardPresentationInstance] + 36
# 7   AppKit                              0x00007ff8171049c7 -[_NSFullScreenSpace(PresentationInstance) activateFullScreenPresentationOptions] + 86
# 8   AppKit                              0x00007ff816f1cdb9 -[_NSExitFullScreenTransitionController _doSucceededToExitFullScreen] + 38
# 9   AppKit                              0x00007ff816f1d91b __63-[_NSExitFullScreenTransitionController _performExitFullScreen]_block_invoke + 249
# 10  libxpc.dylib                        0x00007ff81306cfb3 _xpc_connection_reply_callout + 36
# 11  libxpc.dylib                        0x00007ff81306cf3b _xpc_connection_call_reply_async + 69
# 12  libdispatch.dylib                   0x00007ff81317faaa _dispatch_client_callout3 + 8
# 13  libdispatch.dylib                   0x00007ff81319ac6f _dispatch_mach_msg_async_reply_invoke + 387
# 14  libdispatch.dylib                   0x00007ff81318c6ee _dispatch_main_queue_drain + 749
# 15  libdispatch.dylib                   0x00007ff81318c3f3 _dispatch_main_queue_callback_4CF + 31
# 16  CoreFoundation                      0x00007ff813419610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 17  CoreFoundation                      0x00007ff8133d9b90 __CFRunLoopRun + 2454
# 18  CoreFoundation                      0x00007ff8133d8b80 CFRunLoopRunSpecific + 560
# 19  HIToolbox                           0x00007ff81cd1d766 RunCurrentEventLoopInMode + 292
# 20  HIToolbox                           0x00007ff81cd1d576 ReceiveNextEventCommon + 679
# 21  HIToolbox                           0x00007ff81cd1d2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 22  AppKit                              0x00007ff816524f33 _DPSNextEvent + 909
# 23  AppKit                              0x00007ff816523db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 24  libqcocoa.dylib                     0x00000001184ba1f8 qt_plugin_instance + 147367

# %%
cleaned_spots_df['sigma_x'].describe()
# Out:
# count    49867.000000
# mean         1.899934
# std          0.762162
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max          4.000000
# Name: sigma_x, dtype: float64

# %%
cleaned_spots_df['sigma_x'].plot(kind='box', showmeans=True)
# Out:
# <Axes: >

# %%
cleaned_spots_df['amplitude'].describe()
# Out:
# count    49867.000000
# mean       220.430355
# std         38.029763
# min        175.000000
# 25%        190.333333
# 50%        210.000000
# 75%        240.956261
# max        349.793612
# Name: amplitude, dtype: float64

# %%
output_path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/cleaned_spots_intensities_c3_all.pkl'
# Save the DataFrame to a Pickle file
cleaned_spots_df.to_pickle(output_path)
