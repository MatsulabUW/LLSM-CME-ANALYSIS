# %%
from os import path
import pandas as pd
from IPython.display import display
from matplotlib import pyplot as plt
from skimage import io
import numpy as np 

plt.rcParams["font.family"] = ""

# %%
track_df = pd.read_pickle('/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/track_df_updated.pkl')

# %%
track_df.head()
# Out:
#    frame  index   amplitude  mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  \
# 0      0      0  206.593249  11.0   12.0   0.0      2.0      2.0      4.0
# 1      0      1  191.000000  36.0   88.0   1.0      2.0      1.0      2.0
# 2      0      2  231.007679  40.0  141.0   1.0      2.0      2.0      2.0
# 3      0      3  185.152538  40.0   58.0   1.0      2.0      1.0      3.0
# 4      0      4  202.000000  46.0   73.0   1.0      2.0      2.0      3.0
#
#    frame_y  ...  track_id      c2_amp  c2_peak  c2_peak_x  c2_peak_y  \
# 0        0  ...         0  122.947826    152.0        9.0       14.0
# 1        0  ...         1  116.233333    143.0       34.0       87.0
# 2        0  ...         2  122.330000    142.0       41.0      142.0
# 3        0  ...         3  117.626667    142.0       42.0       59.0
# 4        0  ...         4  115.112000    141.0       45.0       74.0
#
#    c2_peak_z  c3_mean_amp  c2_peak_mean  c2_voxel_sum  c3_voxel_sum
# 0        2.0   163.682353    125.500000         11295         13913
# 1        2.0   138.233333    114.826667         20068         19928
# 2        0.0   153.940000    122.853333         15316         22805
# 3        0.0   141.280000    118.016667         14557         20358
# 4        3.0   147.768000    115.502857         23194         21963
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Finding lengths of each of the track

# %%
lengths_df = track_df['track_id'].value_counts().reset_index()
lengths_df.columns = ['track_id', 'length']
lengths_df
# Out:
#        track_id  length
# 0          3344      63
# 1           212      60
# 2           286      51
# 3          7239      51
# 4         12615      49
# ...         ...     ...
# 18918      8179       1
# 18919      8180       1
# 18920      8182       1
# 18921      8189       1
# 18922     18922       1
#
# [18923 rows x 2 columns]

# %% [markdown]
# ## Finding channel 2 peak (c2_peak) and channel 3 peak (amplitude) for each track

# %%
#Group by 'track_id' and find the maximum value of 'c2_peak_max'
max_amp_per_track = track_df.groupby('track_id')[['c2_peak','amplitude']].max().reset_index()
filtered_tracks_1 = max_amp_per_track[max_amp_per_track['c2_peak'] > 170]
filtered_tracks_1
# Out:
#        track_id  c2_peak   amplitude
# 9             9    172.0  235.809569
# 17           17    201.0  226.502247
# 22           22    172.0  249.375311
# 27           27    181.0  254.000000
# 32           32    174.0  261.000000
# ...         ...      ...         ...
# 18909     18909    188.0  268.000000
# 18911     18911    197.0  227.000000
# 18913     18913    200.0  228.000000
# 18916     18916    197.0  253.000000
# 18921     18921    181.0  274.813463
#
# [5139 rows x 3 columns]

# %% [markdown]
# ## Merging the above dataframe with lengths dataframe

# %%
filtered_tracks_with_lengths = pd.merge(filtered_tracks_1,lengths_df, on='track_id')
filtered_tracks_with_lengths.columns = ['track_id', 'c2_peak', 'amplitude', 'length']
filtered_tracks_with_lengths.head()
# Out:
#    track_id  c2_peak   amplitude  length
# 0         9    172.0  235.809569       1
# 1        17    201.0  226.502247       8
# 2        22    172.0  249.375311       3
# 3        27    181.0  254.000000       3
# 4        32    174.0  261.000000       5

# %% [markdown]
# ## Finding the starting frame of each track

# %%
# Group by 'track_id' and find the minimum frame for each track
starting_frame_per_track = track_df.groupby('track_id')['frame'].min().reset_index()

starting_frame_per_track.columns = ['track_id', 'start_frame']
# Display the resulting DataFrame
starting_frame_per_track.head()
# Out:
#    track_id  start_frame
# 0         0            0
# 1         1            0
# 2         2            0
# 3         3            0
# 4         4            0

# %% [markdown]
# ## Finding the ending frame of each dataframe

# %%
ending_frame_per_track = track_df.groupby('track_id')['frame'].max().reset_index()

ending_frame_per_track.columns = ['track_id', 'end_frame']
# Display the resulting DataFrame
ending_frame_per_track.head()
# Out:
#    track_id  end_frame
# 0         0          0
# 1         1          0
# 2         2          0
# 3         3          0
# 4         4          1

# %% [markdown]
# ## Merging with the starting dataframe
# ### Now we have peaks, length and starting frame

# %%
filtered_tracks_with_start = pd.merge(filtered_tracks_with_lengths, starting_frame_per_track, on='track_id', how = 'inner')
filtered_tracks_with_start.head()
# Out:
#    track_id  c2_peak   amplitude  length  start_frame
# 0         9    172.0  235.809569       1            0
# 1        17    201.0  226.502247       8            0
# 2        22    172.0  249.375311       3            0
# 3        27    181.0  254.000000       3            0
# 4        32    174.0  261.000000       5            0

# %% [markdown]
# # Merging with the ending dataframe
# ### Now we have peaks, length, starting frame, ending frame

# %%
filtered_tracks_with_start_end = pd.merge(filtered_tracks_with_start,ending_frame_per_track, on='track_id',how='inner')
filtered_tracks_with_start_end.head()
# Out:
#    track_id  c2_peak   amplitude  length  start_frame  end_frame
# 0         9    172.0  235.809569       1            0          0
# 1        17    201.0  226.502247       8            0          7
# 2        22    172.0  249.375311       3            0          2
# 3        27    181.0  254.000000       3            0          2
# 4        32    174.0  261.000000       5            0          4

# %% [markdown]
# ## Created a temporary dataframe

# %%
temp = track_df[['frame', 'track_id', 'c2_peak']]
temp.head()
# Out:
#    frame  track_id  c2_peak
# 0      0         0    152.0
# 1      0         1    143.0
# 2      0         2    142.0
# 3      0         3    142.0
# 4      0         4    141.0

# %% [markdown]
# ## Merged with the temporary dataframe to get the frame number at which c2_peak is achieved for each track

# %%
# Merge based on two columns ('column1' and 'column2')
final_df = pd.merge(filtered_tracks_with_start_end, temp, on=['track_id', 'c2_peak'], how='inner')

final_df.head()
# Out:
#    track_id  c2_peak   amplitude  length  start_frame  end_frame  frame
# 0         9    172.0  235.809569       1            0          0      0
# 1        17    201.0  226.502247       8            0          7      7
# 2        22    172.0  249.375311       3            0          2      0
# 3        27    181.0  254.000000       3            0          2      0
# 4        32    174.0  261.000000       5            0          4      2

# %% [markdown]
# ## Now finding the time in terms of frames after which the peak of dynamin occurs

# %%
final_df['peak_occur_c2'] = final_df['frame'] - final_df['start_frame']
final_df
# Out:
#       track_id  c2_peak   amplitude  length  start_frame  end_frame  frame  \
# 0            9    172.0  235.809569       1            0          0      0
# 1           17    201.0  226.502247       8            0          7      7
# 2           22    172.0  249.375311       3            0          2      0
# 3           27    181.0  254.000000       3            0          2      0
# 4           32    174.0  261.000000       5            0          4      2
# ...        ...      ...         ...     ...          ...        ...    ...
# 5215     18909    188.0  268.000000       1          129        129    129
# 5216     18911    197.0  227.000000       1          129        129    129
# 5217     18913    200.0  228.000000       1          129        129    129
# 5218     18916    197.0  253.000000       1          129        129    129
# 5219     18921    181.0  274.813463       1          129        129    129
#
#       peak_occur_c2
# 0                 0
# 1                 7
# 2                 0
# 3                 0
# 4                 2
# ...             ...
# 5215              0
# 5216              0
# 5217              0
# 5218              0
# 5219              0
#
# [5220 rows x 8 columns]

# %% [markdown]
# ## Creating a temporary dataframe

# %%
temp = track_df[['frame', 'track_id', 'amplitude']]
temp.head()
# Out:
#    frame  track_id   amplitude
# 0      0         0  206.593249
# 1      0         1  191.000000
# 2      0         2  231.007679
# 3      0         3  185.152538
# 4      0         4  202.000000

# %% [markdown]
# ## Now finding the frame at which the peak for channel 3 occurs which is frame_y below

# %%
final_df_2 = pd.merge(final_df, temp, on=['track_id', 'amplitude'], how='inner')

# %%
final_df_2
# Out:
#       track_id  c2_peak   amplitude  length  start_frame  end_frame  frame_x  \
# 0            9    172.0  235.809569       1            0          0        0
# 1           17    201.0  226.502247       8            0          7        7
# 2           22    172.0  249.375311       3            0          2        0
# 3           27    181.0  254.000000       3            0          2        0
# 4           32    174.0  261.000000       5            0          4        2
# ...        ...      ...         ...     ...          ...        ...      ...
# 5231     18909    188.0  268.000000       1          129        129      129
# 5232     18911    197.0  227.000000       1          129        129      129
# 5233     18913    200.0  228.000000       1          129        129      129
# 5234     18916    197.0  253.000000       1          129        129      129
# 5235     18921    181.0  274.813463       1          129        129      129
#
#       peak_occur_c2  frame_y
# 0                 0        0
# 1                 7        7
# 2                 0        1
# 3                 0        2
# 4                 2        0
# ...             ...      ...
# 5231              0      129
# 5232              0      129
# 5233              0      129
# 5234              0      129
# 5235              0      129
#
# [5236 rows x 9 columns]

# %% [markdown]
# ## Now finding the time in terms of frames after which the peak of clathrin occurs

# %%
final_df_2['peak_occur_c3'] = final_df_2['frame_y'] - final_df_2['start_frame']

# %%
final_df_2.head()
# Out:
#    track_id  c2_peak   amplitude  length  start_frame  end_frame  frame_x  \
# 0         9    172.0  235.809569       1            0          0        0
# 1        17    201.0  226.502247       8            0          7        7
# 2        22    172.0  249.375311       3            0          2        0
# 3        27    181.0  254.000000       3            0          2        0
# 4        32    174.0  261.000000       5            0          4        2
#
#    peak_occur_c2  frame_y  peak_occur_c3
# 0              0        0              0
# 1              7        7              7
# 2              0        1              1
# 3              0        2              2
# 4              2        0              0

# %%
final_df_2.columns = ['track_id', 'c2_peak', 'amplitude','track_length', 
                      'start_frame', 'end_frame', 'peak_frame_c2', 'peak_start_c2', 'peak_frame_c3',
                     'peak_start_c3']

# %%
final_df_2.head()
# Out:
#    track_id  c2_peak   amplitude  track_length  start_frame  end_frame  \
# 0         9    172.0  235.809569             1            0          0
# 1        17    201.0  226.502247             8            0          7
# 2        22    172.0  249.375311             3            0          2
# 3        27    181.0  254.000000             3            0          2
# 4        32    174.0  261.000000             5            0          4
#
#    peak_frame_c2  peak_start_c2  peak_frame_c3  peak_start_c3
# 0              0              0              0              0
# 1              7              7              7              7
# 2              0              0              1              1
# 3              0              0              2              2
# 4              2              2              0              0

# %% [markdown]
# # Drop all tracks which have dynamin peak within the first 3 frames

# %%
filtered_final_df = final_df_2[(final_df_2['peak_start_c2'] > 3)]
filtered_final_df = filtered_final_df[(filtered_final_df['peak_start_c3'] > 3)]
filtered_final_df
# Out:
#       track_id  c2_peak   amplitude  track_length  start_frame  end_frame  \
# 1           17    201.0  226.502247             8            0          7
# 5           36    202.0  299.000000            34            0         33
# 17          73    224.0  345.835302             8            0          7
# 25          91    326.0  300.333333            21            0         20
# 32         105    173.0  308.000000            12            0         11
# ...        ...      ...         ...           ...          ...        ...
# 5028     17848    181.0  197.000000             7          121        127
# 5058     18006    185.0  221.635139             8          122        129
# 5082     18107    177.0  191.000000             7          123        129
# 5091     18143    187.0  226.485961             7          123        129
# 5125     18311    187.0  314.492478             6          124        129
#
#       peak_frame_c2  peak_start_c2  peak_frame_c3  peak_start_c3
# 1                 7              7              7              7
# 5                17             17             25             25
# 17                6              6              6              6
# 25               19             19             17             17
# 32               11             11              6              6
# ...             ...            ...            ...            ...
# 5028            126              5            127              6
# 5058            129              7            126              4
# 5082            129              6            127              4
# 5091            127              4            128              5
# 5125            128              4            128              4
#
# [483 rows x 10 columns]

# %% [markdown]
# # Drop all tracks which have dynamin peak in last frame

# %%
filtered_final_df = filtered_final_df[filtered_final_df['end_frame'] != filtered_final_df['peak_frame_c2']]

# %%
filtered_final_df
# Out:
#       track_id  c2_peak   amplitude  track_length  start_frame  end_frame  \
# 5           36    202.0  299.000000            34            0         33
# 17          73    224.0  345.835302             8            0          7
# 25          91    326.0  300.333333            21            0         20
# 48         144    210.0  335.333333            18            0         17
# 49         145    181.0  258.333333            20            0         19
# ...        ...      ...         ...           ...          ...        ...
# 5001     17739    188.0  234.000000            10          120        129
# 5008     17791    188.0  202.000000             7          120        126
# 5028     17848    181.0  197.000000             7          121        127
# 5091     18143    187.0  226.485961             7          123        129
# 5125     18311    187.0  314.492478             6          124        129
#
#       peak_frame_c2  peak_start_c2  peak_frame_c3  peak_start_c3
# 5                17             17             25             25
# 17                6              6              6              6
# 25               19             19             17             17
# 48               13             13             17             17
# 49               14             14             10             10
# ...             ...            ...            ...            ...
# 5001            126              6            124              4
# 5008            124              4            126              6
# 5028            126              5            127              6
# 5091            127              4            128              5
# 5125            128              4            128              4
#
# [377 rows x 10 columns]

# %% [markdown]
# # Drop all tracks which have clathrin peak in last frame

# %%
filtered_final_df = filtered_final_df[filtered_final_df['end_frame'] != filtered_final_df['peak_frame_c3']]

# %%
filtered_final_df
# Out:
#       track_id  c2_peak   amplitude  track_length  start_frame  end_frame  \
# 5           36    202.0  299.000000            34            0         33
# 17          73    224.0  345.835302             8            0          7
# 25          91    326.0  300.333333            21            0         20
# 49         145    181.0  258.333333            20            0         19
# 58         155    231.0  335.000000            12            0         11
# ...        ...      ...         ...           ...          ...        ...
# 4979     17656    203.0  213.000000             7          119        125
# 4987     17686    171.0  208.000000             9          119        127
# 5001     17739    188.0  234.000000            10          120        129
# 5091     18143    187.0  226.485961             7          123        129
# 5125     18311    187.0  314.492478             6          124        129
#
#       peak_frame_c2  peak_start_c2  peak_frame_c3  peak_start_c3
# 5                17             17             25             25
# 17                6              6              6              6
# 25               19             19             17             17
# 49               14             14             10             10
# 58                4              4              7              7
# ...             ...            ...            ...            ...
# 4979            124              5            124              5
# 4987            126              7            125              6
# 5001            126              6            124              4
# 5091            127              4            128              5
# 5125            128              4            128              4
#
# [331 rows x 10 columns]

# %%
filtered_final_df.columns = ['track_id', 'c2_peak', 'c3_peak', 'track_length', 'start_frame', 
                         'end_frame', 'peak_frame_c2', 'peak_start_c2', 'peak_frame_c3', 'peak_start_c3']

# %%
file_path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/filtered_tracks.pkl'
filtered_final_df.to_pickle(file_path)

# %% [markdown]
# ## TENTATIVE GAP FINDING CODE BELOW

# %%
track_df.head()
# Out:
#    frame  index   amplitude  mu_x   mu_y  mu_z  sigma_x  sigma_y  sigma_z  \
# 0      0      0  206.593249  11.0   12.0   0.0      2.0      2.0      4.0
# 1      0      1  191.000000  36.0   88.0   1.0      2.0      1.0      2.0
# 2      0      2  231.007679  40.0  141.0   1.0      2.0      2.0      2.0
# 3      0      3  185.152538  40.0   58.0   1.0      2.0      1.0      3.0
# 4      0      4  202.000000  46.0   73.0   1.0      2.0      2.0      3.0
#
#    frame_y  ...  track_id      c2_amp  c2_peak  c2_peak_x  c2_peak_y  \
# 0        0  ...         0  122.947826    152.0        9.0       14.0
# 1        0  ...         1  116.233333    143.0       34.0       87.0
# 2        0  ...         2  122.330000    142.0       41.0      142.0
# 3        0  ...         3  117.626667    142.0       42.0       59.0
# 4        0  ...         4  115.112000    141.0       45.0       74.0
#
#    c2_peak_z  c3_mean_amp  c2_peak_mean  c2_voxel_sum  c3_voxel_sum
# 0        2.0   163.682353    125.500000         11295         13913
# 1        2.0   138.233333    114.826667         20068         19928
# 2        0.0   153.940000    122.853333         15316         22805
# 3        0.0   141.280000    118.016667         14557         20358
# 4        3.0   147.768000    115.502857         23194         21963
#
# [5 rows x 21 columns]

# %%
track_df.sort_values(by=['track_id','frame'])
# Out:
#        frame  index   amplitude   mu_x   mu_y  mu_z  sigma_x  sigma_y  \
# 0          0      0  206.593249   11.0   12.0   0.0      2.0      2.0
# 1          0      1  191.000000   36.0   88.0   1.0      2.0      1.0
# 2          0      2  231.007679   40.0  141.0   1.0      2.0      2.0
# 3          0      3  185.152538   40.0   58.0   1.0      2.0      1.0
# 4          0      4  202.000000   46.0   73.0   1.0      2.0      2.0
# ...      ...    ...         ...    ...    ...   ...      ...      ...
# 49861    129    299  200.000000  136.0  147.0  72.0      2.0      1.0
# 49862    129    300  177.830039  160.0  133.0  72.0      2.0      2.0
# 49863    129    301  179.000000  201.0  207.0  71.0      2.0      1.0
# 49864    129    302  274.813463  219.0   45.0  71.0      2.0      2.0
# 49865    129    303  175.445348  231.0  219.0  71.0      3.0      2.0
#
#        sigma_z  frame_y  ...  track_id      c2_amp  c2_peak  c2_peak_x  \
# 0          4.0        0  ...         0  122.947826    152.0        9.0
# 1          2.0        0  ...         1  116.233333    143.0       34.0
# 2          2.0        0  ...         2  122.330000    142.0       41.0
# 3          3.0        0  ...         3  117.626667    142.0       42.0
# 4          3.0        0  ...         4  115.112000    141.0       45.0
# ...        ...      ...  ...       ...         ...      ...        ...
# 49861      5.0      129  ...     18918  118.616667    144.0      138.0
# 49862      3.0      129  ...     18919  120.153333    146.0      161.0
# 49863      3.0      129  ...     18920  115.380952    140.0      203.0
# 49864      2.0      129  ...     18921  139.080000    181.0      219.0
# 49865      2.0      129  ...     18922  122.320000    156.0      228.0
#
#        c2_peak_y  c2_peak_z  c3_mean_amp  c2_peak_mean  c2_voxel_sum  \
# 0           14.0        2.0   163.682353    125.500000         11295
# 1           87.0        2.0   138.233333    114.826667         20068
# 2          142.0        0.0   153.940000    122.853333         15316
# 3           59.0        0.0   141.280000    118.016667         14557
# 4           74.0        3.0   147.768000    115.502857         23194
# ...          ...        ...          ...           ...           ...
# 49861      148.0       70.0   162.649573    122.700000         27588
# 49862      135.0       70.0   143.660000    118.211429         26421
# 49863      207.0       68.0   130.676190    118.647619         26906
# 49864       43.0       73.0   202.216000    143.040000         21248
# 49865      218.0       72.0   131.234286    126.177143         21927
#
#        c3_voxel_sum
# 0             13913
# 1             19928
# 2             22805
# 3             20358
# 4             21963
# ...             ...
# 49861         27901
# 49862         24970
# 49863         26313
# 49864         38855
# 49865         26220
#
# [49867 rows x 21 columns]

# %%
track_df.drop('frame_diff', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 track_df.drop('frame_diff', axis = 1, inplace = True)
#
# File ~/miniconda3/envs/lap_track/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/lap_track/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/miniconda3/envs/lap_track/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/lap_track/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/miniconda3/envs/lap_track/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/miniconda3/envs/lap_track/lib/python3.10/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['frame_diff'] not found in axis"

# %%
# Sort the DataFrame by 'track_id' and 'frame_number'
track_df = track_df.sort_values(by=['track_id', 'frame'])

# Apply diff within each track group
track_df['frame_diff'] = track_df.groupby('track_id')['frame'].diff()

# Assign 1 where track_id changes
track_df['frame_diff'] = track_df['frame_diff'].where(track_df['track_id'].eq(track_df['track_id'].shift(1)), 1)

# Display the result
track_df.head()

# %%
# Group by 'track_id' and find the max 'frame_diff' within each group
max_frame_diff_per_track = track_df.groupby('track_id')['frame_diff'].max()

# Display the result
