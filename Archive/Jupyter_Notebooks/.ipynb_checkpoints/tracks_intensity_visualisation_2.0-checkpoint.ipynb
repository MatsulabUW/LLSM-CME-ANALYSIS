# %%
from os import path
import pandas as pd
from IPython.display import display
from matplotlib import pyplot as plt
import napari
from skimage import io
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams["font.family"] = ""

# %%
track_df = pd.read_pickle('/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/track_df_updated.pkl')
filtered_tracks = pd.read_pickle('/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/filtered_tracks.pkl')

# %%
# Create a napari viewer
viewer = napari.Viewer()

# Replace 'your_file.tif' with the path to your 4D TIFF file
file_path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/Channel3_complete.tif'

# Load the TIFF file using skimage
raw_image_3 = io.imread(file_path)

# Add the 4D stack to the viewer
layer_raw_3 = viewer.add_image(raw_image_3)

# Add Bounding Box
layer_raw_3.bounding_box.visible = True

# %%
# Replace 'your_file.tif' with the path to your 4D TIFF file
file_path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/Channel2_complete.tif'

# Load the TIFF file using skimage
raw_image_2 = io.imread(file_path)

# Add the 4D stack to the viewer
layer_raw_2 = viewer.add_image(raw_image_2)

# Add Bounding Box
layer_raw_2.bounding_box.visible = True
# Out:
# 1   HIToolbox                           0x00007ff81cbad726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81cbad2b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff81cb1ccd7 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1113
# 4   HIToolbox                           0x00007ff81cbad173 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 175
# 5   AppKit                              0x00007ff81667e4b7 -[NSApplication _setPresentationOptions:instance:flags:] + 1145
# 6   AppKit                              0x00007ff8164d3165 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 582
# 7   CoreFoundation                      0x00007ff8131ed3f4 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff81328743a ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00007ff813287389 _CFXRegistrationPost + 536
# 10  CoreFoundation                      0x00007ff8131c0919 _CFXNotificationPost + 735
# 11  Foundation                          0x00007ff813ffaf2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff81667eb28 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 15  SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 16  libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 17  libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 18  libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 19  libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 20  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 21  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 22  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 23  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 24  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 25  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 26  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 27  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 28  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 29  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cb3a0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cbad726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cb3a0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cbad726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cb3a0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cbad726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cb3a0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153

# %%
viewer.layers.remove(tracks_1)
# Out:
# 1   HIToolbox                           0x00007ff81cbad726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cb3a0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cbad726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153
# 1   HIToolbox                           0x00007ff81cb3a0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff81cb76638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff817e1c74d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff81812f04a _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 202
# 5   SkyLight                            0x00007ff81812ef71 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 18
# 6   libdispatch.dylib                   0x00007ff812f9b7fb _dispatch_call_block_and_release + 12
# 7   libdispatch.dylib                   0x00007ff812f9ca44 _dispatch_client_callout + 8
# 8   libdispatch.dylib                   0x00007ff812fa97b9 _dispatch_main_queue_drain + 952
# 9   libdispatch.dylib                   0x00007ff812fa93f3 _dispatch_main_queue_callback_4CF + 31
# 10  CoreFoundation                      0x00007ff813236610 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 11  CoreFoundation                      0x00007ff8131f6b90 __CFRunLoopRun + 2454
# 12  CoreFoundation                      0x00007ff8131f5b80 CFRunLoopRunSpecific + 560
# 13  HIToolbox                           0x00007ff81cb3a766 RunCurrentEventLoopInMode + 292
# 14  HIToolbox                           0x00007ff81cb3a576 ReceiveNextEventCommon + 679
# 15  HIToolbox                           0x00007ff81cb3a2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 16  AppKit                              0x00007ff816341f33 _DPSNextEvent + 909
# 17  AppKit                              0x00007ff816340db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 18  AppKit                              0x00007ff8163333f7 -[NSApplication run] + 586
# 19  libqcocoa.dylib                     0x000000011c10a50a qt_plugin_instance + 148153

# %%
viewer.dims.current_step = (74, 0, 0, 0)
plt.imshow(viewer.screenshot())
plt.xticks([])
plt.yticks([])

# %%
#points_layer = viewer.add_points(filtered_df[["frame", "mu_z", "mu_y", "mu_x"]], size=3, 
#                                name = 'filtered_points', face_color = 'r', symbol = 'ring')
#all_points_layer = viewer.add_points(track_df[["frame", "mu_z", "mu_y", "mu_x"]], size=2,
#                                name = 'all_points', face_color = 'white', symbol = 'o')
#tracks_1 = viewer.add_tracks(track_df[["track_id", "frame", "mu_z", "mu_y", "mu_x"]], name = 'Primary tracks')
#viewer.layers.remove(tracks_1)
