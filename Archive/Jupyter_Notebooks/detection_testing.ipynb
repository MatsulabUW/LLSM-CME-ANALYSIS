# %%
from os import path
import pandas as pd
from IPython.display import display
from matplotlib import pyplot as plt
import napari
from skimage import io

# %%
# Create a napari viewer
#viewer = napari.Viewer()

# Replace 'your_file.tif' with the path to your 4D TIFF file
file_path = '/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/Channel_3.tif'

# Load the TIFF file using skimage
raw_image = io.imread(file_path)

# selecting timepoint 4
raw_image = raw_image[4]

# Add the 4D stack to the viewer
#layer_raw = viewer.add_image(raw_image)

# %%
raw_image.shape

# %%
# Create a napari viewer
viewer = napari.Viewer()

# Add the 4D stack to the viewer
layer_raw = viewer.add_image(raw_image)

# %%
spots_df = pd.read_csv('/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/test_data_new/output_gaussians_p_10_g_5.csv')

# %%
spots_df.head()

# %%
points_layer = viewer.add_points(spots_df[[ "mu_z", "mu_y", "mu_x"]], size=2,
                                name = 'channel_3_points', face_color = 'white', symbol = 'o')

# %%
points_layer = viewer.add_points(spots_df[[ "mu_z", "mu_y", "mu_x"]], size=3,
                                name = 'channel_3_rings', face_color = 'yellow', symbol = 'ring')

# %%
spots_df_old = pd.read_csv('/Users/apple/Desktop/Akamatsu_Lab/Lap_track/self/files/test_data/output_gaussians_p_20_g_5.csv')

# %%
points_layer = viewer.add_points(spots_df_old[[ "mu_z", "mu_y", "mu_x"]], size=2,
                                name = 'channel_3_points_old', face_color = 'white', symbol = 'o')

# %%
points_layer = viewer.add_points(spots_df_old[[ "mu_z", "mu_y", "mu_x"]], size=3,
                                name = 'channel_3_points_rings', face_color = 'red', symbol = 'ring')
